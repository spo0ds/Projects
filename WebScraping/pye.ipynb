# %%
fhandle = open('mbox-short.txt')
for line in fhandle:
    line = line.rstrip()
    print(line)
# Out:
# From stephen.marquard@uct.ac.za Sat Jan  5 09:14:16 2008
# Return-Path: <postmaster@collab.sakaiproject.org>
# Received: from murder (mail.umich.edu [141.211.14.90])
# 	 by frankenstein.mail.umich.edu (Cyrus v2.3.8) with LMTPA;
# 	 Sat, 05 Jan 2008 09:14:16 -0500
# X-Sieve: CMU Sieve 2.3
# Received: from murder ([unix socket])
# 	 by mail.umich.edu (Cyrus v2.2.12) with LMTPA;
# 	 Sat, 05 Jan 2008 09:14:16 -0500
# Received: from holes.mr.itd.umich.edu (holes.mr.itd.umich.edu [141.211.14.79])
# 	by flawless.mail.umich.edu () with ESMTP id m05EEFR1013674;
# 	Sat, 5 Jan 2008 09:14:15 -0500
# Received: FROM paploo.uhi.ac.uk (app1.prod.collab.uhi.ac.uk [194.35.219.184])
# 	BY holes.mr.itd.umich.edu ID 477F90B0.2DB2F.12494 ;
# 	 5 Jan 2008 09:14:10 -0500
# Received: from paploo.uhi.ac.uk (localhost [127.0.0.1])
# 	by paploo.uhi.ac.uk (Postfix) with ESMTP id 5F919BC2F2;
# 	Sat,  5 Jan 2008 14:10:05 +0000 (GMT)
# Message-ID: <200801051412.m05ECIaH010327@nakamura.uits.iupui.edu>
# Mime-Version: 1.0
# Content-Transfer-Encoding: 7bit
# Received: from prod.collab.uhi.ac.uk ([194.35.219.182])
#           by paploo.uhi.ac.uk (JAMES SMTP Server 2.1.3) with SMTP ID 899
#           for <source@collab.sakaiproject.org>;
#           Sat, 5 Jan 2008 14:09:50 +0000 (GMT)
# Received: from nakamura.uits.iupui.edu (nakamura.uits.iupui.edu [134.68.220.122])
# 	by shmi.uhi.ac.uk (Postfix) with ESMTP id A215243002
# 	for <source@collab.sakaiproject.org>; Sat,  5 Jan 2008 14:13:33 +0000 (GMT)
# Received: from nakamura.uits.iupui.edu (localhost [127.0.0.1])
# 	by nakamura.uits.iupui.edu (8.12.11.20060308/8.12.11) with ESMTP id m05ECJVp010329
# 	for <source@collab.sakaiproject.org>; Sat, 5 Jan 2008 09:12:19 -0500
# Received: (from apache@localhost)
# 	by nakamura.uits.iupui.edu (8.12.11.20060308/8.12.11/Submit) id m05ECIaH010327
# 	for source@collab.sakaiproject.org; Sat, 5 Jan 2008 09:12:18 -0500
# Date: Sat, 5 Jan 2008 09:12:18 -0500
# X-Authentication-Warning: nakamura.uits.iupui.edu: apache set sender to stephen.marquard@uct.ac.za using -f
# To: source@collab.sakaiproject.org
# From: stephen.marquard@uct.ac.za
# Subject: [sakai] svn commit: r39772 - content/branches/sakai_2-5-x/content-impl/impl/src/java/org/sakaiproject/content/impl
# X-Content-Type-Outer-Envelope: text/plain; charset=UTF-8
# X-Content-Type-Message-Body: text/plain; charset=UTF-8
# Content-Type: text/plain; charset=UTF-8
# X-DSPAM-Result: Innocent
# X-DSPAM-Processed: Sat Jan  5 09:14:16 2008
# X-DSPAM-Confidence: 0.8475
# X-DSPAM-Probability: 0.0000
#
# Details: http://source.sakaiproject.org/viewsvn/?view=rev&rev=39772
#
# Author: stephen.marquard@uct.ac.za
# Date: 2008-01-05 09:12:07 -0500 (Sat, 05 Jan 2008)
# New Revision: 39772
#
# Modified:
# content/branches/sakai_2-5-x/content-impl/impl/src/java/org/sakaiproject/content/impl/ContentServiceSqlOracle.java
# content/branches/sakai_2-5-x/content-impl/impl/src/java/org/sakaiproject/content/impl/DbContentService.java
# Log:
# SAK-12501 merge to 2-5-x: r39622, r39624:5, r39632:3 (resolve conflict from differing linebreaks for r39622)
#
# ----------------------
# This automatic notification message was sent by Sakai Collab (https://collab.sakaiproject.org/portal) from the Source site.
# You can modify how you receive notifications at My Workspace > Preferences.
#
#
#
# From louis@media.berkeley.edu Fri Jan  4 18:10:48 2008
# Return-Path: <postmaster@collab.sakaiproject.org>
# Received: from murder (mail.umich.edu [141.211.14.97])
# 	 by frankenstein.mail.umich.edu (Cyrus v2.3.8) with LMTPA;
# 	 Fri, 04 Jan 2008 18:10:48 -0500
# X-Sieve: CMU Sieve 2.3
# Received: from murder ([unix socket])
# 	 by mail.umich.edu (Cyrus v2.2.12) with LMTPA;
# 	 Fri, 04 Jan 2008 18:10:48 -0500
# Received: from icestorm.mr.itd.umich.edu (icestorm.mr.itd.umich.edu [141.211.93.149])
# 	by sleepers.mail.umich.edu () with ESMTP id m04NAbGa029441;
# 	Fri, 4 Jan 2008 18:10:37 -0500
# Received: FROM paploo.uhi.ac.uk (app1.prod.collab.uhi.ac.uk [194.35.219.184])
# 	BY icestorm.mr.itd.umich.edu ID 477EBCE3.161BB.4320 ;
# 	 4 Jan 2008 18:10:31 -0500
# Received: from paploo.uhi.ac.uk (localhost [127.0.0.1])
# 	by paploo.uhi.ac.uk (Postfix) with ESMTP id 07969BB706;
# 	Fri,  4 Jan 2008 23:10:33 +0000 (GMT)
# Message-ID: <200801042308.m04N8v6O008125@nakamura.uits.iupui.edu>
# Mime-Version: 1.0
# Content-Transfer-Encoding: 7bit
# Received: from prod.collab.uhi.ac.uk ([194.35.219.182])
#           by paploo.uhi.ac.uk (JAMES SMTP Server 2.1.3) with SMTP ID 710
#           for <source@collab.sakaiproject.org>;
#           Fri, 4 Jan 2008 23:10:10 +0000 (GMT)
# Received: from nakamura.uits.iupui.edu (nakamura.uits.iupui.edu [134.68.220.122])
# 	by shmi.uhi.ac.uk (Postfix) with ESMTP id 4BA2F42F57
# 	for <source@collab.sakaiproject.org>; Fri,  4 Jan 2008 23:10:10 +0000 (GMT)
# Received: from nakamura.uits.iupui.edu (localhost [127.0.0.1])
# 	by nakamura.uits.iupui.edu (8.12.11.20060308/8.12.11) with ESMTP id m04N8vHG008127
# 	for <source@collab.sakaiproject.org>; Fri, 4 Jan 2008 18:08:57 -0500
# Received: (from apache@localhost)
# 	by nakamura.uits.iupui.edu (8.12.11.20060308/8.12.11/Submit) id m04N8v6O008125
# 	for source@collab.sakaiproject.org; Fri, 4 Jan 2008 18:08:57 -0500
# Date: Fri, 4 Jan 2008 18:08:57 -0500
# X-Authentication-Warning: nakamura.uits.iupui.edu: apache set sender to louis@media.berkeley.edu using -f
# To: source@collab.sakaiproject.org
# From: louis@media.berkeley.edu
# Subject: [sakai] svn commit: r39771 - in bspace/site-manage/sakai_2-4-x/site-manage-tool/tool/src: bundle java/org/sakaiproject/site/tool
# X-Content-Type-Outer-Envelope: text/plain; charset=UTF-8
# X-Content-Type-Message-Body: text/plain; charset=UTF-8
# Content-Type: text/plain; charset=UTF-8
# X-DSPAM-Result: Innocent
# X-DSPAM-Processed: Fri Jan  4 18:10:48 2008
# X-DSPAM-Confidence: 0.6178
# X-DSPAM-Probability: 0.0000
#
# Details: http://source.sakaiproject.org/viewsvn/?view=rev&rev=39771
#
# Author: louis@media.berkeley.edu
# Date: 2008-01-04 18:08:50 -0500 (Fri, 04 Jan 2008)
# New Revision: 39771
#
# Modified:
# bspace/site-manage/sakai_2-4-x/site-manage-tool/tool/src/bundle/sitesetupgeneric.properties
# bspace/site-manage/sakai_2-4-x/site-manage-tool/tool/src/java/org/sakaiproject/site/tool/SiteAction.java
# Log:
# BSP-1415 New (Guest) user Notification
#
# ----------------------
# This automatic notification message was sent by Sakai Collab (https://collab.sakaiproject.org/portal) from the Source site.
# You can modify how you receive notifications at My Workspace > Preferences.
#
#
#
# From zqian@umich.edu Fri Jan  4 16:10:39 2008
# Return-Path: <postmaster@collab.sakaiproject.org>
# Received: from murder (mail.umich.edu [141.211.14.25])
# 	 by frankenstein.mail.umich.edu (Cyrus v2.3.8) with LMTPA;
# 	 Fri, 04 Jan 2008 16:10:39 -0500
# X-Sieve: CMU Sieve 2.3
# Received: from murder ([unix socket])
# 	 by mail.umich.edu (Cyrus v2.2.12) with LMTPA;
# 	 Fri, 04 Jan 2008 16:10:39 -0500
# Received: from ghostbusters.mr.itd.umich.edu (ghostbusters.mr.itd.umich.edu [141.211.93.144])
# 	by panther.mail.umich.edu () with ESMTP id m04LAcZw014275;
# 	Fri, 4 Jan 2008 16:10:38 -0500
# Received: FROM paploo.uhi.ac.uk (app1.prod.collab.uhi.ac.uk [194.35.219.184])
# 	BY ghostbusters.mr.itd.umich.edu ID 477EA0C6.A0214.25480 ;
# 	 4 Jan 2008 16:10:33 -0500
# Received: from paploo.uhi.ac.uk (localhost [127.0.0.1])
# 	by paploo.uhi.ac.uk (Postfix) with ESMTP id C48CDBB490;
# 	Fri,  4 Jan 2008 21:10:31 +0000 (GMT)
# Message-ID: <200801042109.m04L92hb007923@nakamura.uits.iupui.edu>
# Mime-Version: 1.0
# Content-Transfer-Encoding: 7bit
# Received: from prod.collab.uhi.ac.uk ([194.35.219.182])
#           by paploo.uhi.ac.uk (JAMES SMTP Server 2.1.3) with SMTP ID 906
#           for <source@collab.sakaiproject.org>;
#           Fri, 4 Jan 2008 21:10:18 +0000 (GMT)
# Received: from nakamura.uits.iupui.edu (nakamura.uits.iupui.edu [134.68.220.122])
# 	by shmi.uhi.ac.uk (Postfix) with ESMTP id 7D13042F71
# 	for <source@collab.sakaiproject.org>; Fri,  4 Jan 2008 21:10:14 +0000 (GMT)
# Received: from nakamura.uits.iupui.edu (localhost [127.0.0.1])
# 	by nakamura.uits.iupui.edu (8.12.11.20060308/8.12.11) with ESMTP id m04L927E007925
# 	for <source@collab.sakaiproject.org>; Fri, 4 Jan 2008 16:09:02 -0500
# Received: (from apache@localhost)
# 	by nakamura.uits.iupui.edu (8.12.11.20060308/8.12.11/Submit) id m04L92hb007923
# 	for source@collab.sakaiproject.org; Fri, 4 Jan 2008 16:09:02 -0500
# Date: Fri, 4 Jan 2008 16:09:02 -0500
# X-Authentication-Warning: nakamura.uits.iupui.edu: apache set sender to zqian@umich.edu using -f
# To: source@collab.sakaiproject.org
# From: zqian@umich.edu
# Subject: [sakai] svn commit: r39770 - site-manage/branches/sakai_2-5-x/site-manage-tool/tool/src/webapp/vm/sitesetup
# X-Content-Type-Outer-Envelope: text/plain; charset=UTF-8
# X-Content-Type-Message-Body: text/plain; charset=UTF-8
# Content-Type: text/plain; charset=UTF-8
# X-DSPAM-Result: Innocent
# X-DSPAM-Processed: Fri Jan  4 16:10:39 2008
# X-DSPAM-Confidence: 0.6961
# X-DSPAM-Probability: 0.0000
#
# Details: http://source.sakaiproject.org/viewsvn/?view=rev&rev=39770
#
# Author: zqian@umich.edu
# Date: 2008-01-04 16:09:01 -0500 (Fri, 04 Jan 2008)
# New Revision: 39770
#
# Modified:
# site-manage/branches/sakai_2-5-x/site-manage-tool/tool/src/webapp/vm/sitesetup/chef_site-siteInfo-list.vm
# Log:
# merge fix to SAK-9996 into 2-5-x branch: svn merge -r 39687:39688 https://source.sakaiproject.org/svn/site-manage/trunk/
#
# ----------------------
# This automatic notification message was sent by Sakai Collab (https://collab.sakaiproject.org/portal) from the Source site.
# You can modify how you receive notifications at My Workspace > Preferences.
#
#
#
# From rjlowe@iupui.edu Fri Jan  4 15:46:24 2008
# Return-Path: <postmaster@collab.sakaiproject.org>
# Received: from murder (mail.umich.edu [141.211.14.25])
# 	 by frankenstein.mail.umich.edu (Cyrus v2.3.8) with LMTPA;
# 	 Fri, 04 Jan 2008 15:46:24 -0500
# X-Sieve: CMU Sieve 2.3
# Received: from murder ([unix socket])
# 	 by mail.umich.edu (Cyrus v2.2.12) with LMTPA;
# 	 Fri, 04 Jan 2008 15:46:24 -0500
# Received: from dreamcatcher.mr.itd.umich.edu (dreamcatcher.mr.itd.umich.edu [141.211.14.43])
# 	by panther.mail.umich.edu () with ESMTP id m04KkNbx032077;
# 	Fri, 4 Jan 2008 15:46:23 -0500
# Received: FROM paploo.uhi.ac.uk (app1.prod.collab.uhi.ac.uk [194.35.219.184])
# 	BY dreamcatcher.mr.itd.umich.edu ID 477E9B13.2F3BC.22965 ;
# 	 4 Jan 2008 15:46:13 -0500
# Received: from paploo.uhi.ac.uk (localhost [127.0.0.1])
# 	by paploo.uhi.ac.uk (Postfix) with ESMTP id 4AE03BB552;
# 	Fri,  4 Jan 2008 20:46:13 +0000 (GMT)
# Message-ID: <200801042044.m04Kiem3007881@nakamura.uits.iupui.edu>
# Mime-Version: 1.0
# Content-Transfer-Encoding: 7bit
# Received: from prod.collab.uhi.ac.uk ([194.35.219.182])
#           by paploo.uhi.ac.uk (JAMES SMTP Server 2.1.3) with SMTP ID 38
#           for <source@collab.sakaiproject.org>;
#           Fri, 4 Jan 2008 20:45:56 +0000 (GMT)
# Received: from nakamura.uits.iupui.edu (nakamura.uits.iupui.edu [134.68.220.122])
# 	by shmi.uhi.ac.uk (Postfix) with ESMTP id A55D242F57
# 	for <source@collab.sakaiproject.org>; Fri,  4 Jan 2008 20:45:52 +0000 (GMT)
# Received: from nakamura.uits.iupui.edu (localhost [127.0.0.1])
# 	by nakamura.uits.iupui.edu (8.12.11.20060308/8.12.11) with ESMTP id m04KieqE007883
# 	for <source@collab.sakaiproject.org>; Fri, 4 Jan 2008 15:44:40 -0500
# Received: (from apache@localhost)
# 	by nakamura.uits.iupui.edu (8.12.11.20060308/8.12.11/Submit) id m04Kiem3007881
# 	for source@collab.sakaiproject.org; Fri, 4 Jan 2008 15:44:40 -0500
# Date: Fri, 4 Jan 2008 15:44:40 -0500
# X-Authentication-Warning: nakamura.uits.iupui.edu: apache set sender to rjlowe@iupui.edu using -f
# To: source@collab.sakaiproject.org
# From: rjlowe@iupui.edu
# Subject: [sakai] svn commit: r39769 - in gradebook/trunk/app/ui/src: java/org/sakaiproject/tool/gradebook/ui/helpers/beans java/org/sakaiproject/tool/gradebook/ui/helpers/producers webapp/WEB-INF webapp/WEB-INF/bundle
# X-Content-Type-Outer-Envelope: text/plain; charset=UTF-8
# X-Content-Type-Message-Body: text/plain; charset=UTF-8
# Content-Type: text/plain; charset=UTF-8
# X-DSPAM-Result: Innocent
# X-DSPAM-Processed: Fri Jan  4 15:46:24 2008
# X-DSPAM-Confidence: 0.7565
# X-DSPAM-Probability: 0.0000
#
# Details: http://source.sakaiproject.org/viewsvn/?view=rev&rev=39769
#
# Author: rjlowe@iupui.edu
# Date: 2008-01-04 15:44:39 -0500 (Fri, 04 Jan 2008)
# New Revision: 39769
#
# Modified:
# gradebook/trunk/app/ui/src/java/org/sakaiproject/tool/gradebook/ui/helpers/beans/AssignmentGradeRecordBean.java
# gradebook/trunk/app/ui/src/java/org/sakaiproject/tool/gradebook/ui/helpers/producers/GradeGradebookItemProducer.java
# gradebook/trunk/app/ui/src/webapp/WEB-INF/applicationContext.xml
# gradebook/trunk/app/ui/src/webapp/WEB-INF/bundle/messages.properties
# gradebook/trunk/app/ui/src/webapp/WEB-INF/requestContext.xml
# Log:
# SAK-12180 - Fixed errors with grading helper
#
# ----------------------
# This automatic notification message was sent by Sakai Collab (https://collab.sakaiproject.org/portal) from the Source site.
# You can modify how you receive notifications at My Workspace > Preferences.
#
#
#
# From zqian@umich.edu Fri Jan  4 15:03:18 2008
# Return-Path: <postmaster@collab.sakaiproject.org>
# Received: from murder (mail.umich.edu [141.211.14.46])
# 	 by frankenstein.mail.umich.edu (Cyrus v2.3.8) with LMTPA;
# 	 Fri, 04 Jan 2008 15:03:18 -0500
# X-Sieve: CMU Sieve 2.3
# Received: from murder ([unix socket])
# 	 by mail.umich.edu (Cyrus v2.2.12) with LMTPA;
# 	 Fri, 04 Jan 2008 15:03:18 -0500
# Received: from firestarter.mr.itd.umich.edu (firestarter.mr.itd.umich.edu [141.211.14.83])
# 	by fan.mail.umich.edu () with ESMTP id m04K3HGF006563;
# 	Fri, 4 Jan 2008 15:03:17 -0500
# Received: FROM paploo.uhi.ac.uk (app1.prod.collab.uhi.ac.uk [194.35.219.184])
# 	BY firestarter.mr.itd.umich.edu ID 477E9100.8F7F4.1590 ;
# 	 4 Jan 2008 15:03:15 -0500
# Received: from paploo.uhi.ac.uk (localhost [127.0.0.1])
# 	by paploo.uhi.ac.uk (Postfix) with ESMTP id 57770BB477;
# 	Fri,  4 Jan 2008 20:03:09 +0000 (GMT)
# Message-ID: <200801042001.m04K1cO0007738@nakamura.uits.iupui.edu>
# Mime-Version: 1.0
# Content-Transfer-Encoding: 7bit
# Received: from prod.collab.uhi.ac.uk ([194.35.219.182])
#           by paploo.uhi.ac.uk (JAMES SMTP Server 2.1.3) with SMTP ID 622
#           for <source@collab.sakaiproject.org>;
#           Fri, 4 Jan 2008 20:02:46 +0000 (GMT)
# Received: from nakamura.uits.iupui.edu (nakamura.uits.iupui.edu [134.68.220.122])
# 	by shmi.uhi.ac.uk (Postfix) with ESMTP id AB4D042F4D
# 	for <source@collab.sakaiproject.org>; Fri,  4 Jan 2008 20:02:50 +0000 (GMT)
# Received: from nakamura.uits.iupui.edu (localhost [127.0.0.1])
# 	by nakamura.uits.iupui.edu (8.12.11.20060308/8.12.11) with ESMTP id m04K1cXv007740
# 	for <source@collab.sakaiproject.org>; Fri, 4 Jan 2008 15:01:38 -0500
# Received: (from apache@localhost)
# 	by nakamura.uits.iupui.edu (8.12.11.20060308/8.12.11/Submit) id m04K1cO0007738
# 	for source@collab.sakaiproject.org; Fri, 4 Jan 2008 15:01:38 -0500
# Date: Fri, 4 Jan 2008 15:01:38 -0500
# X-Authentication-Warning: nakamura.uits.iupui.edu: apache set sender to zqian@umich.edu using -f
# To: source@collab.sakaiproject.org
# From: zqian@umich.edu
# Subject: [sakai] svn commit: r39766 - site-manage/branches/sakai_2-4-x/site-manage-tool/tool/src/java/org/sakaiproject/site/tool
# X-Content-Type-Outer-Envelope: text/plain; charset=UTF-8
# X-Content-Type-Message-Body: text/plain; charset=UTF-8
# Content-Type: text/plain; charset=UTF-8
# X-DSPAM-Result: Innocent
# X-DSPAM-Processed: Fri Jan  4 15:03:18 2008
# X-DSPAM-Confidence: 0.7626
# X-DSPAM-Probability: 0.0000
#
# Details: http://source.sakaiproject.org/viewsvn/?view=rev&rev=39766
#
# Author: zqian@umich.edu
# Date: 2008-01-04 15:01:37 -0500 (Fri, 04 Jan 2008)
# New Revision: 39766
#
# Modified:
# site-manage/branches/sakai_2-4-x/site-manage-tool/tool/src/java/org/sakaiproject/site/tool/SiteAction.java
# Log:
# merge fix to SAK-10788 into site-manage 2.4.x branch:
#
# Sakai Source Repository  	#38024  	Wed Nov 07 14:54:46 MST 2007  	zqian@umich.edu  	 Fix to SAK-10788: If a provided id in a couse site is fake or doesn't provide any user information, Site Info appears to be like project site with empty participant list
#
# Watch for enrollments object being null and concatenate provider ids when there are more than one.
# Files Changed
# MODIFY /site-manage/trunk/site-manage-tool/tool/src/java/org/sakaiproject/site/tool/SiteAction.java
#
#
#
#
# ----------------------
# This automatic notification message was sent by Sakai Collab (https://collab.sakaiproject.org/portal) from the Source site.
# You can modify how you receive notifications at My Workspace > Preferences.
#
#
#
# From rjlowe@iupui.edu Fri Jan  4 14:50:18 2008
# Return-Path: <postmaster@collab.sakaiproject.org>
# Received: from murder (mail.umich.edu [141.211.14.93])
# 	 by frankenstein.mail.umich.edu (Cyrus v2.3.8) with LMTPA;
# 	 Fri, 04 Jan 2008 14:50:18 -0500
# X-Sieve: CMU Sieve 2.3
# Received: from murder ([unix socket])
# 	 by mail.umich.edu (Cyrus v2.2.12) with LMTPA;
# 	 Fri, 04 Jan 2008 14:50:18 -0500
# Received: from eyewitness.mr.itd.umich.edu (eyewitness.mr.itd.umich.edu [141.211.93.142])
# 	by mission.mail.umich.edu () with ESMTP id m04JoHJi019755;
# 	Fri, 4 Jan 2008 14:50:17 -0500
# Received: FROM paploo.uhi.ac.uk (app1.prod.collab.uhi.ac.uk [194.35.219.184])
# 	BY eyewitness.mr.itd.umich.edu ID 477E8DF2.67B91.5278 ;
# 	 4 Jan 2008 14:50:13 -0500
# Received: from paploo.uhi.ac.uk (localhost [127.0.0.1])
# 	by paploo.uhi.ac.uk (Postfix) with ESMTP id 2D1B9BB492;
# 	Fri,  4 Jan 2008 19:47:10 +0000 (GMT)
# Message-ID: <200801041948.m04JmdwO007705@nakamura.uits.iupui.edu>
# Mime-Version: 1.0
# Content-Transfer-Encoding: 7bit
# Received: from prod.collab.uhi.ac.uk ([194.35.219.182])
#           by paploo.uhi.ac.uk (JAMES SMTP Server 2.1.3) with SMTP ID 960
#           for <source@collab.sakaiproject.org>;
#           Fri, 4 Jan 2008 19:46:50 +0000 (GMT)
# Received: from nakamura.uits.iupui.edu (nakamura.uits.iupui.edu [134.68.220.122])
# 	by shmi.uhi.ac.uk (Postfix) with ESMTP id B3E6742F4A
# 	for <source@collab.sakaiproject.org>; Fri,  4 Jan 2008 19:49:51 +0000 (GMT)
# Received: from nakamura.uits.iupui.edu (localhost [127.0.0.1])
# 	by nakamura.uits.iupui.edu (8.12.11.20060308/8.12.11) with ESMTP id m04JmeV9007707
# 	for <source@collab.sakaiproject.org>; Fri, 4 Jan 2008 14:48:40 -0500
# Received: (from apache@localhost)
# 	by nakamura.uits.iupui.edu (8.12.11.20060308/8.12.11/Submit) id m04JmdwO007705
# 	for source@collab.sakaiproject.org; Fri, 4 Jan 2008 14:48:39 -0500
# Date: Fri, 4 Jan 2008 14:48:39 -0500
# X-Authentication-Warning: nakamura.uits.iupui.edu: apache set sender to rjlowe@iupui.edu using -f
# To: source@collab.sakaiproject.org
# From: rjlowe@iupui.edu
# Subject: [sakai] svn commit: r39765 - in gradebook/trunk/app: business/src/java/org/sakaiproject/tool/gradebook/business business/src/java/org/sakaiproject/tool/gradebook/business/impl ui ui/src/java/org/sakaiproject/tool/gradebook/ui/helpers/beans ui/src/java/org/sakaiproject/tool/gradebook/ui/helpers/entity ui/src/java/org/sakaiproject/tool/gradebook/ui/helpers/params ui/src/java/org/sakaiproject/tool/gradebook/ui/helpers/producers ui/src/webapp/WEB-INF ui/src/webapp/WEB-INF/bundle ui/src/webapp/content/templates
# X-Content-Type-Outer-Envelope: text/plain; charset=UTF-8
# X-Content-Type-Message-Body: text/plain; charset=UTF-8
# Content-Type: text/plain; charset=UTF-8
# X-DSPAM-Result: Innocent
# X-DSPAM-Processed: Fri Jan  4 14:50:18 2008
# X-DSPAM-Confidence: 0.7556
# X-DSPAM-Probability: 0.0000
#
# Details: http://source.sakaiproject.org/viewsvn/?view=rev&rev=39765
#
# Author: rjlowe@iupui.edu
# Date: 2008-01-04 14:48:37 -0500 (Fri, 04 Jan 2008)
# New Revision: 39765
#
# Added:
# gradebook/trunk/app/ui/src/java/org/sakaiproject/tool/gradebook/ui/helpers/beans/AssignmentGradeRecordBean.java
# gradebook/trunk/app/ui/src/java/org/sakaiproject/tool/gradebook/ui/helpers/beans/AssignmentGradeRecordCreator.java
# gradebook/trunk/app/ui/src/java/org/sakaiproject/tool/gradebook/ui/helpers/entity/GradebookEntryGradeEntityProvider.java
# gradebook/trunk/app/ui/src/java/org/sakaiproject/tool/gradebook/ui/helpers/params/GradeGradebookItemViewParams.java
# gradebook/trunk/app/ui/src/java/org/sakaiproject/tool/gradebook/ui/helpers/producers/GradeGradebookItemProducer.java
# gradebook/trunk/app/ui/src/webapp/content/templates/grade-gradebook-item.html
# Modified:
# gradebook/trunk/app/business/src/java/org/sakaiproject/tool/gradebook/business/GradebookManager.java
# gradebook/trunk/app/business/src/java/org/sakaiproject/tool/gradebook/business/impl/GradebookManagerHibernateImpl.java
# gradebook/trunk/app/ui/pom.xml
# gradebook/trunk/app/ui/src/java/org/sakaiproject/tool/gradebook/ui/helpers/beans/GradebookItemBean.java
# gradebook/trunk/app/ui/src/java/org/sakaiproject/tool/gradebook/ui/helpers/entity/GradebookEntryEntityProvider.java
# gradebook/trunk/app/ui/src/java/org/sakaiproject/tool/gradebook/ui/helpers/producers/AddGradebookItemProducer.java
# gradebook/trunk/app/ui/src/webapp/WEB-INF/applicationContext.xml
# gradebook/trunk/app/ui/src/webapp/WEB-INF/bundle/messages.properties
# gradebook/trunk/app/ui/src/webapp/WEB-INF/requestContext.xml
# Log:
# SAK-12180 - New helper tool to grade an assignment
#
# ----------------------
# This automatic notification message was sent by Sakai Collab (https://collab.sakaiproject.org/portal) from the Source site.
# You can modify how you receive notifications at My Workspace > Preferences.
#
#
#
# From cwen@iupui.edu Fri Jan  4 11:37:30 2008
# Return-Path: <postmaster@collab.sakaiproject.org>
# Received: from murder (mail.umich.edu [141.211.14.46])
# 	 by frankenstein.mail.umich.edu (Cyrus v2.3.8) with LMTPA;
# 	 Fri, 04 Jan 2008 11:37:30 -0500
# X-Sieve: CMU Sieve 2.3
# Received: from murder ([unix socket])
# 	 by mail.umich.edu (Cyrus v2.2.12) with LMTPA;
# 	 Fri, 04 Jan 2008 11:37:30 -0500
# Received: from tadpole.mr.itd.umich.edu (tadpole.mr.itd.umich.edu [141.211.14.72])
# 	by fan.mail.umich.edu () with ESMTP id m04GbT9x022078;
# 	Fri, 4 Jan 2008 11:37:29 -0500
# Received: FROM paploo.uhi.ac.uk (app1.prod.collab.uhi.ac.uk [194.35.219.184])
# 	BY tadpole.mr.itd.umich.edu ID 477E60B2.82756.9904 ;
# 	 4 Jan 2008 11:37:09 -0500
# Received: from paploo.uhi.ac.uk (localhost [127.0.0.1])
# 	by paploo.uhi.ac.uk (Postfix) with ESMTP id 8D13DBB001;
# 	Fri,  4 Jan 2008 16:37:07 +0000 (GMT)
# Message-ID: <200801041635.m04GZQGZ007313@nakamura.uits.iupui.edu>
# Mime-Version: 1.0
# Content-Transfer-Encoding: 7bit
# Received: from prod.collab.uhi.ac.uk ([194.35.219.182])
#           by paploo.uhi.ac.uk (JAMES SMTP Server 2.1.3) with SMTP ID 120
#           for <source@collab.sakaiproject.org>;
#           Fri, 4 Jan 2008 16:36:40 +0000 (GMT)
# Received: from nakamura.uits.iupui.edu (nakamura.uits.iupui.edu [134.68.220.122])
# 	by shmi.uhi.ac.uk (Postfix) with ESMTP id D430B42E42
# 	for <source@collab.sakaiproject.org>; Fri,  4 Jan 2008 16:36:37 +0000 (GMT)
# Received: from nakamura.uits.iupui.edu (localhost [127.0.0.1])
# 	by nakamura.uits.iupui.edu (8.12.11.20060308/8.12.11) with ESMTP id m04GZQ7W007315
# 	for <source@collab.sakaiproject.org>; Fri, 4 Jan 2008 11:35:26 -0500
# Received: (from apache@localhost)
# 	by nakamura.uits.iupui.edu (8.12.11.20060308/8.12.11/Submit) id m04GZQGZ007313
# 	for source@collab.sakaiproject.org; Fri, 4 Jan 2008 11:35:26 -0500
# Date: Fri, 4 Jan 2008 11:35:26 -0500
# X-Authentication-Warning: nakamura.uits.iupui.edu: apache set sender to cwen@iupui.edu using -f
# To: source@collab.sakaiproject.org
# From: cwen@iupui.edu
# Subject: [sakai] svn commit: r39764 - in msgcntr/trunk/messageforums-app/src/java/org/sakaiproject/tool/messageforums: . ui
# X-Content-Type-Outer-Envelope: text/plain; charset=UTF-8
# X-Content-Type-Message-Body: text/plain; charset=UTF-8
# Content-Type: text/plain; charset=UTF-8
# X-DSPAM-Result: Innocent
# X-DSPAM-Processed: Fri Jan  4 11:37:30 2008
# X-DSPAM-Confidence: 0.7002
# X-DSPAM-Probability: 0.0000
#
# Details: http://source.sakaiproject.org/viewsvn/?view=rev&rev=39764
#
# Author: cwen@iupui.edu
# Date: 2008-01-04 11:35:25 -0500 (Fri, 04 Jan 2008)
# New Revision: 39764
#
# Modified:
# msgcntr/trunk/messageforums-app/src/java/org/sakaiproject/tool/messageforums/PrivateMessagesTool.java
# msgcntr/trunk/messageforums-app/src/java/org/sakaiproject/tool/messageforums/ui/PrivateMessageDecoratedBean.java
# Log:
# unmerge Xingtang's checkin for SAK-12488.
#
# svn merge -r39558:39557 https://source.sakaiproject.org/svn/msgcntr/trunk
# U    messageforums-app/src/java/org/sakaiproject/tool/messageforums/PrivateMessagesTool.java
# U    messageforums-app/src/java/org/sakaiproject/tool/messageforums/ui/PrivateMessageDecoratedBean.java
#
# svn log -r 39558
# ------------------------------------------------------------------------
# r39558 | hu2@iupui.edu | 2007-12-20 15:25:38 -0500 (Thu, 20 Dec 2007) | 3 lines
#
# SAK-12488
# when send a message to yourself. click reply to all, cc row should be null.
# http://jira.sakaiproject.org/jira/browse/SAK-12488
# ------------------------------------------------------------------------
#
#
# ----------------------
# This automatic notification message was sent by Sakai Collab (https://collab.sakaiproject.org/portal) from the Source site.
# You can modify how you receive notifications at My Workspace > Preferences.
#
#
#
# From cwen@iupui.edu Fri Jan  4 11:35:08 2008
# Return-Path: <postmaster@collab.sakaiproject.org>
# Received: from murder (mail.umich.edu [141.211.14.46])
# 	 by frankenstein.mail.umich.edu (Cyrus v2.3.8) with LMTPA;
# 	 Fri, 04 Jan 2008 11:35:08 -0500
# X-Sieve: CMU Sieve 2.3
# Received: from murder ([unix socket])
# 	 by mail.umich.edu (Cyrus v2.2.12) with LMTPA;
# 	 Fri, 04 Jan 2008 11:35:08 -0500
# Received: from it.mr.itd.umich.edu (it.mr.itd.umich.edu [141.211.93.151])
# 	by fan.mail.umich.edu () with ESMTP id m04GZ6lt020480;
# 	Fri, 4 Jan 2008 11:35:06 -0500
# Received: FROM paploo.uhi.ac.uk (app1.prod.collab.uhi.ac.uk [194.35.219.184])
# 	BY it.mr.itd.umich.edu ID 477E6033.6469D.21870 ;
# 	 4 Jan 2008 11:35:02 -0500
# Received: from paploo.uhi.ac.uk (localhost [127.0.0.1])
# 	by paploo.uhi.ac.uk (Postfix) with ESMTP id E40FABAE5B;
# 	Fri,  4 Jan 2008 16:34:38 +0000 (GMT)
# Message-ID: <200801041633.m04GX6eG007292@nakamura.uits.iupui.edu>
# Mime-Version: 1.0
# Content-Transfer-Encoding: 7bit
# Received: from prod.collab.uhi.ac.uk ([194.35.219.182])
#           by paploo.uhi.ac.uk (JAMES SMTP Server 2.1.3) with SMTP ID 697
#           for <source@collab.sakaiproject.org>;
#           Fri, 4 Jan 2008 16:34:01 +0000 (GMT)
# Received: from nakamura.uits.iupui.edu (nakamura.uits.iupui.edu [134.68.220.122])
# 	by shmi.uhi.ac.uk (Postfix) with ESMTP id 1CD0C42E42
# 	for <source@collab.sakaiproject.org>; Fri,  4 Jan 2008 16:34:17 +0000 (GMT)
# Received: from nakamura.uits.iupui.edu (localhost [127.0.0.1])
# 	by nakamura.uits.iupui.edu (8.12.11.20060308/8.12.11) with ESMTP id m04GX6Y3007294
# 	for <source@collab.sakaiproject.org>; Fri, 4 Jan 2008 11:33:06 -0500
# Received: (from apache@localhost)
# 	by nakamura.uits.iupui.edu (8.12.11.20060308/8.12.11/Submit) id m04GX6eG007292
# 	for source@collab.sakaiproject.org; Fri, 4 Jan 2008 11:33:06 -0500
# Date: Fri, 4 Jan 2008 11:33:06 -0500
# X-Authentication-Warning: nakamura.uits.iupui.edu: apache set sender to cwen@iupui.edu using -f
# To: source@collab.sakaiproject.org
# From: cwen@iupui.edu
# Subject: [sakai] svn commit: r39763 - in msgcntr/trunk: messageforums-api/src/bundle/org/sakaiproject/api/app/messagecenter/bundle messageforums-app/src/java/org/sakaiproject/tool/messageforums
# X-Content-Type-Outer-Envelope: text/plain; charset=UTF-8
# X-Content-Type-Message-Body: text/plain; charset=UTF-8
# Content-Type: text/plain; charset=UTF-8
# X-DSPAM-Result: Innocent
# X-DSPAM-Processed: Fri Jan  4 11:35:08 2008
# X-DSPAM-Confidence: 0.7615
# X-DSPAM-Probability: 0.0000
#
# Details: http://source.sakaiproject.org/viewsvn/?view=rev&rev=39763
#
# Author: cwen@iupui.edu
# Date: 2008-01-04 11:33:05 -0500 (Fri, 04 Jan 2008)
# New Revision: 39763
#
# Modified:
# msgcntr/trunk/messageforums-api/src/bundle/org/sakaiproject/api/app/messagecenter/bundle/Messages.properties
# msgcntr/trunk/messageforums-app/src/java/org/sakaiproject/tool/messageforums/PrivateMessagesTool.java
# Log:
# unmerge Xingtang's check in for SAK-12484.
#
# svn merge -r39571:39570 https://source.sakaiproject.org/svn/msgcntr/trunk
# U    messageforums-api/src/bundle/org/sakaiproject/api/app/messagecenter/bundle/Messages.properties
# U    messageforums-app/src/java/org/sakaiproject/tool/messageforums/PrivateMessagesTool.java
#
# svn log -r 39571
# ------------------------------------------------------------------------
# r39571 | hu2@iupui.edu | 2007-12-20 21:26:28 -0500 (Thu, 20 Dec 2007) | 3 lines
#
# SAK-12484
# reply all cc list should not include the current user name.
# http://jira.sakaiproject.org/jira/browse/SAK-12484
# ------------------------------------------------------------------------
#
#
# ----------------------
# This automatic notification message was sent by Sakai Collab (https://collab.sakaiproject.org/portal) from the Source site.
# You can modify how you receive notifications at My Workspace > Preferences.
#
#
#
# From gsilver@umich.edu Fri Jan  4 11:12:37 2008
# Return-Path: <postmaster@collab.sakaiproject.org>
# Received: from murder (mail.umich.edu [141.211.14.25])
# 	 by frankenstein.mail.umich.edu (Cyrus v2.3.8) with LMTPA;
# 	 Fri, 04 Jan 2008 11:12:37 -0500
# X-Sieve: CMU Sieve 2.3
# Received: from murder ([unix socket])
# 	 by mail.umich.edu (Cyrus v2.2.12) with LMTPA;
# 	 Fri, 04 Jan 2008 11:12:37 -0500
# Received: from holes.mr.itd.umich.edu (holes.mr.itd.umich.edu [141.211.14.79])
# 	by panther.mail.umich.edu () with ESMTP id m04GCaHB030887;
# 	Fri, 4 Jan 2008 11:12:36 -0500
# Received: FROM paploo.uhi.ac.uk (app1.prod.collab.uhi.ac.uk [194.35.219.184])
# 	BY holes.mr.itd.umich.edu ID 477E5AEB.E670B.28397 ;
# 	 4 Jan 2008 11:12:30 -0500
# Received: from paploo.uhi.ac.uk (localhost [127.0.0.1])
# 	by paploo.uhi.ac.uk (Postfix) with ESMTP id 99715BAE7D;
# 	Fri,  4 Jan 2008 16:12:27 +0000 (GMT)
# Message-ID: <200801041611.m04GB1Lb007221@nakamura.uits.iupui.edu>
# Mime-Version: 1.0
# Content-Transfer-Encoding: 7bit
# Received: from prod.collab.uhi.ac.uk ([194.35.219.182])
#           by paploo.uhi.ac.uk (JAMES SMTP Server 2.1.3) with SMTP ID 272
#           for <source@collab.sakaiproject.org>;
#           Fri, 4 Jan 2008 16:12:14 +0000 (GMT)
# Received: from nakamura.uits.iupui.edu (nakamura.uits.iupui.edu [134.68.220.122])
# 	by shmi.uhi.ac.uk (Postfix) with ESMTP id 0A6ED42DFC
# 	for <source@collab.sakaiproject.org>; Fri,  4 Jan 2008 16:12:12 +0000 (GMT)
# Received: from nakamura.uits.iupui.edu (localhost [127.0.0.1])
# 	by nakamura.uits.iupui.edu (8.12.11.20060308/8.12.11) with ESMTP id m04GB1Wt007223
# 	for <source@collab.sakaiproject.org>; Fri, 4 Jan 2008 11:11:01 -0500
# Received: (from apache@localhost)
# 	by nakamura.uits.iupui.edu (8.12.11.20060308/8.12.11/Submit) id m04GB1Lb007221
# 	for source@collab.sakaiproject.org; Fri, 4 Jan 2008 11:11:01 -0500
# Date: Fri, 4 Jan 2008 11:11:01 -0500
# X-Authentication-Warning: nakamura.uits.iupui.edu: apache set sender to gsilver@umich.edu using -f
# To: source@collab.sakaiproject.org
# From: gsilver@umich.edu
# Subject: [sakai] svn commit: r39762 - web/trunk/web-tool/tool/src/bundle
# X-Content-Type-Outer-Envelope: text/plain; charset=UTF-8
# X-Content-Type-Message-Body: text/plain; charset=UTF-8
# Content-Type: text/plain; charset=UTF-8
# X-DSPAM-Result: Innocent
# X-DSPAM-Processed: Fri Jan  4 11:12:37 2008
# X-DSPAM-Confidence: 0.7601
# X-DSPAM-Probability: 0.0000
#
# Details: http://source.sakaiproject.org/viewsvn/?view=rev&rev=39762
#
# Author: gsilver@umich.edu
# Date: 2008-01-04 11:11:00 -0500 (Fri, 04 Jan 2008)
# New Revision: 39762
#
# Modified:
# web/trunk/web-tool/tool/src/bundle/iframe.properties
# Log:
# SAK-12596
# http://bugs.sakaiproject.org/jira/browse/SAK-12596
# - left moot (unused) entries commented for now
#
# ----------------------
# This automatic notification message was sent by Sakai Collab (https://collab.sakaiproject.org/portal) from the Source site.
# You can modify how you receive notifications at My Workspace > Preferences.
#
#
#
# From gsilver@umich.edu Fri Jan  4 11:11:52 2008
# Return-Path: <postmaster@collab.sakaiproject.org>
# Received: from murder (mail.umich.edu [141.211.14.36])
# 	 by frankenstein.mail.umich.edu (Cyrus v2.3.8) with LMTPA;
# 	 Fri, 04 Jan 2008 11:11:52 -0500
# X-Sieve: CMU Sieve 2.3
# Received: from murder ([unix socket])
# 	 by mail.umich.edu (Cyrus v2.2.12) with LMTPA;
# 	 Fri, 04 Jan 2008 11:11:52 -0500
# Received: from creepshow.mr.itd.umich.edu (creepshow.mr.itd.umich.edu [141.211.14.84])
# 	by godsend.mail.umich.edu () with ESMTP id m04GBqqv025330;
# 	Fri, 4 Jan 2008 11:11:52 -0500
# Received: FROM paploo.uhi.ac.uk (app1.prod.collab.uhi.ac.uk [194.35.219.184])
# 	BY creepshow.mr.itd.umich.edu ID 477E5AB3.5CC32.30840 ;
# 	 4 Jan 2008 11:11:34 -0500
# Received: from paploo.uhi.ac.uk (localhost [127.0.0.1])
# 	by paploo.uhi.ac.uk (Postfix) with ESMTP id 62AA4BAE46;
# 	Fri,  4 Jan 2008 16:11:31 +0000 (GMT)
# Message-ID: <200801041610.m04GA5KP007209@nakamura.uits.iupui.edu>
# Mime-Version: 1.0
# Content-Transfer-Encoding: 7bit
# Received: from prod.collab.uhi.ac.uk ([194.35.219.182])
#           by paploo.uhi.ac.uk (JAMES SMTP Server 2.1.3) with SMTP ID 1006
#           for <source@collab.sakaiproject.org>;
#           Fri, 4 Jan 2008 16:11:18 +0000 (GMT)
# Received: from nakamura.uits.iupui.edu (nakamura.uits.iupui.edu [134.68.220.122])
# 	by shmi.uhi.ac.uk (Postfix) with ESMTP id C596A3DFA2
# 	for <source@collab.sakaiproject.org>; Fri,  4 Jan 2008 16:11:16 +0000 (GMT)
# Received: from nakamura.uits.iupui.edu (localhost [127.0.0.1])
# 	by nakamura.uits.iupui.edu (8.12.11.20060308/8.12.11) with ESMTP id m04GA5LR007211
# 	for <source@collab.sakaiproject.org>; Fri, 4 Jan 2008 11:10:05 -0500
# Received: (from apache@localhost)
# 	by nakamura.uits.iupui.edu (8.12.11.20060308/8.12.11/Submit) id m04GA5KP007209
# 	for source@collab.sakaiproject.org; Fri, 4 Jan 2008 11:10:05 -0500
# Date: Fri, 4 Jan 2008 11:10:05 -0500
# X-Authentication-Warning: nakamura.uits.iupui.edu: apache set sender to gsilver@umich.edu using -f
# To: source@collab.sakaiproject.org
# From: gsilver@umich.edu
# Subject: [sakai] svn commit: r39761 - site/trunk/site-tool/tool/src/bundle
# X-Content-Type-Outer-Envelope: text/plain; charset=UTF-8
# X-Content-Type-Message-Body: text/plain; charset=UTF-8
# Content-Type: text/plain; charset=UTF-8
# X-DSPAM-Result: Innocent
# X-DSPAM-Processed: Fri Jan  4 11:11:52 2008
# X-DSPAM-Confidence: 0.7605
# X-DSPAM-Probability: 0.0000
#
# Details: http://source.sakaiproject.org/viewsvn/?view=rev&rev=39761
#
# Author: gsilver@umich.edu
# Date: 2008-01-04 11:10:04 -0500 (Fri, 04 Jan 2008)
# New Revision: 39761
#
# Modified:
# site/trunk/site-tool/tool/src/bundle/admin.properties
# Log:
# SAK-12595
# http://bugs.sakaiproject.org/jira/browse/SAK-12595
# - left moot (unused) entries commented for now
#
# ----------------------
# This automatic notification message was sent by Sakai Collab (https://collab.sakaiproject.org/portal) from the Source site.
# You can modify how you receive notifications at My Workspace > Preferences.
#
#
#
# From zqian@umich.edu Fri Jan  4 11:11:03 2008
# Return-Path: <postmaster@collab.sakaiproject.org>
# Received: from murder (mail.umich.edu [141.211.14.97])
# 	 by frankenstein.mail.umich.edu (Cyrus v2.3.8) with LMTPA;
# 	 Fri, 04 Jan 2008 11:11:03 -0500
# X-Sieve: CMU Sieve 2.3
# Received: from murder ([unix socket])
# 	 by mail.umich.edu (Cyrus v2.2.12) with LMTPA;
# 	 Fri, 04 Jan 2008 11:11:03 -0500
# Received: from carrie.mr.itd.umich.edu (carrie.mr.itd.umich.edu [141.211.93.152])
# 	by sleepers.mail.umich.edu () with ESMTP id m04GB3Vg011502;
# 	Fri, 4 Jan 2008 11:11:03 -0500
# Received: FROM paploo.uhi.ac.uk (app1.prod.collab.uhi.ac.uk [194.35.219.184])
# 	BY carrie.mr.itd.umich.edu ID 477E5A8D.B378F.24200 ;
# 	 4 Jan 2008 11:10:56 -0500
# Received: from paploo.uhi.ac.uk (localhost [127.0.0.1])
# 	by paploo.uhi.ac.uk (Postfix) with ESMTP id C7251BAD44;
# 	Fri,  4 Jan 2008 16:10:53 +0000 (GMT)
# Message-ID: <200801041609.m04G9EuX007197@nakamura.uits.iupui.edu>
# Mime-Version: 1.0
# Content-Transfer-Encoding: 7bit
# Received: from prod.collab.uhi.ac.uk ([194.35.219.182])
#           by paploo.uhi.ac.uk (JAMES SMTP Server 2.1.3) with SMTP ID 483
#           for <source@collab.sakaiproject.org>;
#           Fri, 4 Jan 2008 16:10:27 +0000 (GMT)
# Received: from nakamura.uits.iupui.edu (nakamura.uits.iupui.edu [134.68.220.122])
# 	by shmi.uhi.ac.uk (Postfix) with ESMTP id 2E7043DFA2
# 	for <source@collab.sakaiproject.org>; Fri,  4 Jan 2008 16:10:26 +0000 (GMT)
# Received: from nakamura.uits.iupui.edu (localhost [127.0.0.1])
# 	by nakamura.uits.iupui.edu (8.12.11.20060308/8.12.11) with ESMTP id m04G9Eqg007199
# 	for <source@collab.sakaiproject.org>; Fri, 4 Jan 2008 11:09:15 -0500
# Received: (from apache@localhost)
# 	by nakamura.uits.iupui.edu (8.12.11.20060308/8.12.11/Submit) id m04G9EuX007197
# 	for source@collab.sakaiproject.org; Fri, 4 Jan 2008 11:09:14 -0500
# Date: Fri, 4 Jan 2008 11:09:14 -0500
# X-Authentication-Warning: nakamura.uits.iupui.edu: apache set sender to zqian@umich.edu using -f
# To: source@collab.sakaiproject.org
# From: zqian@umich.edu
# Subject: [sakai] svn commit: r39760 - in site-manage/trunk/site-manage-tool/tool/src: java/org/sakaiproject/site/tool webapp/vm/sitesetup
# X-Content-Type-Outer-Envelope: text/plain; charset=UTF-8
# X-Content-Type-Message-Body: text/plain; charset=UTF-8
# Content-Type: text/plain; charset=UTF-8
# X-DSPAM-Result: Innocent
# X-DSPAM-Processed: Fri Jan  4 11:11:03 2008
# X-DSPAM-Confidence: 0.6959
# X-DSPAM-Probability: 0.0000
#
# Details: http://source.sakaiproject.org/viewsvn/?view=rev&rev=39760
#
# Author: zqian@umich.edu
# Date: 2008-01-04 11:09:12 -0500 (Fri, 04 Jan 2008)
# New Revision: 39760
#
# Modified:
# site-manage/trunk/site-manage-tool/tool/src/java/org/sakaiproject/site/tool/SiteAction.java
# site-manage/trunk/site-manage-tool/tool/src/webapp/vm/sitesetup/chef_site-siteInfo-list.vm
# Log:
# fix to SAK-10911: Refactor use of site.upd, site.upd.site.mbrship and site.upd.grp.mbrship permissions
#
# ----------------------
# This automatic notification message was sent by Sakai Collab (https://collab.sakaiproject.org/portal) from the Source site.
# You can modify how you receive notifications at My Workspace > Preferences.
#
#
#
# From gsilver@umich.edu Fri Jan  4 11:10:22 2008
# Return-Path: <postmaster@collab.sakaiproject.org>
# Received: from murder (mail.umich.edu [141.211.14.39])
# 	 by frankenstein.mail.umich.edu (Cyrus v2.3.8) with LMTPA;
# 	 Fri, 04 Jan 2008 11:10:22 -0500
# X-Sieve: CMU Sieve 2.3
# Received: from murder ([unix socket])
# 	 by mail.umich.edu (Cyrus v2.2.12) with LMTPA;
# 	 Fri, 04 Jan 2008 11:10:22 -0500
# Received: from holes.mr.itd.umich.edu (holes.mr.itd.umich.edu [141.211.14.79])
# 	by faithful.mail.umich.edu () with ESMTP id m04GAL9k010604;
# 	Fri, 4 Jan 2008 11:10:21 -0500
# Received: FROM paploo.uhi.ac.uk (app1.prod.collab.uhi.ac.uk [194.35.219.184])
# 	BY holes.mr.itd.umich.edu ID 477E5A67.34350.23015 ;
# 	 4 Jan 2008 11:10:18 -0500
# Received: from paploo.uhi.ac.uk (localhost [127.0.0.1])
# 	by paploo.uhi.ac.uk (Postfix) with ESMTP id 98D04BAD43;
# 	Fri,  4 Jan 2008 16:10:11 +0000 (GMT)
# Message-ID: <200801041608.m04G8d7w007184@nakamura.uits.iupui.edu>
# Mime-Version: 1.0
# Content-Transfer-Encoding: 7bit
# Received: from prod.collab.uhi.ac.uk ([194.35.219.182])
#           by paploo.uhi.ac.uk (JAMES SMTP Server 2.1.3) with SMTP ID 966
#           for <source@collab.sakaiproject.org>;
#           Fri, 4 Jan 2008 16:09:51 +0000 (GMT)
# Received: from nakamura.uits.iupui.edu (nakamura.uits.iupui.edu [134.68.220.122])
# 	by shmi.uhi.ac.uk (Postfix) with ESMTP id 9F89542DD0
# 	for <source@collab.sakaiproject.org>; Fri,  4 Jan 2008 16:09:50 +0000 (GMT)
# Received: from nakamura.uits.iupui.edu (localhost [127.0.0.1])
# 	by nakamura.uits.iupui.edu (8.12.11.20060308/8.12.11) with ESMTP id m04G8dXN007186
# 	for <source@collab.sakaiproject.org>; Fri, 4 Jan 2008 11:08:39 -0500
# Received: (from apache@localhost)
# 	by nakamura.uits.iupui.edu (8.12.11.20060308/8.12.11/Submit) id m04G8d7w007184
# 	for source@collab.sakaiproject.org; Fri, 4 Jan 2008 11:08:39 -0500
# Date: Fri, 4 Jan 2008 11:08:39 -0500
# X-Authentication-Warning: nakamura.uits.iupui.edu: apache set sender to gsilver@umich.edu using -f
# To: source@collab.sakaiproject.org
# From: gsilver@umich.edu
# Subject: [sakai] svn commit: r39759 - mailarchive/trunk/mailarchive-tool/tool/src/bundle
# X-Content-Type-Outer-Envelope: text/plain; charset=UTF-8
# X-Content-Type-Message-Body: text/plain; charset=UTF-8
# Content-Type: text/plain; charset=UTF-8
# X-DSPAM-Result: Innocent
# X-DSPAM-Processed: Fri Jan  4 11:10:22 2008
# X-DSPAM-Confidence: 0.7606
# X-DSPAM-Probability: 0.0000
#
# Details: http://source.sakaiproject.org/viewsvn/?view=rev&rev=39759
#
# Author: gsilver@umich.edu
# Date: 2008-01-04 11:08:38 -0500 (Fri, 04 Jan 2008)
# New Revision: 39759
#
# Modified:
# mailarchive/trunk/mailarchive-tool/tool/src/bundle/email.properties
# Log:
# SAK-12592
# http://bugs.sakaiproject.org/jira/browse/SAK-12592
# - left moot (unused) entries commented for now
#
# ----------------------
# This automatic notification message was sent by Sakai Collab (https://collab.sakaiproject.org/portal) from the Source site.
# You can modify how you receive notifications at My Workspace > Preferences.
#
#
#
# From wagnermr@iupui.edu Fri Jan  4 10:38:42 2008
# Return-Path: <postmaster@collab.sakaiproject.org>
# Received: from murder (mail.umich.edu [141.211.14.90])
# 	 by frankenstein.mail.umich.edu (Cyrus v2.3.8) with LMTPA;
# 	 Fri, 04 Jan 2008 10:38:42 -0500
# X-Sieve: CMU Sieve 2.3
# Received: from murder ([unix socket])
# 	 by mail.umich.edu (Cyrus v2.2.12) with LMTPA;
# 	 Fri, 04 Jan 2008 10:38:42 -0500
# Received: from shining.mr.itd.umich.edu (shining.mr.itd.umich.edu [141.211.93.153])
# 	by flawless.mail.umich.edu () with ESMTP id m04Fcfjm012313;
# 	Fri, 4 Jan 2008 10:38:41 -0500
# Received: FROM paploo.uhi.ac.uk (app1.prod.collab.uhi.ac.uk [194.35.219.184])
# 	BY shining.mr.itd.umich.edu ID 477E52FA.E6C6E.24093 ;
# 	 4 Jan 2008 10:38:37 -0500
# Received: from paploo.uhi.ac.uk (localhost [127.0.0.1])
# 	by paploo.uhi.ac.uk (Postfix) with ESMTP id 6A39594CD2;
# 	Fri,  4 Jan 2008 15:37:36 +0000 (GMT)
# Message-ID: <200801041537.m04Fb6Ci007092@nakamura.uits.iupui.edu>
# Mime-Version: 1.0
# Content-Transfer-Encoding: 7bit
# Received: from prod.collab.uhi.ac.uk ([194.35.219.182])
#           by paploo.uhi.ac.uk (JAMES SMTP Server 2.1.3) with SMTP ID 690
#           for <source@collab.sakaiproject.org>;
#           Fri, 4 Jan 2008 15:37:21 +0000 (GMT)
# Received: from nakamura.uits.iupui.edu (nakamura.uits.iupui.edu [134.68.220.122])
# 	by shmi.uhi.ac.uk (Postfix) with ESMTP id CEFA037ACE
# 	for <source@collab.sakaiproject.org>; Fri,  4 Jan 2008 15:38:17 +0000 (GMT)
# Received: from nakamura.uits.iupui.edu (localhost [127.0.0.1])
# 	by nakamura.uits.iupui.edu (8.12.11.20060308/8.12.11) with ESMTP id m04Fb6nh007094
# 	for <source@collab.sakaiproject.org>; Fri, 4 Jan 2008 10:37:06 -0500
# Received: (from apache@localhost)
# 	by nakamura.uits.iupui.edu (8.12.11.20060308/8.12.11/Submit) id m04Fb6Ci007092
# 	for source@collab.sakaiproject.org; Fri, 4 Jan 2008 10:37:06 -0500
# Date: Fri, 4 Jan 2008 10:37:06 -0500
# X-Authentication-Warning: nakamura.uits.iupui.edu: apache set sender to wagnermr@iupui.edu using -f
# To: source@collab.sakaiproject.org
# From: wagnermr@iupui.edu
# Subject: [sakai] svn commit: r39758 - in gradebook/trunk: app/business/src/java/org/sakaiproject/tool/gradebook/business/impl service/api/src/java/org/sakaiproject/service/gradebook/shared service/impl/src/java/org/sakaiproject/component/gradebook
# X-Content-Type-Outer-Envelope: text/plain; charset=UTF-8
# X-Content-Type-Message-Body: text/plain; charset=UTF-8
# Content-Type: text/plain; charset=UTF-8
# X-DSPAM-Result: Innocent
# X-DSPAM-Processed: Fri Jan  4 10:38:42 2008
# X-DSPAM-Confidence: 0.7559
# X-DSPAM-Probability: 0.0000
#
# Details: http://source.sakaiproject.org/viewsvn/?view=rev&rev=39758
#
# Author: wagnermr@iupui.edu
# Date: 2008-01-04 10:37:04 -0500 (Fri, 04 Jan 2008)
# New Revision: 39758
#
# Modified:
# gradebook/trunk/app/business/src/java/org/sakaiproject/tool/gradebook/business/impl/GradebookManagerHibernateImpl.java
# gradebook/trunk/service/api/src/java/org/sakaiproject/service/gradebook/shared/GradebookService.java
# gradebook/trunk/service/impl/src/java/org/sakaiproject/component/gradebook/GradebookServiceHibernateImpl.java
# Log:
# SAK-12175
# http://bugs.sakaiproject.org/jira/browse/SAK-12175
# Create methods required for gb integration with the Assignment2 tool
# getGradeDefinitionForStudentForItem
#
# ----------------------
# This automatic notification message was sent by Sakai Collab (https://collab.sakaiproject.org/portal) from the Source site.
# You can modify how you receive notifications at My Workspace > Preferences.
#
#
#
# From zqian@umich.edu Fri Jan  4 10:17:43 2008
# Return-Path: <postmaster@collab.sakaiproject.org>
# Received: from murder (mail.umich.edu [141.211.14.97])
# 	 by frankenstein.mail.umich.edu (Cyrus v2.3.8) with LMTPA;
# 	 Fri, 04 Jan 2008 10:17:43 -0500
# X-Sieve: CMU Sieve 2.3
# Received: from murder ([unix socket])
# 	 by mail.umich.edu (Cyrus v2.2.12) with LMTPA;
# 	 Fri, 04 Jan 2008 10:17:42 -0500
# Received: from creepshow.mr.itd.umich.edu (creepshow.mr.itd.umich.edu [141.211.14.84])
# 	by sleepers.mail.umich.edu () with ESMTP id m04FHgfs011536;
# 	Fri, 4 Jan 2008 10:17:42 -0500
# Received: FROM paploo.uhi.ac.uk (app1.prod.collab.uhi.ac.uk [194.35.219.184])
# 	BY creepshow.mr.itd.umich.edu ID 477E4E0F.CCA4B.926 ;
# 	 4 Jan 2008 10:17:38 -0500
# Received: from paploo.uhi.ac.uk (localhost [127.0.0.1])
# 	by paploo.uhi.ac.uk (Postfix) with ESMTP id BD02DBAC64;
# 	Fri,  4 Jan 2008 15:17:34 +0000 (GMT)
# Message-ID: <200801041515.m04FFv42007050@nakamura.uits.iupui.edu>
# Mime-Version: 1.0
# Content-Transfer-Encoding: 7bit
# Received: from prod.collab.uhi.ac.uk ([194.35.219.182])
#           by paploo.uhi.ac.uk (JAMES SMTP Server 2.1.3) with SMTP ID 25
#           for <source@collab.sakaiproject.org>;
#           Fri, 4 Jan 2008 15:17:11 +0000 (GMT)
# Received: from nakamura.uits.iupui.edu (nakamura.uits.iupui.edu [134.68.220.122])
# 	by shmi.uhi.ac.uk (Postfix) with ESMTP id 5B396236B9
# 	for <source@collab.sakaiproject.org>; Fri,  4 Jan 2008 15:17:08 +0000 (GMT)
# Received: from nakamura.uits.iupui.edu (localhost [127.0.0.1])
# 	by nakamura.uits.iupui.edu (8.12.11.20060308/8.12.11) with ESMTP id m04FFv85007052
# 	for <source@collab.sakaiproject.org>; Fri, 4 Jan 2008 10:15:57 -0500
# Received: (from apache@localhost)
# 	by nakamura.uits.iupui.edu (8.12.11.20060308/8.12.11/Submit) id m04FFv42007050
# 	for source@collab.sakaiproject.org; Fri, 4 Jan 2008 10:15:57 -0500
# Date: Fri, 4 Jan 2008 10:15:57 -0500
# X-Authentication-Warning: nakamura.uits.iupui.edu: apache set sender to zqian@umich.edu using -f
# To: source@collab.sakaiproject.org
# From: zqian@umich.edu
# Subject: [sakai] svn commit: r39757 - in assignment/trunk: assignment-impl/impl/src/java/org/sakaiproject/assignment/impl assignment-tool/tool/src/webapp/vm/assignment
# X-Content-Type-Outer-Envelope: text/plain; charset=UTF-8
# X-Content-Type-Message-Body: text/plain; charset=UTF-8
# Content-Type: text/plain; charset=UTF-8
# X-DSPAM-Result: Innocent
# X-DSPAM-Processed: Fri Jan  4 10:17:42 2008
# X-DSPAM-Confidence: 0.7605
# X-DSPAM-Probability: 0.0000
#
# Details: http://source.sakaiproject.org/viewsvn/?view=rev&rev=39757
#
# Author: zqian@umich.edu
# Date: 2008-01-04 10:15:54 -0500 (Fri, 04 Jan 2008)
# New Revision: 39757
#
# Modified:
# assignment/trunk/assignment-impl/impl/src/java/org/sakaiproject/assignment/impl/BaseAssignmentService.java
# assignment/trunk/assignment-tool/tool/src/webapp/vm/assignment/chef_assignments_instructor_list_submissions.vm
# Log:
# fix to SAK-12604:Don't show groups/sections filter if the site doesn't have any
#
# ----------------------
# This automatic notification message was sent by Sakai Collab (https://collab.sakaiproject.org/portal) from the Source site.
# You can modify how you receive notifications at My Workspace > Preferences.
#
#
#
# From antranig@caret.cam.ac.uk Fri Jan  4 10:04:14 2008
# Return-Path: <postmaster@collab.sakaiproject.org>
# Received: from murder (mail.umich.edu [141.211.14.25])
# 	 by frankenstein.mail.umich.edu (Cyrus v2.3.8) with LMTPA;
# 	 Fri, 04 Jan 2008 10:04:14 -0500
# X-Sieve: CMU Sieve 2.3
# Received: from murder ([unix socket])
# 	 by mail.umich.edu (Cyrus v2.2.12) with LMTPA;
# 	 Fri, 04 Jan 2008 10:04:14 -0500
# Received: from holes.mr.itd.umich.edu (holes.mr.itd.umich.edu [141.211.14.79])
# 	by panther.mail.umich.edu () with ESMTP id m04F4Dci015108;
# 	Fri, 4 Jan 2008 10:04:13 -0500
# Received: FROM paploo.uhi.ac.uk (app1.prod.collab.uhi.ac.uk [194.35.219.184])
# 	BY holes.mr.itd.umich.edu ID 477E4AE3.D7AF.31669 ;
# 	 4 Jan 2008 10:04:05 -0500
# Received: from paploo.uhi.ac.uk (localhost [127.0.0.1])
# 	by paploo.uhi.ac.uk (Postfix) with ESMTP id 933E3BAC17;
# 	Fri,  4 Jan 2008 15:04:00 +0000 (GMT)
# ...
# 	 by frankenstein.mail.umich.edu (Cyrus v2.3.8) with LMTPA;
# 	 Thu, 03 Jan 2008 17:18:23 -0500
# X-Sieve: CMU Sieve 2.3
# Received: from murder ([unix socket])
# 	 by mail.umich.edu (Cyrus v2.2.12) with LMTPA;
# 	 Thu, 03 Jan 2008 17:18:23 -0500
# Received: from salemslot.mr.itd.umich.edu (salemslot.mr.itd.umich.edu [141.211.14.58])
# 	by jacknife.mail.umich.edu () with ESMTP id m03MIMXY027729;
# 	Thu, 3 Jan 2008 17:18:22 -0500
# Received: FROM paploo.uhi.ac.uk (app1.prod.collab.uhi.ac.uk [194.35.219.184])
# 	BY salemslot.mr.itd.umich.edu ID 477D5F23.797F6.16348 ;
# 	 3 Jan 2008 17:18:14 -0500
# Received: from paploo.uhi.ac.uk (localhost [127.0.0.1])
# 	by paploo.uhi.ac.uk (Postfix) with ESMTP id EF439B98CE;
# 	Thu,  3 Jan 2008 22:18:19 +0000 (GMT)
# Message-ID: <200801032216.m03MGhDa005292@nakamura.uits.iupui.edu>
# Mime-Version: 1.0
# Content-Transfer-Encoding: 7bit
# Received: from prod.collab.uhi.ac.uk ([194.35.219.182])
#           by paploo.uhi.ac.uk (JAMES SMTP Server 2.1.3) with SMTP ID 236
#           for <source@collab.sakaiproject.org>;
#           Thu, 3 Jan 2008 22:18:04 +0000 (GMT)
# Received: from nakamura.uits.iupui.edu (nakamura.uits.iupui.edu [134.68.220.122])
# 	by shmi.uhi.ac.uk (Postfix) with ESMTP id 905D53C2FD
# 	for <source@collab.sakaiproject.org>; Thu,  3 Jan 2008 22:17:52 +0000 (GMT)
# Received: from nakamura.uits.iupui.edu (localhost [127.0.0.1])
# 	by nakamura.uits.iupui.edu (8.12.11.20060308/8.12.11) with ESMTP id m03MGhrs005294
# 	for <source@collab.sakaiproject.org>; Thu, 3 Jan 2008 17:16:43 -0500
# Received: (from apache@localhost)
# 	by nakamura.uits.iupui.edu (8.12.11.20060308/8.12.11/Submit) id m03MGhDa005292
# 	for source@collab.sakaiproject.org; Thu, 3 Jan 2008 17:16:43 -0500
# Date: Thu, 3 Jan 2008 17:16:43 -0500
# X-Authentication-Warning: nakamura.uits.iupui.edu: apache set sender to louis@media.berkeley.edu using -f
# To: source@collab.sakaiproject.org
# From: louis@media.berkeley.edu
# Subject: [sakai] svn commit: r39746 - in bspace/site-manage/sakai_2-4-x/site-manage-tool/tool/src: bundle webapp/vm/sitesetup
# X-Content-Type-Outer-Envelope: text/plain; charset=UTF-8
# X-Content-Type-Message-Body: text/plain; charset=UTF-8
# Content-Type: text/plain; charset=UTF-8
# X-DSPAM-Result: Innocent
# X-DSPAM-Processed: Thu Jan  3 17:18:23 2008
# X-DSPAM-Confidence: 0.6959
# X-DSPAM-Probability: 0.0000
#
# Details: http://source.sakaiproject.org/viewsvn/?view=rev&rev=39746
#
# Author: louis@media.berkeley.edu
# Date: 2008-01-03 17:16:39 -0500 (Thu, 03 Jan 2008)
# New Revision: 39746
#
# Modified:
# bspace/site-manage/sakai_2-4-x/site-manage-tool/tool/src/bundle/sitesetupgeneric.properties
# bspace/site-manage/sakai_2-4-x/site-manage-tool/tool/src/webapp/vm/sitesetup/chef_site-siteInfo-duplicate.vm
# Log:
# BSP-1421 Add text to clarify "Duplicate Site" option in Site Info
#
# ----------------------
# This automatic notification message was sent by Sakai Collab (https://collab.sakaiproject.org/portal) from the Source site.
# You can modify how you receive notifications at My Workspace > Preferences.
#
#
#
# From ray@media.berkeley.edu Thu Jan  3 17:07:00 2008
# Return-Path: <postmaster@collab.sakaiproject.org>
# Received: from murder (mail.umich.edu [141.211.14.39])
# 	 by frankenstein.mail.umich.edu (Cyrus v2.3.8) with LMTPA;
# 	 Thu, 03 Jan 2008 17:07:00 -0500
# X-Sieve: CMU Sieve 2.3
# Received: from murder ([unix socket])
# 	 by mail.umich.edu (Cyrus v2.2.12) with LMTPA;
# 	 Thu, 03 Jan 2008 17:07:00 -0500
# Received: from anniehall.mr.itd.umich.edu (anniehall.mr.itd.umich.edu [141.211.93.141])
# 	by faithful.mail.umich.edu () with ESMTP id m03M6xaq014868;
# 	Thu, 3 Jan 2008 17:06:59 -0500
# Received: FROM paploo.uhi.ac.uk (app1.prod.collab.uhi.ac.uk [194.35.219.184])
# 	BY anniehall.mr.itd.umich.edu ID 477D5C7A.4FE1F.22211 ;
# 	 3 Jan 2008 17:06:53 -0500
# Received: from paploo.uhi.ac.uk (localhost [127.0.0.1])
# 	by paploo.uhi.ac.uk (Postfix) with ESMTP id 0BC8D7225E;
# 	Thu,  3 Jan 2008 22:06:57 +0000 (GMT)
# Message-ID: <200801032205.m03M5Ea7005273@nakamura.uits.iupui.edu>
# Mime-Version: 1.0
# Content-Transfer-Encoding: 7bit
# Received: from prod.collab.uhi.ac.uk ([194.35.219.182])
#           by paploo.uhi.ac.uk (JAMES SMTP Server 2.1.3) with SMTP ID 554
#           for <source@collab.sakaiproject.org>;
#           Thu, 3 Jan 2008 22:06:34 +0000 (GMT)
# Received: from nakamura.uits.iupui.edu (nakamura.uits.iupui.edu [134.68.220.122])
# 	by shmi.uhi.ac.uk (Postfix) with ESMTP id 2AB513C2FD
# 	for <source@collab.sakaiproject.org>; Thu,  3 Jan 2008 22:06:23 +0000 (GMT)
# Received: from nakamura.uits.iupui.edu (localhost [127.0.0.1])
# 	by nakamura.uits.iupui.edu (8.12.11.20060308/8.12.11) with ESMTP id m03M5EQa005275
# 	for <source@collab.sakaiproject.org>; Thu, 3 Jan 2008 17:05:14 -0500
# Received: (from apache@localhost)
# 	by nakamura.uits.iupui.edu (8.12.11.20060308/8.12.11/Submit) id m03M5Ea7005273
# 	for source@collab.sakaiproject.org; Thu, 3 Jan 2008 17:05:14 -0500
# Date: Thu, 3 Jan 2008 17:05:14 -0500
# X-Authentication-Warning: nakamura.uits.iupui.edu: apache set sender to ray@media.berkeley.edu using -f
# To: source@collab.sakaiproject.org
# From: ray@media.berkeley.edu
# Subject: [sakai] svn commit: r39745 - providers/trunk/cm/cm-authz-provider/src/java/org/sakaiproject/coursemanagement/impl/provider
# X-Content-Type-Outer-Envelope: text/plain; charset=UTF-8
# X-Content-Type-Message-Body: text/plain; charset=UTF-8
# Content-Type: text/plain; charset=UTF-8
# X-DSPAM-Result: Innocent
# X-DSPAM-Processed: Thu Jan  3 17:07:00 2008
# X-DSPAM-Confidence: 0.7556
# X-DSPAM-Probability: 0.0000
#
# Details: http://source.sakaiproject.org/viewsvn/?view=rev&rev=39745
#
# Author: ray@media.berkeley.edu
# Date: 2008-01-03 17:05:11 -0500 (Thu, 03 Jan 2008)
# New Revision: 39745
#
# Modified:
# providers/trunk/cm/cm-authz-provider/src/java/org/sakaiproject/coursemanagement/impl/provider/CourseManagementGroupProvider.java
# Log:
# SAK-12602 Fix logic when a user has multiple roles in a section
#
# ----------------------
# This automatic notification message was sent by Sakai Collab (https://collab.sakaiproject.org/portal) from the Source site.
# You can modify how you receive notifications at My Workspace > Preferences.
#
#
#
# From cwen@iupui.edu Thu Jan  3 16:34:40 2008
# Return-Path: <postmaster@collab.sakaiproject.org>
# Received: from murder (mail.umich.edu [141.211.14.34])
# 	 by frankenstein.mail.umich.edu (Cyrus v2.3.8) with LMTPA;
# 	 Thu, 03 Jan 2008 16:34:40 -0500
# X-Sieve: CMU Sieve 2.3
# Received: from murder ([unix socket])
# 	 by mail.umich.edu (Cyrus v2.2.12) with LMTPA;
# 	 Thu, 03 Jan 2008 16:34:40 -0500
# Received: from icestorm.mr.itd.umich.edu (icestorm.mr.itd.umich.edu [141.211.93.149])
# 	by chaos.mail.umich.edu () with ESMTP id m03LYdY1029538;
# 	Thu, 3 Jan 2008 16:34:39 -0500
# Received: FROM paploo.uhi.ac.uk (app1.prod.collab.uhi.ac.uk [194.35.219.184])
# 	BY icestorm.mr.itd.umich.edu ID 477D54EA.13F34.26602 ;
# 	 3 Jan 2008 16:34:36 -0500
# Received: from paploo.uhi.ac.uk (localhost [127.0.0.1])
# 	by paploo.uhi.ac.uk (Postfix) with ESMTP id CC710ADC79;
# 	Thu,  3 Jan 2008 21:34:29 +0000 (GMT)
# Message-ID: <200801032133.m03LX3gG005191@nakamura.uits.iupui.edu>
# Mime-Version: 1.0
# Content-Transfer-Encoding: 7bit
# Received: from prod.collab.uhi.ac.uk ([194.35.219.182])
#           by paploo.uhi.ac.uk (JAMES SMTP Server 2.1.3) with SMTP ID 611
#           for <source@collab.sakaiproject.org>;
#           Thu, 3 Jan 2008 21:34:08 +0000 (GMT)
# Received: from nakamura.uits.iupui.edu (nakamura.uits.iupui.edu [134.68.220.122])
# 	by shmi.uhi.ac.uk (Postfix) with ESMTP id 43C4242B55
# 	for <source@collab.sakaiproject.org>; Thu,  3 Jan 2008 21:34:12 +0000 (GMT)
# Received: from nakamura.uits.iupui.edu (localhost [127.0.0.1])
# 	by nakamura.uits.iupui.edu (8.12.11.20060308/8.12.11) with ESMTP id m03LX3Vb005193
# 	for <source@collab.sakaiproject.org>; Thu, 3 Jan 2008 16:33:03 -0500
# Received: (from apache@localhost)
# 	by nakamura.uits.iupui.edu (8.12.11.20060308/8.12.11/Submit) id m03LX3gG005191
# 	for source@collab.sakaiproject.org; Thu, 3 Jan 2008 16:33:03 -0500
# Date: Thu, 3 Jan 2008 16:33:03 -0500
# X-Authentication-Warning: nakamura.uits.iupui.edu: apache set sender to cwen@iupui.edu using -f
# To: source@collab.sakaiproject.org
# From: cwen@iupui.edu
# Subject: [sakai] svn commit: r39744 - oncourse/branches/oncourse_OPC_122007
# X-Content-Type-Outer-Envelope: text/plain; charset=UTF-8
# X-Content-Type-Message-Body: text/plain; charset=UTF-8
# Content-Type: text/plain; charset=UTF-8
# X-DSPAM-Result: Innocent
# X-DSPAM-Processed: Thu Jan  3 16:34:40 2008
# X-DSPAM-Confidence: 0.9846
# X-DSPAM-Probability: 0.0000
#
# Details: http://source.sakaiproject.org/viewsvn/?view=rev&rev=39744
#
# Author: cwen@iupui.edu
# Date: 2008-01-03 16:33:02 -0500 (Thu, 03 Jan 2008)
# New Revision: 39744
#
# Modified:
# oncourse/branches/oncourse_OPC_122007/
# oncourse/branches/oncourse_OPC_122007/.externals
# Log:
# update external for GB.
#
# ----------------------
# This automatic notification message was sent by Sakai Collab (https://collab.sakaiproject.org/portal) from the Source site.
# You can modify how you receive notifications at My Workspace > Preferences.
#
#
#
# From cwen@iupui.edu Thu Jan  3 16:29:07 2008
# Return-Path: <postmaster@collab.sakaiproject.org>
# Received: from murder (mail.umich.edu [141.211.14.46])
# 	 by frankenstein.mail.umich.edu (Cyrus v2.3.8) with LMTPA;
# 	 Thu, 03 Jan 2008 16:29:07 -0500
# X-Sieve: CMU Sieve 2.3
# Received: from murder ([unix socket])
# 	 by mail.umich.edu (Cyrus v2.2.12) with LMTPA;
# 	 Thu, 03 Jan 2008 16:29:07 -0500
# Received: from galaxyquest.mr.itd.umich.edu (galaxyquest.mr.itd.umich.edu [141.211.93.145])
# 	by fan.mail.umich.edu () with ESMTP id m03LT6uw027749;
# 	Thu, 3 Jan 2008 16:29:06 -0500
# Received: FROM paploo.uhi.ac.uk (app1.prod.collab.uhi.ac.uk [194.35.219.184])
# 	BY galaxyquest.mr.itd.umich.edu ID 477D5397.E161D.20326 ;
# 	 3 Jan 2008 16:28:58 -0500
# Received: from paploo.uhi.ac.uk (localhost [127.0.0.1])
# 	by paploo.uhi.ac.uk (Postfix) with ESMTP id DEC65ADC79;
# 	Thu,  3 Jan 2008 21:28:52 +0000 (GMT)
# Message-ID: <200801032127.m03LRUqH005177@nakamura.uits.iupui.edu>
# Mime-Version: 1.0
# Content-Transfer-Encoding: 7bit
# Received: from prod.collab.uhi.ac.uk ([194.35.219.182])
#           by paploo.uhi.ac.uk (JAMES SMTP Server 2.1.3) with SMTP ID 917
#           for <source@collab.sakaiproject.org>;
#           Thu, 3 Jan 2008 21:28:39 +0000 (GMT)
# Received: from nakamura.uits.iupui.edu (nakamura.uits.iupui.edu [134.68.220.122])
# 	by shmi.uhi.ac.uk (Postfix) with ESMTP id 1FBB042B30
# 	for <source@collab.sakaiproject.org>; Thu,  3 Jan 2008 21:28:38 +0000 (GMT)
# Received: from nakamura.uits.iupui.edu (localhost [127.0.0.1])
# 	by nakamura.uits.iupui.edu (8.12.11.20060308/8.12.11) with ESMTP id m03LRUk4005179
# 	for <source@collab.sakaiproject.org>; Thu, 3 Jan 2008 16:27:30 -0500
# Received: (from apache@localhost)
# 	by nakamura.uits.iupui.edu (8.12.11.20060308/8.12.11/Submit) id m03LRUqH005177
# 	for source@collab.sakaiproject.org; Thu, 3 Jan 2008 16:27:30 -0500
# Date: Thu, 3 Jan 2008 16:27:30 -0500
# X-Authentication-Warning: nakamura.uits.iupui.edu: apache set sender to cwen@iupui.edu using -f
# To: source@collab.sakaiproject.org
# From: cwen@iupui.edu
# Subject: [sakai] svn commit: r39743 - gradebook/branches/oncourse_2-4-2/app/ui/src/java/org/sakaiproject/tool/gradebook/ui
# X-Content-Type-Outer-Envelope: text/plain; charset=UTF-8
# X-Content-Type-Message-Body: text/plain; charset=UTF-8
# Content-Type: text/plain; charset=UTF-8
# X-DSPAM-Result: Innocent
# X-DSPAM-Processed: Thu Jan  3 16:29:07 2008
# X-DSPAM-Confidence: 0.8509
# X-DSPAM-Probability: 0.0000
#
# Details: http://source.sakaiproject.org/viewsvn/?view=rev&rev=39743
#
# Author: cwen@iupui.edu
# Date: 2008-01-03 16:27:29 -0500 (Thu, 03 Jan 2008)
# New Revision: 39743
#
# Modified:
# gradebook/branches/oncourse_2-4-2/app/ui/src/java/org/sakaiproject/tool/gradebook/ui/RosterBean.java
# Log:
# svn merge -c 39403 https://source.sakaiproject.org/svn/gradebook/trunk
# U    app/ui/src/java/org/sakaiproject/tool/gradebook/ui/RosterBean.java
#
# svn log -r 39403 https://source.sakaiproject.org/svn/gradebook/trunk
# ------------------------------------------------------------------------
# r39403 | wagnermr@iupui.edu | 2007-12-17 17:11:08 -0500 (Mon, 17 Dec 2007) | 3 lines
#
# SAK-12504
# http://jira.sakaiproject.org/jira/browse/SAK-12504
# Viewing "All Grades" page as a TA with grader permissions causes stack trace
# ------------------------------------------------------------------------
#
#
# ----------------------
# This automatic notification message was sent by Sakai Collab (https://collab.sakaiproject.org/portal) from the Source site.
# You can modify how you receive notifications at My Workspace > Preferences.
#
#
#
# From cwen@iupui.edu Thu Jan  3 16:23:48 2008
# Return-Path: <postmaster@collab.sakaiproject.org>
# Received: from murder (mail.umich.edu [141.211.14.91])
# 	 by frankenstein.mail.umich.edu (Cyrus v2.3.8) with LMTPA;
# 	 Thu, 03 Jan 2008 16:23:48 -0500
# X-Sieve: CMU Sieve 2.3
# Received: from murder ([unix socket])
# 	 by mail.umich.edu (Cyrus v2.2.12) with LMTPA;
# 	 Thu, 03 Jan 2008 16:23:48 -0500
# Received: from salemslot.mr.itd.umich.edu (salemslot.mr.itd.umich.edu [141.211.14.58])
# 	by jacknife.mail.umich.edu () with ESMTP id m03LNlf0002115;
# 	Thu, 3 Jan 2008 16:23:47 -0500
# Received: FROM paploo.uhi.ac.uk (app1.prod.collab.uhi.ac.uk [194.35.219.184])
# 	BY salemslot.mr.itd.umich.edu ID 477D525E.1448.30389 ;
# 	 3 Jan 2008 16:23:44 -0500
# Received: from paploo.uhi.ac.uk (localhost [127.0.0.1])
# 	by paploo.uhi.ac.uk (Postfix) with ESMTP id 9D005B9D06;
# 	Thu,  3 Jan 2008 21:23:38 +0000 (GMT)
# Message-ID: <200801032122.m03LMFo4005148@nakamura.uits.iupui.edu>
# Mime-Version: 1.0
# Content-Transfer-Encoding: 7bit
# Received: from prod.collab.uhi.ac.uk ([194.35.219.182])
#           by paploo.uhi.ac.uk (JAMES SMTP Server 2.1.3) with SMTP ID 6
#           for <source@collab.sakaiproject.org>;
#           Thu, 3 Jan 2008 21:23:24 +0000 (GMT)
# Received: from nakamura.uits.iupui.edu (nakamura.uits.iupui.edu [134.68.220.122])
# 	by shmi.uhi.ac.uk (Postfix) with ESMTP id 3535542B69
# 	for <source@collab.sakaiproject.org>; Thu,  3 Jan 2008 21:23:24 +0000 (GMT)
# Received: from nakamura.uits.iupui.edu (localhost [127.0.0.1])
# 	by nakamura.uits.iupui.edu (8.12.11.20060308/8.12.11) with ESMTP id m03LMFtT005150
# 	for <source@collab.sakaiproject.org>; Thu, 3 Jan 2008 16:22:15 -0500
# Received: (from apache@localhost)
# 	by nakamura.uits.iupui.edu (8.12.11.20060308/8.12.11/Submit) id m03LMFo4005148
# 	for source@collab.sakaiproject.org; Thu, 3 Jan 2008 16:22:15 -0500
# Date: Thu, 3 Jan 2008 16:22:15 -0500
# X-Authentication-Warning: nakamura.uits.iupui.edu: apache set sender to cwen@iupui.edu using -f
# To: source@collab.sakaiproject.org
# From: cwen@iupui.edu
# Subject: [sakai] svn commit: r39742 - gradebook/branches/oncourse_2-4-2/app/ui/src/java/org/sakaiproject/tool/gradebook/ui
# X-Content-Type-Outer-Envelope: text/plain; charset=UTF-8
# X-Content-Type-Message-Body: text/plain; charset=UTF-8
# Content-Type: text/plain; charset=UTF-8
# X-DSPAM-Result: Innocent
# X-DSPAM-Processed: Thu Jan  3 16:23:48 2008
# X-DSPAM-Confidence: 0.9907
# X-DSPAM-Probability: 0.0000
#
# Details: http://source.sakaiproject.org/viewsvn/?view=rev&rev=39742
#
# Author: cwen@iupui.edu
# Date: 2008-01-03 16:22:14 -0500 (Thu, 03 Jan 2008)
# New Revision: 39742
#
# Modified:
# gradebook/branches/oncourse_2-4-2/app/ui/src/java/org/sakaiproject/tool/gradebook/ui/RosterBean.java
# Log:
# svn merge -c 35014 https://source.sakaiproject.org/svn/gradebook/trunk
# U    app/ui/src/java/org/sakaiproject/tool/gradebook/ui/RosterBean.java
#
# svn log -r 35014 https://source.sakaiproject.org/svn/gradebook/trunk
# ------------------------------------------------------------------------
# r35014 | wagnermr@iupui.edu | 2007-09-12 16:17:59 -0400 (Wed, 12 Sep 2007) | 3 lines
#
# SAK-11458
# http://bugs.sakaiproject.org/jira/browse/SAK-11458
# Course grade does not appear on "All Grades" page if no categories in gb
# ------------------------------------------------------------------------
#
#
# ----------------------
# This automatic notification message was sent by Sakai Collab (https://collab.sakaiproject.org/portal) from the Source site.
# You can modify how you receive notifications at My Workspace > Preferences.

# %%
fhandle = open('mbox-short.txt')
for line in fhandle:
    line = line.rstrip()
    line = line.upper()
    print(line)
# Out:
# FROM STEPHEN.MARQUARD@UCT.AC.ZA SAT JAN  5 09:14:16 2008
# RETURN-PATH: <POSTMASTER@COLLAB.SAKAIPROJECT.ORG>
# RECEIVED: FROM MURDER (MAIL.UMICH.EDU [141.211.14.90])
# 	 BY FRANKENSTEIN.MAIL.UMICH.EDU (CYRUS V2.3.8) WITH LMTPA;
# 	 SAT, 05 JAN 2008 09:14:16 -0500
# X-SIEVE: CMU SIEVE 2.3
# RECEIVED: FROM MURDER ([UNIX SOCKET])
# 	 BY MAIL.UMICH.EDU (CYRUS V2.2.12) WITH LMTPA;
# 	 SAT, 05 JAN 2008 09:14:16 -0500
# RECEIVED: FROM HOLES.MR.ITD.UMICH.EDU (HOLES.MR.ITD.UMICH.EDU [141.211.14.79])
# 	BY FLAWLESS.MAIL.UMICH.EDU () WITH ESMTP ID M05EEFR1013674;
# 	SAT, 5 JAN 2008 09:14:15 -0500
# RECEIVED: FROM PAPLOO.UHI.AC.UK (APP1.PROD.COLLAB.UHI.AC.UK [194.35.219.184])
# 	BY HOLES.MR.ITD.UMICH.EDU ID 477F90B0.2DB2F.12494 ;
# 	 5 JAN 2008 09:14:10 -0500
# RECEIVED: FROM PAPLOO.UHI.AC.UK (LOCALHOST [127.0.0.1])
# 	BY PAPLOO.UHI.AC.UK (POSTFIX) WITH ESMTP ID 5F919BC2F2;
# 	SAT,  5 JAN 2008 14:10:05 +0000 (GMT)
# MESSAGE-ID: <200801051412.M05ECIAH010327@NAKAMURA.UITS.IUPUI.EDU>
# MIME-VERSION: 1.0
# CONTENT-TRANSFER-ENCODING: 7BIT
# RECEIVED: FROM PROD.COLLAB.UHI.AC.UK ([194.35.219.182])
#           BY PAPLOO.UHI.AC.UK (JAMES SMTP SERVER 2.1.3) WITH SMTP ID 899
#           FOR <SOURCE@COLLAB.SAKAIPROJECT.ORG>;
#           SAT, 5 JAN 2008 14:09:50 +0000 (GMT)
# RECEIVED: FROM NAKAMURA.UITS.IUPUI.EDU (NAKAMURA.UITS.IUPUI.EDU [134.68.220.122])
# 	BY SHMI.UHI.AC.UK (POSTFIX) WITH ESMTP ID A215243002
# 	FOR <SOURCE@COLLAB.SAKAIPROJECT.ORG>; SAT,  5 JAN 2008 14:13:33 +0000 (GMT)
# RECEIVED: FROM NAKAMURA.UITS.IUPUI.EDU (LOCALHOST [127.0.0.1])
# 	BY NAKAMURA.UITS.IUPUI.EDU (8.12.11.20060308/8.12.11) WITH ESMTP ID M05ECJVP010329
# 	FOR <SOURCE@COLLAB.SAKAIPROJECT.ORG>; SAT, 5 JAN 2008 09:12:19 -0500
# RECEIVED: (FROM APACHE@LOCALHOST)
# 	BY NAKAMURA.UITS.IUPUI.EDU (8.12.11.20060308/8.12.11/SUBMIT) ID M05ECIAH010327
# 	FOR SOURCE@COLLAB.SAKAIPROJECT.ORG; SAT, 5 JAN 2008 09:12:18 -0500
# DATE: SAT, 5 JAN 2008 09:12:18 -0500
# X-AUTHENTICATION-WARNING: NAKAMURA.UITS.IUPUI.EDU: APACHE SET SENDER TO STEPHEN.MARQUARD@UCT.AC.ZA USING -F
# TO: SOURCE@COLLAB.SAKAIPROJECT.ORG
# FROM: STEPHEN.MARQUARD@UCT.AC.ZA
# SUBJECT: [SAKAI] SVN COMMIT: R39772 - CONTENT/BRANCHES/SAKAI_2-5-X/CONTENT-IMPL/IMPL/SRC/JAVA/ORG/SAKAIPROJECT/CONTENT/IMPL
# X-CONTENT-TYPE-OUTER-ENVELOPE: TEXT/PLAIN; CHARSET=UTF-8
# X-CONTENT-TYPE-MESSAGE-BODY: TEXT/PLAIN; CHARSET=UTF-8
# CONTENT-TYPE: TEXT/PLAIN; CHARSET=UTF-8
# X-DSPAM-RESULT: INNOCENT
# X-DSPAM-PROCESSED: SAT JAN  5 09:14:16 2008
# X-DSPAM-CONFIDENCE: 0.8475
# X-DSPAM-PROBABILITY: 0.0000
#
# DETAILS: HTTP://SOURCE.SAKAIPROJECT.ORG/VIEWSVN/?VIEW=REV&REV=39772
#
# AUTHOR: STEPHEN.MARQUARD@UCT.AC.ZA
# DATE: 2008-01-05 09:12:07 -0500 (SAT, 05 JAN 2008)
# NEW REVISION: 39772
#
# MODIFIED:
# CONTENT/BRANCHES/SAKAI_2-5-X/CONTENT-IMPL/IMPL/SRC/JAVA/ORG/SAKAIPROJECT/CONTENT/IMPL/CONTENTSERVICESQLORACLE.JAVA
# CONTENT/BRANCHES/SAKAI_2-5-X/CONTENT-IMPL/IMPL/SRC/JAVA/ORG/SAKAIPROJECT/CONTENT/IMPL/DBCONTENTSERVICE.JAVA
# LOG:
# SAK-12501 MERGE TO 2-5-X: R39622, R39624:5, R39632:3 (RESOLVE CONFLICT FROM DIFFERING LINEBREAKS FOR R39622)
#
# ----------------------
# THIS AUTOMATIC NOTIFICATION MESSAGE WAS SENT BY SAKAI COLLAB (HTTPS://COLLAB.SAKAIPROJECT.ORG/PORTAL) FROM THE SOURCE SITE.
# YOU CAN MODIFY HOW YOU RECEIVE NOTIFICATIONS AT MY WORKSPACE > PREFERENCES.
#
#
#
# FROM LOUIS@MEDIA.BERKELEY.EDU FRI JAN  4 18:10:48 2008
# RETURN-PATH: <POSTMASTER@COLLAB.SAKAIPROJECT.ORG>
# RECEIVED: FROM MURDER (MAIL.UMICH.EDU [141.211.14.97])
# 	 BY FRANKENSTEIN.MAIL.UMICH.EDU (CYRUS V2.3.8) WITH LMTPA;
# 	 FRI, 04 JAN 2008 18:10:48 -0500
# X-SIEVE: CMU SIEVE 2.3
# RECEIVED: FROM MURDER ([UNIX SOCKET])
# 	 BY MAIL.UMICH.EDU (CYRUS V2.2.12) WITH LMTPA;
# 	 FRI, 04 JAN 2008 18:10:48 -0500
# RECEIVED: FROM ICESTORM.MR.ITD.UMICH.EDU (ICESTORM.MR.ITD.UMICH.EDU [141.211.93.149])
# 	BY SLEEPERS.MAIL.UMICH.EDU () WITH ESMTP ID M04NABGA029441;
# 	FRI, 4 JAN 2008 18:10:37 -0500
# RECEIVED: FROM PAPLOO.UHI.AC.UK (APP1.PROD.COLLAB.UHI.AC.UK [194.35.219.184])
# 	BY ICESTORM.MR.ITD.UMICH.EDU ID 477EBCE3.161BB.4320 ;
# 	 4 JAN 2008 18:10:31 -0500
# RECEIVED: FROM PAPLOO.UHI.AC.UK (LOCALHOST [127.0.0.1])
# 	BY PAPLOO.UHI.AC.UK (POSTFIX) WITH ESMTP ID 07969BB706;
# 	FRI,  4 JAN 2008 23:10:33 +0000 (GMT)
# MESSAGE-ID: <200801042308.M04N8V6O008125@NAKAMURA.UITS.IUPUI.EDU>
# MIME-VERSION: 1.0
# CONTENT-TRANSFER-ENCODING: 7BIT
# RECEIVED: FROM PROD.COLLAB.UHI.AC.UK ([194.35.219.182])
#           BY PAPLOO.UHI.AC.UK (JAMES SMTP SERVER 2.1.3) WITH SMTP ID 710
#           FOR <SOURCE@COLLAB.SAKAIPROJECT.ORG>;
#           FRI, 4 JAN 2008 23:10:10 +0000 (GMT)
# RECEIVED: FROM NAKAMURA.UITS.IUPUI.EDU (NAKAMURA.UITS.IUPUI.EDU [134.68.220.122])
# 	BY SHMI.UHI.AC.UK (POSTFIX) WITH ESMTP ID 4BA2F42F57
# 	FOR <SOURCE@COLLAB.SAKAIPROJECT.ORG>; FRI,  4 JAN 2008 23:10:10 +0000 (GMT)
# RECEIVED: FROM NAKAMURA.UITS.IUPUI.EDU (LOCALHOST [127.0.0.1])
# 	BY NAKAMURA.UITS.IUPUI.EDU (8.12.11.20060308/8.12.11) WITH ESMTP ID M04N8VHG008127
# 	FOR <SOURCE@COLLAB.SAKAIPROJECT.ORG>; FRI, 4 JAN 2008 18:08:57 -0500
# RECEIVED: (FROM APACHE@LOCALHOST)
# 	BY NAKAMURA.UITS.IUPUI.EDU (8.12.11.20060308/8.12.11/SUBMIT) ID M04N8V6O008125
# 	FOR SOURCE@COLLAB.SAKAIPROJECT.ORG; FRI, 4 JAN 2008 18:08:57 -0500
# DATE: FRI, 4 JAN 2008 18:08:57 -0500
# X-AUTHENTICATION-WARNING: NAKAMURA.UITS.IUPUI.EDU: APACHE SET SENDER TO LOUIS@MEDIA.BERKELEY.EDU USING -F
# TO: SOURCE@COLLAB.SAKAIPROJECT.ORG
# FROM: LOUIS@MEDIA.BERKELEY.EDU
# SUBJECT: [SAKAI] SVN COMMIT: R39771 - IN BSPACE/SITE-MANAGE/SAKAI_2-4-X/SITE-MANAGE-TOOL/TOOL/SRC: BUNDLE JAVA/ORG/SAKAIPROJECT/SITE/TOOL
# X-CONTENT-TYPE-OUTER-ENVELOPE: TEXT/PLAIN; CHARSET=UTF-8
# X-CONTENT-TYPE-MESSAGE-BODY: TEXT/PLAIN; CHARSET=UTF-8
# CONTENT-TYPE: TEXT/PLAIN; CHARSET=UTF-8
# X-DSPAM-RESULT: INNOCENT
# X-DSPAM-PROCESSED: FRI JAN  4 18:10:48 2008
# X-DSPAM-CONFIDENCE: 0.6178
# X-DSPAM-PROBABILITY: 0.0000
#
# DETAILS: HTTP://SOURCE.SAKAIPROJECT.ORG/VIEWSVN/?VIEW=REV&REV=39771
#
# AUTHOR: LOUIS@MEDIA.BERKELEY.EDU
# DATE: 2008-01-04 18:08:50 -0500 (FRI, 04 JAN 2008)
# NEW REVISION: 39771
#
# MODIFIED:
# BSPACE/SITE-MANAGE/SAKAI_2-4-X/SITE-MANAGE-TOOL/TOOL/SRC/BUNDLE/SITESETUPGENERIC.PROPERTIES
# BSPACE/SITE-MANAGE/SAKAI_2-4-X/SITE-MANAGE-TOOL/TOOL/SRC/JAVA/ORG/SAKAIPROJECT/SITE/TOOL/SITEACTION.JAVA
# LOG:
# BSP-1415 NEW (GUEST) USER NOTIFICATION
#
# ----------------------
# THIS AUTOMATIC NOTIFICATION MESSAGE WAS SENT BY SAKAI COLLAB (HTTPS://COLLAB.SAKAIPROJECT.ORG/PORTAL) FROM THE SOURCE SITE.
# YOU CAN MODIFY HOW YOU RECEIVE NOTIFICATIONS AT MY WORKSPACE > PREFERENCES.
#
#
#
# FROM ZQIAN@UMICH.EDU FRI JAN  4 16:10:39 2008
# RETURN-PATH: <POSTMASTER@COLLAB.SAKAIPROJECT.ORG>
# RECEIVED: FROM MURDER (MAIL.UMICH.EDU [141.211.14.25])
# 	 BY FRANKENSTEIN.MAIL.UMICH.EDU (CYRUS V2.3.8) WITH LMTPA;
# 	 FRI, 04 JAN 2008 16:10:39 -0500
# X-SIEVE: CMU SIEVE 2.3
# RECEIVED: FROM MURDER ([UNIX SOCKET])
# 	 BY MAIL.UMICH.EDU (CYRUS V2.2.12) WITH LMTPA;
# 	 FRI, 04 JAN 2008 16:10:39 -0500
# RECEIVED: FROM GHOSTBUSTERS.MR.ITD.UMICH.EDU (GHOSTBUSTERS.MR.ITD.UMICH.EDU [141.211.93.144])
# 	BY PANTHER.MAIL.UMICH.EDU () WITH ESMTP ID M04LACZW014275;
# 	FRI, 4 JAN 2008 16:10:38 -0500
# RECEIVED: FROM PAPLOO.UHI.AC.UK (APP1.PROD.COLLAB.UHI.AC.UK [194.35.219.184])
# 	BY GHOSTBUSTERS.MR.ITD.UMICH.EDU ID 477EA0C6.A0214.25480 ;
# 	 4 JAN 2008 16:10:33 -0500
# RECEIVED: FROM PAPLOO.UHI.AC.UK (LOCALHOST [127.0.0.1])
# 	BY PAPLOO.UHI.AC.UK (POSTFIX) WITH ESMTP ID C48CDBB490;
# 	FRI,  4 JAN 2008 21:10:31 +0000 (GMT)
# MESSAGE-ID: <200801042109.M04L92HB007923@NAKAMURA.UITS.IUPUI.EDU>
# MIME-VERSION: 1.0
# CONTENT-TRANSFER-ENCODING: 7BIT
# RECEIVED: FROM PROD.COLLAB.UHI.AC.UK ([194.35.219.182])
#           BY PAPLOO.UHI.AC.UK (JAMES SMTP SERVER 2.1.3) WITH SMTP ID 906
#           FOR <SOURCE@COLLAB.SAKAIPROJECT.ORG>;
#           FRI, 4 JAN 2008 21:10:18 +0000 (GMT)
# RECEIVED: FROM NAKAMURA.UITS.IUPUI.EDU (NAKAMURA.UITS.IUPUI.EDU [134.68.220.122])
# 	BY SHMI.UHI.AC.UK (POSTFIX) WITH ESMTP ID 7D13042F71
# 	FOR <SOURCE@COLLAB.SAKAIPROJECT.ORG>; FRI,  4 JAN 2008 21:10:14 +0000 (GMT)
# RECEIVED: FROM NAKAMURA.UITS.IUPUI.EDU (LOCALHOST [127.0.0.1])
# 	BY NAKAMURA.UITS.IUPUI.EDU (8.12.11.20060308/8.12.11) WITH ESMTP ID M04L927E007925
# 	FOR <SOURCE@COLLAB.SAKAIPROJECT.ORG>; FRI, 4 JAN 2008 16:09:02 -0500
# RECEIVED: (FROM APACHE@LOCALHOST)
# 	BY NAKAMURA.UITS.IUPUI.EDU (8.12.11.20060308/8.12.11/SUBMIT) ID M04L92HB007923
# 	FOR SOURCE@COLLAB.SAKAIPROJECT.ORG; FRI, 4 JAN 2008 16:09:02 -0500
# DATE: FRI, 4 JAN 2008 16:09:02 -0500
# X-AUTHENTICATION-WARNING: NAKAMURA.UITS.IUPUI.EDU: APACHE SET SENDER TO ZQIAN@UMICH.EDU USING -F
# TO: SOURCE@COLLAB.SAKAIPROJECT.ORG
# FROM: ZQIAN@UMICH.EDU
# SUBJECT: [SAKAI] SVN COMMIT: R39770 - SITE-MANAGE/BRANCHES/SAKAI_2-5-X/SITE-MANAGE-TOOL/TOOL/SRC/WEBAPP/VM/SITESETUP
# X-CONTENT-TYPE-OUTER-ENVELOPE: TEXT/PLAIN; CHARSET=UTF-8
# X-CONTENT-TYPE-MESSAGE-BODY: TEXT/PLAIN; CHARSET=UTF-8
# CONTENT-TYPE: TEXT/PLAIN; CHARSET=UTF-8
# X-DSPAM-RESULT: INNOCENT
# X-DSPAM-PROCESSED: FRI JAN  4 16:10:39 2008
# X-DSPAM-CONFIDENCE: 0.6961
# X-DSPAM-PROBABILITY: 0.0000
#
# DETAILS: HTTP://SOURCE.SAKAIPROJECT.ORG/VIEWSVN/?VIEW=REV&REV=39770
#
# AUTHOR: ZQIAN@UMICH.EDU
# DATE: 2008-01-04 16:09:01 -0500 (FRI, 04 JAN 2008)
# NEW REVISION: 39770
#
# MODIFIED:
# SITE-MANAGE/BRANCHES/SAKAI_2-5-X/SITE-MANAGE-TOOL/TOOL/SRC/WEBAPP/VM/SITESETUP/CHEF_SITE-SITEINFO-LIST.VM
# LOG:
# MERGE FIX TO SAK-9996 INTO 2-5-X BRANCH: SVN MERGE -R 39687:39688 HTTPS://SOURCE.SAKAIPROJECT.ORG/SVN/SITE-MANAGE/TRUNK/
#
# ----------------------
# THIS AUTOMATIC NOTIFICATION MESSAGE WAS SENT BY SAKAI COLLAB (HTTPS://COLLAB.SAKAIPROJECT.ORG/PORTAL) FROM THE SOURCE SITE.
# YOU CAN MODIFY HOW YOU RECEIVE NOTIFICATIONS AT MY WORKSPACE > PREFERENCES.
#
#
#
# FROM RJLOWE@IUPUI.EDU FRI JAN  4 15:46:24 2008
# RETURN-PATH: <POSTMASTER@COLLAB.SAKAIPROJECT.ORG>
# RECEIVED: FROM MURDER (MAIL.UMICH.EDU [141.211.14.25])
# 	 BY FRANKENSTEIN.MAIL.UMICH.EDU (CYRUS V2.3.8) WITH LMTPA;
# 	 FRI, 04 JAN 2008 15:46:24 -0500
# X-SIEVE: CMU SIEVE 2.3
# RECEIVED: FROM MURDER ([UNIX SOCKET])
# 	 BY MAIL.UMICH.EDU (CYRUS V2.2.12) WITH LMTPA;
# 	 FRI, 04 JAN 2008 15:46:24 -0500
# RECEIVED: FROM DREAMCATCHER.MR.ITD.UMICH.EDU (DREAMCATCHER.MR.ITD.UMICH.EDU [141.211.14.43])
# 	BY PANTHER.MAIL.UMICH.EDU () WITH ESMTP ID M04KKNBX032077;
# 	FRI, 4 JAN 2008 15:46:23 -0500
# RECEIVED: FROM PAPLOO.UHI.AC.UK (APP1.PROD.COLLAB.UHI.AC.UK [194.35.219.184])
# 	BY DREAMCATCHER.MR.ITD.UMICH.EDU ID 477E9B13.2F3BC.22965 ;
# 	 4 JAN 2008 15:46:13 -0500
# RECEIVED: FROM PAPLOO.UHI.AC.UK (LOCALHOST [127.0.0.1])
# 	BY PAPLOO.UHI.AC.UK (POSTFIX) WITH ESMTP ID 4AE03BB552;
# 	FRI,  4 JAN 2008 20:46:13 +0000 (GMT)
# MESSAGE-ID: <200801042044.M04KIEM3007881@NAKAMURA.UITS.IUPUI.EDU>
# MIME-VERSION: 1.0
# CONTENT-TRANSFER-ENCODING: 7BIT
# RECEIVED: FROM PROD.COLLAB.UHI.AC.UK ([194.35.219.182])
#           BY PAPLOO.UHI.AC.UK (JAMES SMTP SERVER 2.1.3) WITH SMTP ID 38
#           FOR <SOURCE@COLLAB.SAKAIPROJECT.ORG>;
#           FRI, 4 JAN 2008 20:45:56 +0000 (GMT)
# RECEIVED: FROM NAKAMURA.UITS.IUPUI.EDU (NAKAMURA.UITS.IUPUI.EDU [134.68.220.122])
# 	BY SHMI.UHI.AC.UK (POSTFIX) WITH ESMTP ID A55D242F57
# 	FOR <SOURCE@COLLAB.SAKAIPROJECT.ORG>; FRI,  4 JAN 2008 20:45:52 +0000 (GMT)
# RECEIVED: FROM NAKAMURA.UITS.IUPUI.EDU (LOCALHOST [127.0.0.1])
# 	BY NAKAMURA.UITS.IUPUI.EDU (8.12.11.20060308/8.12.11) WITH ESMTP ID M04KIEQE007883
# 	FOR <SOURCE@COLLAB.SAKAIPROJECT.ORG>; FRI, 4 JAN 2008 15:44:40 -0500
# RECEIVED: (FROM APACHE@LOCALHOST)
# 	BY NAKAMURA.UITS.IUPUI.EDU (8.12.11.20060308/8.12.11/SUBMIT) ID M04KIEM3007881
# 	FOR SOURCE@COLLAB.SAKAIPROJECT.ORG; FRI, 4 JAN 2008 15:44:40 -0500
# DATE: FRI, 4 JAN 2008 15:44:40 -0500
# X-AUTHENTICATION-WARNING: NAKAMURA.UITS.IUPUI.EDU: APACHE SET SENDER TO RJLOWE@IUPUI.EDU USING -F
# TO: SOURCE@COLLAB.SAKAIPROJECT.ORG
# FROM: RJLOWE@IUPUI.EDU
# SUBJECT: [SAKAI] SVN COMMIT: R39769 - IN GRADEBOOK/TRUNK/APP/UI/SRC: JAVA/ORG/SAKAIPROJECT/TOOL/GRADEBOOK/UI/HELPERS/BEANS JAVA/ORG/SAKAIPROJECT/TOOL/GRADEBOOK/UI/HELPERS/PRODUCERS WEBAPP/WEB-INF WEBAPP/WEB-INF/BUNDLE
# X-CONTENT-TYPE-OUTER-ENVELOPE: TEXT/PLAIN; CHARSET=UTF-8
# X-CONTENT-TYPE-MESSAGE-BODY: TEXT/PLAIN; CHARSET=UTF-8
# CONTENT-TYPE: TEXT/PLAIN; CHARSET=UTF-8
# X-DSPAM-RESULT: INNOCENT
# X-DSPAM-PROCESSED: FRI JAN  4 15:46:24 2008
# X-DSPAM-CONFIDENCE: 0.7565
# X-DSPAM-PROBABILITY: 0.0000
#
# DETAILS: HTTP://SOURCE.SAKAIPROJECT.ORG/VIEWSVN/?VIEW=REV&REV=39769
#
# AUTHOR: RJLOWE@IUPUI.EDU
# DATE: 2008-01-04 15:44:39 -0500 (FRI, 04 JAN 2008)
# NEW REVISION: 39769
#
# MODIFIED:
# GRADEBOOK/TRUNK/APP/UI/SRC/JAVA/ORG/SAKAIPROJECT/TOOL/GRADEBOOK/UI/HELPERS/BEANS/ASSIGNMENTGRADERECORDBEAN.JAVA
# GRADEBOOK/TRUNK/APP/UI/SRC/JAVA/ORG/SAKAIPROJECT/TOOL/GRADEBOOK/UI/HELPERS/PRODUCERS/GRADEGRADEBOOKITEMPRODUCER.JAVA
# GRADEBOOK/TRUNK/APP/UI/SRC/WEBAPP/WEB-INF/APPLICATIONCONTEXT.XML
# GRADEBOOK/TRUNK/APP/UI/SRC/WEBAPP/WEB-INF/BUNDLE/MESSAGES.PROPERTIES
# GRADEBOOK/TRUNK/APP/UI/SRC/WEBAPP/WEB-INF/REQUESTCONTEXT.XML
# LOG:
# SAK-12180 - FIXED ERRORS WITH GRADING HELPER
#
# ----------------------
# THIS AUTOMATIC NOTIFICATION MESSAGE WAS SENT BY SAKAI COLLAB (HTTPS://COLLAB.SAKAIPROJECT.ORG/PORTAL) FROM THE SOURCE SITE.
# YOU CAN MODIFY HOW YOU RECEIVE NOTIFICATIONS AT MY WORKSPACE > PREFERENCES.
#
#
#
# FROM ZQIAN@UMICH.EDU FRI JAN  4 15:03:18 2008
# RETURN-PATH: <POSTMASTER@COLLAB.SAKAIPROJECT.ORG>
# RECEIVED: FROM MURDER (MAIL.UMICH.EDU [141.211.14.46])
# 	 BY FRANKENSTEIN.MAIL.UMICH.EDU (CYRUS V2.3.8) WITH LMTPA;
# 	 FRI, 04 JAN 2008 15:03:18 -0500
# X-SIEVE: CMU SIEVE 2.3
# RECEIVED: FROM MURDER ([UNIX SOCKET])
# 	 BY MAIL.UMICH.EDU (CYRUS V2.2.12) WITH LMTPA;
# 	 FRI, 04 JAN 2008 15:03:18 -0500
# RECEIVED: FROM FIRESTARTER.MR.ITD.UMICH.EDU (FIRESTARTER.MR.ITD.UMICH.EDU [141.211.14.83])
# 	BY FAN.MAIL.UMICH.EDU () WITH ESMTP ID M04K3HGF006563;
# 	FRI, 4 JAN 2008 15:03:17 -0500
# RECEIVED: FROM PAPLOO.UHI.AC.UK (APP1.PROD.COLLAB.UHI.AC.UK [194.35.219.184])
# 	BY FIRESTARTER.MR.ITD.UMICH.EDU ID 477E9100.8F7F4.1590 ;
# 	 4 JAN 2008 15:03:15 -0500
# RECEIVED: FROM PAPLOO.UHI.AC.UK (LOCALHOST [127.0.0.1])
# 	BY PAPLOO.UHI.AC.UK (POSTFIX) WITH ESMTP ID 57770BB477;
# 	FRI,  4 JAN 2008 20:03:09 +0000 (GMT)
# MESSAGE-ID: <200801042001.M04K1CO0007738@NAKAMURA.UITS.IUPUI.EDU>
# MIME-VERSION: 1.0
# CONTENT-TRANSFER-ENCODING: 7BIT
# RECEIVED: FROM PROD.COLLAB.UHI.AC.UK ([194.35.219.182])
#           BY PAPLOO.UHI.AC.UK (JAMES SMTP SERVER 2.1.3) WITH SMTP ID 622
#           FOR <SOURCE@COLLAB.SAKAIPROJECT.ORG>;
#           FRI, 4 JAN 2008 20:02:46 +0000 (GMT)
# RECEIVED: FROM NAKAMURA.UITS.IUPUI.EDU (NAKAMURA.UITS.IUPUI.EDU [134.68.220.122])
# 	BY SHMI.UHI.AC.UK (POSTFIX) WITH ESMTP ID AB4D042F4D
# 	FOR <SOURCE@COLLAB.SAKAIPROJECT.ORG>; FRI,  4 JAN 2008 20:02:50 +0000 (GMT)
# RECEIVED: FROM NAKAMURA.UITS.IUPUI.EDU (LOCALHOST [127.0.0.1])
# 	BY NAKAMURA.UITS.IUPUI.EDU (8.12.11.20060308/8.12.11) WITH ESMTP ID M04K1CXV007740
# 	FOR <SOURCE@COLLAB.SAKAIPROJECT.ORG>; FRI, 4 JAN 2008 15:01:38 -0500
# RECEIVED: (FROM APACHE@LOCALHOST)
# 	BY NAKAMURA.UITS.IUPUI.EDU (8.12.11.20060308/8.12.11/SUBMIT) ID M04K1CO0007738
# 	FOR SOURCE@COLLAB.SAKAIPROJECT.ORG; FRI, 4 JAN 2008 15:01:38 -0500
# DATE: FRI, 4 JAN 2008 15:01:38 -0500
# X-AUTHENTICATION-WARNING: NAKAMURA.UITS.IUPUI.EDU: APACHE SET SENDER TO ZQIAN@UMICH.EDU USING -F
# TO: SOURCE@COLLAB.SAKAIPROJECT.ORG
# FROM: ZQIAN@UMICH.EDU
# SUBJECT: [SAKAI] SVN COMMIT: R39766 - SITE-MANAGE/BRANCHES/SAKAI_2-4-X/SITE-MANAGE-TOOL/TOOL/SRC/JAVA/ORG/SAKAIPROJECT/SITE/TOOL
# X-CONTENT-TYPE-OUTER-ENVELOPE: TEXT/PLAIN; CHARSET=UTF-8
# X-CONTENT-TYPE-MESSAGE-BODY: TEXT/PLAIN; CHARSET=UTF-8
# CONTENT-TYPE: TEXT/PLAIN; CHARSET=UTF-8
# X-DSPAM-RESULT: INNOCENT
# X-DSPAM-PROCESSED: FRI JAN  4 15:03:18 2008
# X-DSPAM-CONFIDENCE: 0.7626
# X-DSPAM-PROBABILITY: 0.0000
#
# DETAILS: HTTP://SOURCE.SAKAIPROJECT.ORG/VIEWSVN/?VIEW=REV&REV=39766
#
# AUTHOR: ZQIAN@UMICH.EDU
# DATE: 2008-01-04 15:01:37 -0500 (FRI, 04 JAN 2008)
# NEW REVISION: 39766
#
# MODIFIED:
# SITE-MANAGE/BRANCHES/SAKAI_2-4-X/SITE-MANAGE-TOOL/TOOL/SRC/JAVA/ORG/SAKAIPROJECT/SITE/TOOL/SITEACTION.JAVA
# LOG:
# MERGE FIX TO SAK-10788 INTO SITE-MANAGE 2.4.X BRANCH:
#
# SAKAI SOURCE REPOSITORY  	#38024  	WED NOV 07 14:54:46 MST 2007  	ZQIAN@UMICH.EDU  	 FIX TO SAK-10788: IF A PROVIDED ID IN A COUSE SITE IS FAKE OR DOESN'T PROVIDE ANY USER INFORMATION, SITE INFO APPEARS TO BE LIKE PROJECT SITE WITH EMPTY PARTICIPANT LIST
#
# WATCH FOR ENROLLMENTS OBJECT BEING NULL AND CONCATENATE PROVIDER IDS WHEN THERE ARE MORE THAN ONE.
# FILES CHANGED
# MODIFY /SITE-MANAGE/TRUNK/SITE-MANAGE-TOOL/TOOL/SRC/JAVA/ORG/SAKAIPROJECT/SITE/TOOL/SITEACTION.JAVA
#
#
#
#
# ----------------------
# THIS AUTOMATIC NOTIFICATION MESSAGE WAS SENT BY SAKAI COLLAB (HTTPS://COLLAB.SAKAIPROJECT.ORG/PORTAL) FROM THE SOURCE SITE.
# YOU CAN MODIFY HOW YOU RECEIVE NOTIFICATIONS AT MY WORKSPACE > PREFERENCES.
#
#
#
# FROM RJLOWE@IUPUI.EDU FRI JAN  4 14:50:18 2008
# RETURN-PATH: <POSTMASTER@COLLAB.SAKAIPROJECT.ORG>
# RECEIVED: FROM MURDER (MAIL.UMICH.EDU [141.211.14.93])
# 	 BY FRANKENSTEIN.MAIL.UMICH.EDU (CYRUS V2.3.8) WITH LMTPA;
# 	 FRI, 04 JAN 2008 14:50:18 -0500
# X-SIEVE: CMU SIEVE 2.3
# RECEIVED: FROM MURDER ([UNIX SOCKET])
# 	 BY MAIL.UMICH.EDU (CYRUS V2.2.12) WITH LMTPA;
# 	 FRI, 04 JAN 2008 14:50:18 -0500
# RECEIVED: FROM EYEWITNESS.MR.ITD.UMICH.EDU (EYEWITNESS.MR.ITD.UMICH.EDU [141.211.93.142])
# 	BY MISSION.MAIL.UMICH.EDU () WITH ESMTP ID M04JOHJI019755;
# 	FRI, 4 JAN 2008 14:50:17 -0500
# RECEIVED: FROM PAPLOO.UHI.AC.UK (APP1.PROD.COLLAB.UHI.AC.UK [194.35.219.184])
# 	BY EYEWITNESS.MR.ITD.UMICH.EDU ID 477E8DF2.67B91.5278 ;
# 	 4 JAN 2008 14:50:13 -0500
# RECEIVED: FROM PAPLOO.UHI.AC.UK (LOCALHOST [127.0.0.1])
# 	BY PAPLOO.UHI.AC.UK (POSTFIX) WITH ESMTP ID 2D1B9BB492;
# 	FRI,  4 JAN 2008 19:47:10 +0000 (GMT)
# MESSAGE-ID: <200801041948.M04JMDWO007705@NAKAMURA.UITS.IUPUI.EDU>
# MIME-VERSION: 1.0
# CONTENT-TRANSFER-ENCODING: 7BIT
# RECEIVED: FROM PROD.COLLAB.UHI.AC.UK ([194.35.219.182])
#           BY PAPLOO.UHI.AC.UK (JAMES SMTP SERVER 2.1.3) WITH SMTP ID 960
#           FOR <SOURCE@COLLAB.SAKAIPROJECT.ORG>;
#           FRI, 4 JAN 2008 19:46:50 +0000 (GMT)
# RECEIVED: FROM NAKAMURA.UITS.IUPUI.EDU (NAKAMURA.UITS.IUPUI.EDU [134.68.220.122])
# 	BY SHMI.UHI.AC.UK (POSTFIX) WITH ESMTP ID B3E6742F4A
# 	FOR <SOURCE@COLLAB.SAKAIPROJECT.ORG>; FRI,  4 JAN 2008 19:49:51 +0000 (GMT)
# RECEIVED: FROM NAKAMURA.UITS.IUPUI.EDU (LOCALHOST [127.0.0.1])
# 	BY NAKAMURA.UITS.IUPUI.EDU (8.12.11.20060308/8.12.11) WITH ESMTP ID M04JMEV9007707
# 	FOR <SOURCE@COLLAB.SAKAIPROJECT.ORG>; FRI, 4 JAN 2008 14:48:40 -0500
# RECEIVED: (FROM APACHE@LOCALHOST)
# 	BY NAKAMURA.UITS.IUPUI.EDU (8.12.11.20060308/8.12.11/SUBMIT) ID M04JMDWO007705
# 	FOR SOURCE@COLLAB.SAKAIPROJECT.ORG; FRI, 4 JAN 2008 14:48:39 -0500
# DATE: FRI, 4 JAN 2008 14:48:39 -0500
# X-AUTHENTICATION-WARNING: NAKAMURA.UITS.IUPUI.EDU: APACHE SET SENDER TO RJLOWE@IUPUI.EDU USING -F
# TO: SOURCE@COLLAB.SAKAIPROJECT.ORG
# FROM: RJLOWE@IUPUI.EDU
# SUBJECT: [SAKAI] SVN COMMIT: R39765 - IN GRADEBOOK/TRUNK/APP: BUSINESS/SRC/JAVA/ORG/SAKAIPROJECT/TOOL/GRADEBOOK/BUSINESS BUSINESS/SRC/JAVA/ORG/SAKAIPROJECT/TOOL/GRADEBOOK/BUSINESS/IMPL UI UI/SRC/JAVA/ORG/SAKAIPROJECT/TOOL/GRADEBOOK/UI/HELPERS/BEANS UI/SRC/JAVA/ORG/SAKAIPROJECT/TOOL/GRADEBOOK/UI/HELPERS/ENTITY UI/SRC/JAVA/ORG/SAKAIPROJECT/TOOL/GRADEBOOK/UI/HELPERS/PARAMS UI/SRC/JAVA/ORG/SAKAIPROJECT/TOOL/GRADEBOOK/UI/HELPERS/PRODUCERS UI/SRC/WEBAPP/WEB-INF UI/SRC/WEBAPP/WEB-INF/BUNDLE UI/SRC/WEBAPP/CONTENT/TEMPLATES
# X-CONTENT-TYPE-OUTER-ENVELOPE: TEXT/PLAIN; CHARSET=UTF-8
# X-CONTENT-TYPE-MESSAGE-BODY: TEXT/PLAIN; CHARSET=UTF-8
# CONTENT-TYPE: TEXT/PLAIN; CHARSET=UTF-8
# X-DSPAM-RESULT: INNOCENT
# X-DSPAM-PROCESSED: FRI JAN  4 14:50:18 2008
# X-DSPAM-CONFIDENCE: 0.7556
# X-DSPAM-PROBABILITY: 0.0000
#
# DETAILS: HTTP://SOURCE.SAKAIPROJECT.ORG/VIEWSVN/?VIEW=REV&REV=39765
#
# AUTHOR: RJLOWE@IUPUI.EDU
# DATE: 2008-01-04 14:48:37 -0500 (FRI, 04 JAN 2008)
# NEW REVISION: 39765
#
# ADDED:
# GRADEBOOK/TRUNK/APP/UI/SRC/JAVA/ORG/SAKAIPROJECT/TOOL/GRADEBOOK/UI/HELPERS/BEANS/ASSIGNMENTGRADERECORDBEAN.JAVA
# GRADEBOOK/TRUNK/APP/UI/SRC/JAVA/ORG/SAKAIPROJECT/TOOL/GRADEBOOK/UI/HELPERS/BEANS/ASSIGNMENTGRADERECORDCREATOR.JAVA
# GRADEBOOK/TRUNK/APP/UI/SRC/JAVA/ORG/SAKAIPROJECT/TOOL/GRADEBOOK/UI/HELPERS/ENTITY/GRADEBOOKENTRYGRADEENTITYPROVIDER.JAVA
# GRADEBOOK/TRUNK/APP/UI/SRC/JAVA/ORG/SAKAIPROJECT/TOOL/GRADEBOOK/UI/HELPERS/PARAMS/GRADEGRADEBOOKITEMVIEWPARAMS.JAVA
# GRADEBOOK/TRUNK/APP/UI/SRC/JAVA/ORG/SAKAIPROJECT/TOOL/GRADEBOOK/UI/HELPERS/PRODUCERS/GRADEGRADEBOOKITEMPRODUCER.JAVA
# GRADEBOOK/TRUNK/APP/UI/SRC/WEBAPP/CONTENT/TEMPLATES/GRADE-GRADEBOOK-ITEM.HTML
# MODIFIED:
# GRADEBOOK/TRUNK/APP/BUSINESS/SRC/JAVA/ORG/SAKAIPROJECT/TOOL/GRADEBOOK/BUSINESS/GRADEBOOKMANAGER.JAVA
# GRADEBOOK/TRUNK/APP/BUSINESS/SRC/JAVA/ORG/SAKAIPROJECT/TOOL/GRADEBOOK/BUSINESS/IMPL/GRADEBOOKMANAGERHIBERNATEIMPL.JAVA
# GRADEBOOK/TRUNK/APP/UI/POM.XML
# GRADEBOOK/TRUNK/APP/UI/SRC/JAVA/ORG/SAKAIPROJECT/TOOL/GRADEBOOK/UI/HELPERS/BEANS/GRADEBOOKITEMBEAN.JAVA
# GRADEBOOK/TRUNK/APP/UI/SRC/JAVA/ORG/SAKAIPROJECT/TOOL/GRADEBOOK/UI/HELPERS/ENTITY/GRADEBOOKENTRYENTITYPROVIDER.JAVA
# GRADEBOOK/TRUNK/APP/UI/SRC/JAVA/ORG/SAKAIPROJECT/TOOL/GRADEBOOK/UI/HELPERS/PRODUCERS/ADDGRADEBOOKITEMPRODUCER.JAVA
# GRADEBOOK/TRUNK/APP/UI/SRC/WEBAPP/WEB-INF/APPLICATIONCONTEXT.XML
# GRADEBOOK/TRUNK/APP/UI/SRC/WEBAPP/WEB-INF/BUNDLE/MESSAGES.PROPERTIES
# GRADEBOOK/TRUNK/APP/UI/SRC/WEBAPP/WEB-INF/REQUESTCONTEXT.XML
# LOG:
# SAK-12180 - NEW HELPER TOOL TO GRADE AN ASSIGNMENT
#
# ----------------------
# THIS AUTOMATIC NOTIFICATION MESSAGE WAS SENT BY SAKAI COLLAB (HTTPS://COLLAB.SAKAIPROJECT.ORG/PORTAL) FROM THE SOURCE SITE.
# YOU CAN MODIFY HOW YOU RECEIVE NOTIFICATIONS AT MY WORKSPACE > PREFERENCES.
#
#
#
# FROM CWEN@IUPUI.EDU FRI JAN  4 11:37:30 2008
# RETURN-PATH: <POSTMASTER@COLLAB.SAKAIPROJECT.ORG>
# RECEIVED: FROM MURDER (MAIL.UMICH.EDU [141.211.14.46])
# 	 BY FRANKENSTEIN.MAIL.UMICH.EDU (CYRUS V2.3.8) WITH LMTPA;
# 	 FRI, 04 JAN 2008 11:37:30 -0500
# X-SIEVE: CMU SIEVE 2.3
# RECEIVED: FROM MURDER ([UNIX SOCKET])
# 	 BY MAIL.UMICH.EDU (CYRUS V2.2.12) WITH LMTPA;
# 	 FRI, 04 JAN 2008 11:37:30 -0500
# RECEIVED: FROM TADPOLE.MR.ITD.UMICH.EDU (TADPOLE.MR.ITD.UMICH.EDU [141.211.14.72])
# 	BY FAN.MAIL.UMICH.EDU () WITH ESMTP ID M04GBT9X022078;
# 	FRI, 4 JAN 2008 11:37:29 -0500
# RECEIVED: FROM PAPLOO.UHI.AC.UK (APP1.PROD.COLLAB.UHI.AC.UK [194.35.219.184])
# 	BY TADPOLE.MR.ITD.UMICH.EDU ID 477E60B2.82756.9904 ;
# 	 4 JAN 2008 11:37:09 -0500
# RECEIVED: FROM PAPLOO.UHI.AC.UK (LOCALHOST [127.0.0.1])
# 	BY PAPLOO.UHI.AC.UK (POSTFIX) WITH ESMTP ID 8D13DBB001;
# 	FRI,  4 JAN 2008 16:37:07 +0000 (GMT)
# MESSAGE-ID: <200801041635.M04GZQGZ007313@NAKAMURA.UITS.IUPUI.EDU>
# MIME-VERSION: 1.0
# CONTENT-TRANSFER-ENCODING: 7BIT
# RECEIVED: FROM PROD.COLLAB.UHI.AC.UK ([194.35.219.182])
#           BY PAPLOO.UHI.AC.UK (JAMES SMTP SERVER 2.1.3) WITH SMTP ID 120
#           FOR <SOURCE@COLLAB.SAKAIPROJECT.ORG>;
#           FRI, 4 JAN 2008 16:36:40 +0000 (GMT)
# RECEIVED: FROM NAKAMURA.UITS.IUPUI.EDU (NAKAMURA.UITS.IUPUI.EDU [134.68.220.122])
# 	BY SHMI.UHI.AC.UK (POSTFIX) WITH ESMTP ID D430B42E42
# 	FOR <SOURCE@COLLAB.SAKAIPROJECT.ORG>; FRI,  4 JAN 2008 16:36:37 +0000 (GMT)
# RECEIVED: FROM NAKAMURA.UITS.IUPUI.EDU (LOCALHOST [127.0.0.1])
# 	BY NAKAMURA.UITS.IUPUI.EDU (8.12.11.20060308/8.12.11) WITH ESMTP ID M04GZQ7W007315
# 	FOR <SOURCE@COLLAB.SAKAIPROJECT.ORG>; FRI, 4 JAN 2008 11:35:26 -0500
# RECEIVED: (FROM APACHE@LOCALHOST)
# 	BY NAKAMURA.UITS.IUPUI.EDU (8.12.11.20060308/8.12.11/SUBMIT) ID M04GZQGZ007313
# 	FOR SOURCE@COLLAB.SAKAIPROJECT.ORG; FRI, 4 JAN 2008 11:35:26 -0500
# DATE: FRI, 4 JAN 2008 11:35:26 -0500
# X-AUTHENTICATION-WARNING: NAKAMURA.UITS.IUPUI.EDU: APACHE SET SENDER TO CWEN@IUPUI.EDU USING -F
# TO: SOURCE@COLLAB.SAKAIPROJECT.ORG
# FROM: CWEN@IUPUI.EDU
# SUBJECT: [SAKAI] SVN COMMIT: R39764 - IN MSGCNTR/TRUNK/MESSAGEFORUMS-APP/SRC/JAVA/ORG/SAKAIPROJECT/TOOL/MESSAGEFORUMS: . UI
# X-CONTENT-TYPE-OUTER-ENVELOPE: TEXT/PLAIN; CHARSET=UTF-8
# X-CONTENT-TYPE-MESSAGE-BODY: TEXT/PLAIN; CHARSET=UTF-8
# CONTENT-TYPE: TEXT/PLAIN; CHARSET=UTF-8
# X-DSPAM-RESULT: INNOCENT
# X-DSPAM-PROCESSED: FRI JAN  4 11:37:30 2008
# X-DSPAM-CONFIDENCE: 0.7002
# X-DSPAM-PROBABILITY: 0.0000
#
# DETAILS: HTTP://SOURCE.SAKAIPROJECT.ORG/VIEWSVN/?VIEW=REV&REV=39764
#
# AUTHOR: CWEN@IUPUI.EDU
# DATE: 2008-01-04 11:35:25 -0500 (FRI, 04 JAN 2008)
# NEW REVISION: 39764
#
# MODIFIED:
# MSGCNTR/TRUNK/MESSAGEFORUMS-APP/SRC/JAVA/ORG/SAKAIPROJECT/TOOL/MESSAGEFORUMS/PRIVATEMESSAGESTOOL.JAVA
# MSGCNTR/TRUNK/MESSAGEFORUMS-APP/SRC/JAVA/ORG/SAKAIPROJECT/TOOL/MESSAGEFORUMS/UI/PRIVATEMESSAGEDECORATEDBEAN.JAVA
# LOG:
# UNMERGE XINGTANG'S CHECKIN FOR SAK-12488.
#
# SVN MERGE -R39558:39557 HTTPS://SOURCE.SAKAIPROJECT.ORG/SVN/MSGCNTR/TRUNK
# U    MESSAGEFORUMS-APP/SRC/JAVA/ORG/SAKAIPROJECT/TOOL/MESSAGEFORUMS/PRIVATEMESSAGESTOOL.JAVA
# U    MESSAGEFORUMS-APP/SRC/JAVA/ORG/SAKAIPROJECT/TOOL/MESSAGEFORUMS/UI/PRIVATEMESSAGEDECORATEDBEAN.JAVA
#
# SVN LOG -R 39558
# ------------------------------------------------------------------------
# R39558 | HU2@IUPUI.EDU | 2007-12-20 15:25:38 -0500 (THU, 20 DEC 2007) | 3 LINES
#
# SAK-12488
# WHEN SEND A MESSAGE TO YOURSELF. CLICK REPLY TO ALL, CC ROW SHOULD BE NULL.
# HTTP://JIRA.SAKAIPROJECT.ORG/JIRA/BROWSE/SAK-12488
# ------------------------------------------------------------------------
#
#
# ----------------------
# THIS AUTOMATIC NOTIFICATION MESSAGE WAS SENT BY SAKAI COLLAB (HTTPS://COLLAB.SAKAIPROJECT.ORG/PORTAL) FROM THE SOURCE SITE.
# YOU CAN MODIFY HOW YOU RECEIVE NOTIFICATIONS AT MY WORKSPACE > PREFERENCES.
#
#
#
# FROM CWEN@IUPUI.EDU FRI JAN  4 11:35:08 2008
# RETURN-PATH: <POSTMASTER@COLLAB.SAKAIPROJECT.ORG>
# RECEIVED: FROM MURDER (MAIL.UMICH.EDU [141.211.14.46])
# 	 BY FRANKENSTEIN.MAIL.UMICH.EDU (CYRUS V2.3.8) WITH LMTPA;
# 	 FRI, 04 JAN 2008 11:35:08 -0500
# X-SIEVE: CMU SIEVE 2.3
# RECEIVED: FROM MURDER ([UNIX SOCKET])
# 	 BY MAIL.UMICH.EDU (CYRUS V2.2.12) WITH LMTPA;
# 	 FRI, 04 JAN 2008 11:35:08 -0500
# RECEIVED: FROM IT.MR.ITD.UMICH.EDU (IT.MR.ITD.UMICH.EDU [141.211.93.151])
# 	BY FAN.MAIL.UMICH.EDU () WITH ESMTP ID M04GZ6LT020480;
# 	FRI, 4 JAN 2008 11:35:06 -0500
# RECEIVED: FROM PAPLOO.UHI.AC.UK (APP1.PROD.COLLAB.UHI.AC.UK [194.35.219.184])
# 	BY IT.MR.ITD.UMICH.EDU ID 477E6033.6469D.21870 ;
# 	 4 JAN 2008 11:35:02 -0500
# RECEIVED: FROM PAPLOO.UHI.AC.UK (LOCALHOST [127.0.0.1])
# 	BY PAPLOO.UHI.AC.UK (POSTFIX) WITH ESMTP ID E40FABAE5B;
# 	FRI,  4 JAN 2008 16:34:38 +0000 (GMT)
# MESSAGE-ID: <200801041633.M04GX6EG007292@NAKAMURA.UITS.IUPUI.EDU>
# MIME-VERSION: 1.0
# CONTENT-TRANSFER-ENCODING: 7BIT
# RECEIVED: FROM PROD.COLLAB.UHI.AC.UK ([194.35.219.182])
#           BY PAPLOO.UHI.AC.UK (JAMES SMTP SERVER 2.1.3) WITH SMTP ID 697
#           FOR <SOURCE@COLLAB.SAKAIPROJECT.ORG>;
#           FRI, 4 JAN 2008 16:34:01 +0000 (GMT)
# RECEIVED: FROM NAKAMURA.UITS.IUPUI.EDU (NAKAMURA.UITS.IUPUI.EDU [134.68.220.122])
# 	BY SHMI.UHI.AC.UK (POSTFIX) WITH ESMTP ID 1CD0C42E42
# 	FOR <SOURCE@COLLAB.SAKAIPROJECT.ORG>; FRI,  4 JAN 2008 16:34:17 +0000 (GMT)
# RECEIVED: FROM NAKAMURA.UITS.IUPUI.EDU (LOCALHOST [127.0.0.1])
# 	BY NAKAMURA.UITS.IUPUI.EDU (8.12.11.20060308/8.12.11) WITH ESMTP ID M04GX6Y3007294
# 	FOR <SOURCE@COLLAB.SAKAIPROJECT.ORG>; FRI, 4 JAN 2008 11:33:06 -0500
# RECEIVED: (FROM APACHE@LOCALHOST)
# 	BY NAKAMURA.UITS.IUPUI.EDU (8.12.11.20060308/8.12.11/SUBMIT) ID M04GX6EG007292
# 	FOR SOURCE@COLLAB.SAKAIPROJECT.ORG; FRI, 4 JAN 2008 11:33:06 -0500
# DATE: FRI, 4 JAN 2008 11:33:06 -0500
# X-AUTHENTICATION-WARNING: NAKAMURA.UITS.IUPUI.EDU: APACHE SET SENDER TO CWEN@IUPUI.EDU USING -F
# TO: SOURCE@COLLAB.SAKAIPROJECT.ORG
# FROM: CWEN@IUPUI.EDU
# SUBJECT: [SAKAI] SVN COMMIT: R39763 - IN MSGCNTR/TRUNK: MESSAGEFORUMS-API/SRC/BUNDLE/ORG/SAKAIPROJECT/API/APP/MESSAGECENTER/BUNDLE MESSAGEFORUMS-APP/SRC/JAVA/ORG/SAKAIPROJECT/TOOL/MESSAGEFORUMS
# X-CONTENT-TYPE-OUTER-ENVELOPE: TEXT/PLAIN; CHARSET=UTF-8
# X-CONTENT-TYPE-MESSAGE-BODY: TEXT/PLAIN; CHARSET=UTF-8
# CONTENT-TYPE: TEXT/PLAIN; CHARSET=UTF-8
# X-DSPAM-RESULT: INNOCENT
# X-DSPAM-PROCESSED: FRI JAN  4 11:35:08 2008
# X-DSPAM-CONFIDENCE: 0.7615
# X-DSPAM-PROBABILITY: 0.0000
#
# DETAILS: HTTP://SOURCE.SAKAIPROJECT.ORG/VIEWSVN/?VIEW=REV&REV=39763
#
# AUTHOR: CWEN@IUPUI.EDU
# DATE: 2008-01-04 11:33:05 -0500 (FRI, 04 JAN 2008)
# NEW REVISION: 39763
#
# MODIFIED:
# MSGCNTR/TRUNK/MESSAGEFORUMS-API/SRC/BUNDLE/ORG/SAKAIPROJECT/API/APP/MESSAGECENTER/BUNDLE/MESSAGES.PROPERTIES
# MSGCNTR/TRUNK/MESSAGEFORUMS-APP/SRC/JAVA/ORG/SAKAIPROJECT/TOOL/MESSAGEFORUMS/PRIVATEMESSAGESTOOL.JAVA
# LOG:
# UNMERGE XINGTANG'S CHECK IN FOR SAK-12484.
#
# SVN MERGE -R39571:39570 HTTPS://SOURCE.SAKAIPROJECT.ORG/SVN/MSGCNTR/TRUNK
# U    MESSAGEFORUMS-API/SRC/BUNDLE/ORG/SAKAIPROJECT/API/APP/MESSAGECENTER/BUNDLE/MESSAGES.PROPERTIES
# U    MESSAGEFORUMS-APP/SRC/JAVA/ORG/SAKAIPROJECT/TOOL/MESSAGEFORUMS/PRIVATEMESSAGESTOOL.JAVA
#
# SVN LOG -R 39571
# ------------------------------------------------------------------------
# R39571 | HU2@IUPUI.EDU | 2007-12-20 21:26:28 -0500 (THU, 20 DEC 2007) | 3 LINES
#
# SAK-12484
# REPLY ALL CC LIST SHOULD NOT INCLUDE THE CURRENT USER NAME.
# HTTP://JIRA.SAKAIPROJECT.ORG/JIRA/BROWSE/SAK-12484
# ------------------------------------------------------------------------
#
#
# ----------------------
# THIS AUTOMATIC NOTIFICATION MESSAGE WAS SENT BY SAKAI COLLAB (HTTPS://COLLAB.SAKAIPROJECT.ORG/PORTAL) FROM THE SOURCE SITE.
# YOU CAN MODIFY HOW YOU RECEIVE NOTIFICATIONS AT MY WORKSPACE > PREFERENCES.
#
#
#
# FROM GSILVER@UMICH.EDU FRI JAN  4 11:12:37 2008
# RETURN-PATH: <POSTMASTER@COLLAB.SAKAIPROJECT.ORG>
# RECEIVED: FROM MURDER (MAIL.UMICH.EDU [141.211.14.25])
# 	 BY FRANKENSTEIN.MAIL.UMICH.EDU (CYRUS V2.3.8) WITH LMTPA;
# 	 FRI, 04 JAN 2008 11:12:37 -0500
# X-SIEVE: CMU SIEVE 2.3
# RECEIVED: FROM MURDER ([UNIX SOCKET])
# 	 BY MAIL.UMICH.EDU (CYRUS V2.2.12) WITH LMTPA;
# 	 FRI, 04 JAN 2008 11:12:37 -0500
# RECEIVED: FROM HOLES.MR.ITD.UMICH.EDU (HOLES.MR.ITD.UMICH.EDU [141.211.14.79])
# 	BY PANTHER.MAIL.UMICH.EDU () WITH ESMTP ID M04GCAHB030887;
# 	FRI, 4 JAN 2008 11:12:36 -0500
# RECEIVED: FROM PAPLOO.UHI.AC.UK (APP1.PROD.COLLAB.UHI.AC.UK [194.35.219.184])
# 	BY HOLES.MR.ITD.UMICH.EDU ID 477E5AEB.E670B.28397 ;
# 	 4 JAN 2008 11:12:30 -0500
# RECEIVED: FROM PAPLOO.UHI.AC.UK (LOCALHOST [127.0.0.1])
# 	BY PAPLOO.UHI.AC.UK (POSTFIX) WITH ESMTP ID 99715BAE7D;
# 	FRI,  4 JAN 2008 16:12:27 +0000 (GMT)
# MESSAGE-ID: <200801041611.M04GB1LB007221@NAKAMURA.UITS.IUPUI.EDU>
# MIME-VERSION: 1.0
# CONTENT-TRANSFER-ENCODING: 7BIT
# RECEIVED: FROM PROD.COLLAB.UHI.AC.UK ([194.35.219.182])
#           BY PAPLOO.UHI.AC.UK (JAMES SMTP SERVER 2.1.3) WITH SMTP ID 272
#           FOR <SOURCE@COLLAB.SAKAIPROJECT.ORG>;
#           FRI, 4 JAN 2008 16:12:14 +0000 (GMT)
# RECEIVED: FROM NAKAMURA.UITS.IUPUI.EDU (NAKAMURA.UITS.IUPUI.EDU [134.68.220.122])
# 	BY SHMI.UHI.AC.UK (POSTFIX) WITH ESMTP ID 0A6ED42DFC
# 	FOR <SOURCE@COLLAB.SAKAIPROJECT.ORG>; FRI,  4 JAN 2008 16:12:12 +0000 (GMT)
# RECEIVED: FROM NAKAMURA.UITS.IUPUI.EDU (LOCALHOST [127.0.0.1])
# 	BY NAKAMURA.UITS.IUPUI.EDU (8.12.11.20060308/8.12.11) WITH ESMTP ID M04GB1WT007223
# 	FOR <SOURCE@COLLAB.SAKAIPROJECT.ORG>; FRI, 4 JAN 2008 11:11:01 -0500
# RECEIVED: (FROM APACHE@LOCALHOST)
# 	BY NAKAMURA.UITS.IUPUI.EDU (8.12.11.20060308/8.12.11/SUBMIT) ID M04GB1LB007221
# 	FOR SOURCE@COLLAB.SAKAIPROJECT.ORG; FRI, 4 JAN 2008 11:11:01 -0500
# DATE: FRI, 4 JAN 2008 11:11:01 -0500
# X-AUTHENTICATION-WARNING: NAKAMURA.UITS.IUPUI.EDU: APACHE SET SENDER TO GSILVER@UMICH.EDU USING -F
# TO: SOURCE@COLLAB.SAKAIPROJECT.ORG
# FROM: GSILVER@UMICH.EDU
# SUBJECT: [SAKAI] SVN COMMIT: R39762 - WEB/TRUNK/WEB-TOOL/TOOL/SRC/BUNDLE
# X-CONTENT-TYPE-OUTER-ENVELOPE: TEXT/PLAIN; CHARSET=UTF-8
# X-CONTENT-TYPE-MESSAGE-BODY: TEXT/PLAIN; CHARSET=UTF-8
# CONTENT-TYPE: TEXT/PLAIN; CHARSET=UTF-8
# X-DSPAM-RESULT: INNOCENT
# X-DSPAM-PROCESSED: FRI JAN  4 11:12:37 2008
# X-DSPAM-CONFIDENCE: 0.7601
# X-DSPAM-PROBABILITY: 0.0000
#
# DETAILS: HTTP://SOURCE.SAKAIPROJECT.ORG/VIEWSVN/?VIEW=REV&REV=39762
#
# AUTHOR: GSILVER@UMICH.EDU
# DATE: 2008-01-04 11:11:00 -0500 (FRI, 04 JAN 2008)
# NEW REVISION: 39762
#
# MODIFIED:
# WEB/TRUNK/WEB-TOOL/TOOL/SRC/BUNDLE/IFRAME.PROPERTIES
# LOG:
# SAK-12596
# HTTP://BUGS.SAKAIPROJECT.ORG/JIRA/BROWSE/SAK-12596
# - LEFT MOOT (UNUSED) ENTRIES COMMENTED FOR NOW
#
# ----------------------
# THIS AUTOMATIC NOTIFICATION MESSAGE WAS SENT BY SAKAI COLLAB (HTTPS://COLLAB.SAKAIPROJECT.ORG/PORTAL) FROM THE SOURCE SITE.
# YOU CAN MODIFY HOW YOU RECEIVE NOTIFICATIONS AT MY WORKSPACE > PREFERENCES.
#
#
#
# FROM GSILVER@UMICH.EDU FRI JAN  4 11:11:52 2008
# RETURN-PATH: <POSTMASTER@COLLAB.SAKAIPROJECT.ORG>
# RECEIVED: FROM MURDER (MAIL.UMICH.EDU [141.211.14.36])
# 	 BY FRANKENSTEIN.MAIL.UMICH.EDU (CYRUS V2.3.8) WITH LMTPA;
# 	 FRI, 04 JAN 2008 11:11:52 -0500
# X-SIEVE: CMU SIEVE 2.3
# RECEIVED: FROM MURDER ([UNIX SOCKET])
# 	 BY MAIL.UMICH.EDU (CYRUS V2.2.12) WITH LMTPA;
# 	 FRI, 04 JAN 2008 11:11:52 -0500
# RECEIVED: FROM CREEPSHOW.MR.ITD.UMICH.EDU (CREEPSHOW.MR.ITD.UMICH.EDU [141.211.14.84])
# 	BY GODSEND.MAIL.UMICH.EDU () WITH ESMTP ID M04GBQQV025330;
# 	FRI, 4 JAN 2008 11:11:52 -0500
# RECEIVED: FROM PAPLOO.UHI.AC.UK (APP1.PROD.COLLAB.UHI.AC.UK [194.35.219.184])
# 	BY CREEPSHOW.MR.ITD.UMICH.EDU ID 477E5AB3.5CC32.30840 ;
# 	 4 JAN 2008 11:11:34 -0500
# RECEIVED: FROM PAPLOO.UHI.AC.UK (LOCALHOST [127.0.0.1])
# 	BY PAPLOO.UHI.AC.UK (POSTFIX) WITH ESMTP ID 62AA4BAE46;
# 	FRI,  4 JAN 2008 16:11:31 +0000 (GMT)
# MESSAGE-ID: <200801041610.M04GA5KP007209@NAKAMURA.UITS.IUPUI.EDU>
# MIME-VERSION: 1.0
# CONTENT-TRANSFER-ENCODING: 7BIT
# RECEIVED: FROM PROD.COLLAB.UHI.AC.UK ([194.35.219.182])
#           BY PAPLOO.UHI.AC.UK (JAMES SMTP SERVER 2.1.3) WITH SMTP ID 1006
#           FOR <SOURCE@COLLAB.SAKAIPROJECT.ORG>;
#           FRI, 4 JAN 2008 16:11:18 +0000 (GMT)
# RECEIVED: FROM NAKAMURA.UITS.IUPUI.EDU (NAKAMURA.UITS.IUPUI.EDU [134.68.220.122])
# 	BY SHMI.UHI.AC.UK (POSTFIX) WITH ESMTP ID C596A3DFA2
# 	FOR <SOURCE@COLLAB.SAKAIPROJECT.ORG>; FRI,  4 JAN 2008 16:11:16 +0000 (GMT)
# RECEIVED: FROM NAKAMURA.UITS.IUPUI.EDU (LOCALHOST [127.0.0.1])
# 	BY NAKAMURA.UITS.IUPUI.EDU (8.12.11.20060308/8.12.11) WITH ESMTP ID M04GA5LR007211
# 	FOR <SOURCE@COLLAB.SAKAIPROJECT.ORG>; FRI, 4 JAN 2008 11:10:05 -0500
# RECEIVED: (FROM APACHE@LOCALHOST)
# 	BY NAKAMURA.UITS.IUPUI.EDU (8.12.11.20060308/8.12.11/SUBMIT) ID M04GA5KP007209
# 	FOR SOURCE@COLLAB.SAKAIPROJECT.ORG; FRI, 4 JAN 2008 11:10:05 -0500
# DATE: FRI, 4 JAN 2008 11:10:05 -0500
# X-AUTHENTICATION-WARNING: NAKAMURA.UITS.IUPUI.EDU: APACHE SET SENDER TO GSILVER@UMICH.EDU USING -F
# TO: SOURCE@COLLAB.SAKAIPROJECT.ORG
# FROM: GSILVER@UMICH.EDU
# SUBJECT: [SAKAI] SVN COMMIT: R39761 - SITE/TRUNK/SITE-TOOL/TOOL/SRC/BUNDLE
# X-CONTENT-TYPE-OUTER-ENVELOPE: TEXT/PLAIN; CHARSET=UTF-8
# X-CONTENT-TYPE-MESSAGE-BODY: TEXT/PLAIN; CHARSET=UTF-8
# CONTENT-TYPE: TEXT/PLAIN; CHARSET=UTF-8
# X-DSPAM-RESULT: INNOCENT
# X-DSPAM-PROCESSED: FRI JAN  4 11:11:52 2008
# X-DSPAM-CONFIDENCE: 0.7605
# X-DSPAM-PROBABILITY: 0.0000
#
# DETAILS: HTTP://SOURCE.SAKAIPROJECT.ORG/VIEWSVN/?VIEW=REV&REV=39761
#
# AUTHOR: GSILVER@UMICH.EDU
# DATE: 2008-01-04 11:10:04 -0500 (FRI, 04 JAN 2008)
# NEW REVISION: 39761
#
# MODIFIED:
# SITE/TRUNK/SITE-TOOL/TOOL/SRC/BUNDLE/ADMIN.PROPERTIES
# LOG:
# SAK-12595
# HTTP://BUGS.SAKAIPROJECT.ORG/JIRA/BROWSE/SAK-12595
# - LEFT MOOT (UNUSED) ENTRIES COMMENTED FOR NOW
#
# ----------------------
# THIS AUTOMATIC NOTIFICATION MESSAGE WAS SENT BY SAKAI COLLAB (HTTPS://COLLAB.SAKAIPROJECT.ORG/PORTAL) FROM THE SOURCE SITE.
# YOU CAN MODIFY HOW YOU RECEIVE NOTIFICATIONS AT MY WORKSPACE > PREFERENCES.
#
#
#
# FROM ZQIAN@UMICH.EDU FRI JAN  4 11:11:03 2008
# RETURN-PATH: <POSTMASTER@COLLAB.SAKAIPROJECT.ORG>
# RECEIVED: FROM MURDER (MAIL.UMICH.EDU [141.211.14.97])
# 	 BY FRANKENSTEIN.MAIL.UMICH.EDU (CYRUS V2.3.8) WITH LMTPA;
# 	 FRI, 04 JAN 2008 11:11:03 -0500
# X-SIEVE: CMU SIEVE 2.3
# RECEIVED: FROM MURDER ([UNIX SOCKET])
# 	 BY MAIL.UMICH.EDU (CYRUS V2.2.12) WITH LMTPA;
# 	 FRI, 04 JAN 2008 11:11:03 -0500
# RECEIVED: FROM CARRIE.MR.ITD.UMICH.EDU (CARRIE.MR.ITD.UMICH.EDU [141.211.93.152])
# 	BY SLEEPERS.MAIL.UMICH.EDU () WITH ESMTP ID M04GB3VG011502;
# 	FRI, 4 JAN 2008 11:11:03 -0500
# RECEIVED: FROM PAPLOO.UHI.AC.UK (APP1.PROD.COLLAB.UHI.AC.UK [194.35.219.184])
# 	BY CARRIE.MR.ITD.UMICH.EDU ID 477E5A8D.B378F.24200 ;
# 	 4 JAN 2008 11:10:56 -0500
# RECEIVED: FROM PAPLOO.UHI.AC.UK (LOCALHOST [127.0.0.1])
# 	BY PAPLOO.UHI.AC.UK (POSTFIX) WITH ESMTP ID C7251BAD44;
# 	FRI,  4 JAN 2008 16:10:53 +0000 (GMT)
# MESSAGE-ID: <200801041609.M04G9EUX007197@NAKAMURA.UITS.IUPUI.EDU>
# MIME-VERSION: 1.0
# CONTENT-TRANSFER-ENCODING: 7BIT
# RECEIVED: FROM PROD.COLLAB.UHI.AC.UK ([194.35.219.182])
#           BY PAPLOO.UHI.AC.UK (JAMES SMTP SERVER 2.1.3) WITH SMTP ID 483
#           FOR <SOURCE@COLLAB.SAKAIPROJECT.ORG>;
#           FRI, 4 JAN 2008 16:10:27 +0000 (GMT)
# RECEIVED: FROM NAKAMURA.UITS.IUPUI.EDU (NAKAMURA.UITS.IUPUI.EDU [134.68.220.122])
# 	BY SHMI.UHI.AC.UK (POSTFIX) WITH ESMTP ID 2E7043DFA2
# 	FOR <SOURCE@COLLAB.SAKAIPROJECT.ORG>; FRI,  4 JAN 2008 16:10:26 +0000 (GMT)
# RECEIVED: FROM NAKAMURA.UITS.IUPUI.EDU (LOCALHOST [127.0.0.1])
# 	BY NAKAMURA.UITS.IUPUI.EDU (8.12.11.20060308/8.12.11) WITH ESMTP ID M04G9EQG007199
# 	FOR <SOURCE@COLLAB.SAKAIPROJECT.ORG>; FRI, 4 JAN 2008 11:09:15 -0500
# RECEIVED: (FROM APACHE@LOCALHOST)
# 	BY NAKAMURA.UITS.IUPUI.EDU (8.12.11.20060308/8.12.11/SUBMIT) ID M04G9EUX007197
# 	FOR SOURCE@COLLAB.SAKAIPROJECT.ORG; FRI, 4 JAN 2008 11:09:14 -0500
# DATE: FRI, 4 JAN 2008 11:09:14 -0500
# X-AUTHENTICATION-WARNING: NAKAMURA.UITS.IUPUI.EDU: APACHE SET SENDER TO ZQIAN@UMICH.EDU USING -F
# TO: SOURCE@COLLAB.SAKAIPROJECT.ORG
# FROM: ZQIAN@UMICH.EDU
# SUBJECT: [SAKAI] SVN COMMIT: R39760 - IN SITE-MANAGE/TRUNK/SITE-MANAGE-TOOL/TOOL/SRC: JAVA/ORG/SAKAIPROJECT/SITE/TOOL WEBAPP/VM/SITESETUP
# X-CONTENT-TYPE-OUTER-ENVELOPE: TEXT/PLAIN; CHARSET=UTF-8
# X-CONTENT-TYPE-MESSAGE-BODY: TEXT/PLAIN; CHARSET=UTF-8
# CONTENT-TYPE: TEXT/PLAIN; CHARSET=UTF-8
# X-DSPAM-RESULT: INNOCENT
# X-DSPAM-PROCESSED: FRI JAN  4 11:11:03 2008
# X-DSPAM-CONFIDENCE: 0.6959
# X-DSPAM-PROBABILITY: 0.0000
#
# DETAILS: HTTP://SOURCE.SAKAIPROJECT.ORG/VIEWSVN/?VIEW=REV&REV=39760
#
# AUTHOR: ZQIAN@UMICH.EDU
# DATE: 2008-01-04 11:09:12 -0500 (FRI, 04 JAN 2008)
# NEW REVISION: 39760
#
# MODIFIED:
# SITE-MANAGE/TRUNK/SITE-MANAGE-TOOL/TOOL/SRC/JAVA/ORG/SAKAIPROJECT/SITE/TOOL/SITEACTION.JAVA
# SITE-MANAGE/TRUNK/SITE-MANAGE-TOOL/TOOL/SRC/WEBAPP/VM/SITESETUP/CHEF_SITE-SITEINFO-LIST.VM
# LOG:
# FIX TO SAK-10911: REFACTOR USE OF SITE.UPD, SITE.UPD.SITE.MBRSHIP AND SITE.UPD.GRP.MBRSHIP PERMISSIONS
#
# ----------------------
# THIS AUTOMATIC NOTIFICATION MESSAGE WAS SENT BY SAKAI COLLAB (HTTPS://COLLAB.SAKAIPROJECT.ORG/PORTAL) FROM THE SOURCE SITE.
# YOU CAN MODIFY HOW YOU RECEIVE NOTIFICATIONS AT MY WORKSPACE > PREFERENCES.
#
#
#
# FROM GSILVER@UMICH.EDU FRI JAN  4 11:10:22 2008
# RETURN-PATH: <POSTMASTER@COLLAB.SAKAIPROJECT.ORG>
# RECEIVED: FROM MURDER (MAIL.UMICH.EDU [141.211.14.39])
# 	 BY FRANKENSTEIN.MAIL.UMICH.EDU (CYRUS V2.3.8) WITH LMTPA;
# 	 FRI, 04 JAN 2008 11:10:22 -0500
# X-SIEVE: CMU SIEVE 2.3
# RECEIVED: FROM MURDER ([UNIX SOCKET])
# 	 BY MAIL.UMICH.EDU (CYRUS V2.2.12) WITH LMTPA;
# 	 FRI, 04 JAN 2008 11:10:22 -0500
# RECEIVED: FROM HOLES.MR.ITD.UMICH.EDU (HOLES.MR.ITD.UMICH.EDU [141.211.14.79])
# 	BY FAITHFUL.MAIL.UMICH.EDU () WITH ESMTP ID M04GAL9K010604;
# 	FRI, 4 JAN 2008 11:10:21 -0500
# RECEIVED: FROM PAPLOO.UHI.AC.UK (APP1.PROD.COLLAB.UHI.AC.UK [194.35.219.184])
# 	BY HOLES.MR.ITD.UMICH.EDU ID 477E5A67.34350.23015 ;
# 	 4 JAN 2008 11:10:18 -0500
# RECEIVED: FROM PAPLOO.UHI.AC.UK (LOCALHOST [127.0.0.1])
# 	BY PAPLOO.UHI.AC.UK (POSTFIX) WITH ESMTP ID 98D04BAD43;
# 	FRI,  4 JAN 2008 16:10:11 +0000 (GMT)
# MESSAGE-ID: <200801041608.M04G8D7W007184@NAKAMURA.UITS.IUPUI.EDU>
# MIME-VERSION: 1.0
# CONTENT-TRANSFER-ENCODING: 7BIT
# RECEIVED: FROM PROD.COLLAB.UHI.AC.UK ([194.35.219.182])
#           BY PAPLOO.UHI.AC.UK (JAMES SMTP SERVER 2.1.3) WITH SMTP ID 966
#           FOR <SOURCE@COLLAB.SAKAIPROJECT.ORG>;
#           FRI, 4 JAN 2008 16:09:51 +0000 (GMT)
# RECEIVED: FROM NAKAMURA.UITS.IUPUI.EDU (NAKAMURA.UITS.IUPUI.EDU [134.68.220.122])
# 	BY SHMI.UHI.AC.UK (POSTFIX) WITH ESMTP ID 9F89542DD0
# 	FOR <SOURCE@COLLAB.SAKAIPROJECT.ORG>; FRI,  4 JAN 2008 16:09:50 +0000 (GMT)
# RECEIVED: FROM NAKAMURA.UITS.IUPUI.EDU (LOCALHOST [127.0.0.1])
# 	BY NAKAMURA.UITS.IUPUI.EDU (8.12.11.20060308/8.12.11) WITH ESMTP ID M04G8DXN007186
# 	FOR <SOURCE@COLLAB.SAKAIPROJECT.ORG>; FRI, 4 JAN 2008 11:08:39 -0500
# RECEIVED: (FROM APACHE@LOCALHOST)
# 	BY NAKAMURA.UITS.IUPUI.EDU (8.12.11.20060308/8.12.11/SUBMIT) ID M04G8D7W007184
# 	FOR SOURCE@COLLAB.SAKAIPROJECT.ORG; FRI, 4 JAN 2008 11:08:39 -0500
# DATE: FRI, 4 JAN 2008 11:08:39 -0500
# X-AUTHENTICATION-WARNING: NAKAMURA.UITS.IUPUI.EDU: APACHE SET SENDER TO GSILVER@UMICH.EDU USING -F
# TO: SOURCE@COLLAB.SAKAIPROJECT.ORG
# FROM: GSILVER@UMICH.EDU
# SUBJECT: [SAKAI] SVN COMMIT: R39759 - MAILARCHIVE/TRUNK/MAILARCHIVE-TOOL/TOOL/SRC/BUNDLE
# X-CONTENT-TYPE-OUTER-ENVELOPE: TEXT/PLAIN; CHARSET=UTF-8
# X-CONTENT-TYPE-MESSAGE-BODY: TEXT/PLAIN; CHARSET=UTF-8
# CONTENT-TYPE: TEXT/PLAIN; CHARSET=UTF-8
# X-DSPAM-RESULT: INNOCENT
# X-DSPAM-PROCESSED: FRI JAN  4 11:10:22 2008
# X-DSPAM-CONFIDENCE: 0.7606
# X-DSPAM-PROBABILITY: 0.0000
#
# DETAILS: HTTP://SOURCE.SAKAIPROJECT.ORG/VIEWSVN/?VIEW=REV&REV=39759
#
# AUTHOR: GSILVER@UMICH.EDU
# DATE: 2008-01-04 11:08:38 -0500 (FRI, 04 JAN 2008)
# NEW REVISION: 39759
#
# MODIFIED:
# MAILARCHIVE/TRUNK/MAILARCHIVE-TOOL/TOOL/SRC/BUNDLE/EMAIL.PROPERTIES
# LOG:
# SAK-12592
# HTTP://BUGS.SAKAIPROJECT.ORG/JIRA/BROWSE/SAK-12592
# - LEFT MOOT (UNUSED) ENTRIES COMMENTED FOR NOW
#
# ----------------------
# THIS AUTOMATIC NOTIFICATION MESSAGE WAS SENT BY SAKAI COLLAB (HTTPS://COLLAB.SAKAIPROJECT.ORG/PORTAL) FROM THE SOURCE SITE.
# YOU CAN MODIFY HOW YOU RECEIVE NOTIFICATIONS AT MY WORKSPACE > PREFERENCES.
#
#
#
# FROM WAGNERMR@IUPUI.EDU FRI JAN  4 10:38:42 2008
# RETURN-PATH: <POSTMASTER@COLLAB.SAKAIPROJECT.ORG>
# RECEIVED: FROM MURDER (MAIL.UMICH.EDU [141.211.14.90])
# 	 BY FRANKENSTEIN.MAIL.UMICH.EDU (CYRUS V2.3.8) WITH LMTPA;
# 	 FRI, 04 JAN 2008 10:38:42 -0500
# X-SIEVE: CMU SIEVE 2.3
# RECEIVED: FROM MURDER ([UNIX SOCKET])
# 	 BY MAIL.UMICH.EDU (CYRUS V2.2.12) WITH LMTPA;
# 	 FRI, 04 JAN 2008 10:38:42 -0500
# RECEIVED: FROM SHINING.MR.ITD.UMICH.EDU (SHINING.MR.ITD.UMICH.EDU [141.211.93.153])
# 	BY FLAWLESS.MAIL.UMICH.EDU () WITH ESMTP ID M04FCFJM012313;
# 	FRI, 4 JAN 2008 10:38:41 -0500
# RECEIVED: FROM PAPLOO.UHI.AC.UK (APP1.PROD.COLLAB.UHI.AC.UK [194.35.219.184])
# 	BY SHINING.MR.ITD.UMICH.EDU ID 477E52FA.E6C6E.24093 ;
# 	 4 JAN 2008 10:38:37 -0500
# RECEIVED: FROM PAPLOO.UHI.AC.UK (LOCALHOST [127.0.0.1])
# 	BY PAPLOO.UHI.AC.UK (POSTFIX) WITH ESMTP ID 6A39594CD2;
# 	FRI,  4 JAN 2008 15:37:36 +0000 (GMT)
# MESSAGE-ID: <200801041537.M04FB6CI007092@NAKAMURA.UITS.IUPUI.EDU>
# MIME-VERSION: 1.0
# CONTENT-TRANSFER-ENCODING: 7BIT
# RECEIVED: FROM PROD.COLLAB.UHI.AC.UK ([194.35.219.182])
#           BY PAPLOO.UHI.AC.UK (JAMES SMTP SERVER 2.1.3) WITH SMTP ID 690
#           FOR <SOURCE@COLLAB.SAKAIPROJECT.ORG>;
#           FRI, 4 JAN 2008 15:37:21 +0000 (GMT)
# RECEIVED: FROM NAKAMURA.UITS.IUPUI.EDU (NAKAMURA.UITS.IUPUI.EDU [134.68.220.122])
# 	BY SHMI.UHI.AC.UK (POSTFIX) WITH ESMTP ID CEFA037ACE
# 	FOR <SOURCE@COLLAB.SAKAIPROJECT.ORG>; FRI,  4 JAN 2008 15:38:17 +0000 (GMT)
# RECEIVED: FROM NAKAMURA.UITS.IUPUI.EDU (LOCALHOST [127.0.0.1])
# 	BY NAKAMURA.UITS.IUPUI.EDU (8.12.11.20060308/8.12.11) WITH ESMTP ID M04FB6NH007094
# 	FOR <SOURCE@COLLAB.SAKAIPROJECT.ORG>; FRI, 4 JAN 2008 10:37:06 -0500
# RECEIVED: (FROM APACHE@LOCALHOST)
# 	BY NAKAMURA.UITS.IUPUI.EDU (8.12.11.20060308/8.12.11/SUBMIT) ID M04FB6CI007092
# 	FOR SOURCE@COLLAB.SAKAIPROJECT.ORG; FRI, 4 JAN 2008 10:37:06 -0500
# DATE: FRI, 4 JAN 2008 10:37:06 -0500
# X-AUTHENTICATION-WARNING: NAKAMURA.UITS.IUPUI.EDU: APACHE SET SENDER TO WAGNERMR@IUPUI.EDU USING -F
# TO: SOURCE@COLLAB.SAKAIPROJECT.ORG
# FROM: WAGNERMR@IUPUI.EDU
# SUBJECT: [SAKAI] SVN COMMIT: R39758 - IN GRADEBOOK/TRUNK: APP/BUSINESS/SRC/JAVA/ORG/SAKAIPROJECT/TOOL/GRADEBOOK/BUSINESS/IMPL SERVICE/API/SRC/JAVA/ORG/SAKAIPROJECT/SERVICE/GRADEBOOK/SHARED SERVICE/IMPL/SRC/JAVA/ORG/SAKAIPROJECT/COMPONENT/GRADEBOOK
# X-CONTENT-TYPE-OUTER-ENVELOPE: TEXT/PLAIN; CHARSET=UTF-8
# X-CONTENT-TYPE-MESSAGE-BODY: TEXT/PLAIN; CHARSET=UTF-8
# CONTENT-TYPE: TEXT/PLAIN; CHARSET=UTF-8
# X-DSPAM-RESULT: INNOCENT
# X-DSPAM-PROCESSED: FRI JAN  4 10:38:42 2008
# X-DSPAM-CONFIDENCE: 0.7559
# X-DSPAM-PROBABILITY: 0.0000
#
# DETAILS: HTTP://SOURCE.SAKAIPROJECT.ORG/VIEWSVN/?VIEW=REV&REV=39758
#
# AUTHOR: WAGNERMR@IUPUI.EDU
# DATE: 2008-01-04 10:37:04 -0500 (FRI, 04 JAN 2008)
# NEW REVISION: 39758
#
# MODIFIED:
# GRADEBOOK/TRUNK/APP/BUSINESS/SRC/JAVA/ORG/SAKAIPROJECT/TOOL/GRADEBOOK/BUSINESS/IMPL/GRADEBOOKMANAGERHIBERNATEIMPL.JAVA
# GRADEBOOK/TRUNK/SERVICE/API/SRC/JAVA/ORG/SAKAIPROJECT/SERVICE/GRADEBOOK/SHARED/GRADEBOOKSERVICE.JAVA
# GRADEBOOK/TRUNK/SERVICE/IMPL/SRC/JAVA/ORG/SAKAIPROJECT/COMPONENT/GRADEBOOK/GRADEBOOKSERVICEHIBERNATEIMPL.JAVA
# LOG:
# SAK-12175
# HTTP://BUGS.SAKAIPROJECT.ORG/JIRA/BROWSE/SAK-12175
# CREATE METHODS REQUIRED FOR GB INTEGRATION WITH THE ASSIGNMENT2 TOOL
# GETGRADEDEFINITIONFORSTUDENTFORITEM
#
# ----------------------
# THIS AUTOMATIC NOTIFICATION MESSAGE WAS SENT BY SAKAI COLLAB (HTTPS://COLLAB.SAKAIPROJECT.ORG/PORTAL) FROM THE SOURCE SITE.
# YOU CAN MODIFY HOW YOU RECEIVE NOTIFICATIONS AT MY WORKSPACE > PREFERENCES.
#
#
#
# FROM ZQIAN@UMICH.EDU FRI JAN  4 10:17:43 2008
# RETURN-PATH: <POSTMASTER@COLLAB.SAKAIPROJECT.ORG>
# RECEIVED: FROM MURDER (MAIL.UMICH.EDU [141.211.14.97])
# 	 BY FRANKENSTEIN.MAIL.UMICH.EDU (CYRUS V2.3.8) WITH LMTPA;
# 	 FRI, 04 JAN 2008 10:17:43 -0500
# X-SIEVE: CMU SIEVE 2.3
# RECEIVED: FROM MURDER ([UNIX SOCKET])
# 	 BY MAIL.UMICH.EDU (CYRUS V2.2.12) WITH LMTPA;
# 	 FRI, 04 JAN 2008 10:17:42 -0500
# RECEIVED: FROM CREEPSHOW.MR.ITD.UMICH.EDU (CREEPSHOW.MR.ITD.UMICH.EDU [141.211.14.84])
# 	BY SLEEPERS.MAIL.UMICH.EDU () WITH ESMTP ID M04FHGFS011536;
# 	FRI, 4 JAN 2008 10:17:42 -0500
# RECEIVED: FROM PAPLOO.UHI.AC.UK (APP1.PROD.COLLAB.UHI.AC.UK [194.35.219.184])
# 	BY CREEPSHOW.MR.ITD.UMICH.EDU ID 477E4E0F.CCA4B.926 ;
# 	 4 JAN 2008 10:17:38 -0500
# RECEIVED: FROM PAPLOO.UHI.AC.UK (LOCALHOST [127.0.0.1])
# 	BY PAPLOO.UHI.AC.UK (POSTFIX) WITH ESMTP ID BD02DBAC64;
# 	FRI,  4 JAN 2008 15:17:34 +0000 (GMT)
# MESSAGE-ID: <200801041515.M04FFV42007050@NAKAMURA.UITS.IUPUI.EDU>
# MIME-VERSION: 1.0
# CONTENT-TRANSFER-ENCODING: 7BIT
# RECEIVED: FROM PROD.COLLAB.UHI.AC.UK ([194.35.219.182])
#           BY PAPLOO.UHI.AC.UK (JAMES SMTP SERVER 2.1.3) WITH SMTP ID 25
#           FOR <SOURCE@COLLAB.SAKAIPROJECT.ORG>;
#           FRI, 4 JAN 2008 15:17:11 +0000 (GMT)
# RECEIVED: FROM NAKAMURA.UITS.IUPUI.EDU (NAKAMURA.UITS.IUPUI.EDU [134.68.220.122])
# 	BY SHMI.UHI.AC.UK (POSTFIX) WITH ESMTP ID 5B396236B9
# 	FOR <SOURCE@COLLAB.SAKAIPROJECT.ORG>; FRI,  4 JAN 2008 15:17:08 +0000 (GMT)
# RECEIVED: FROM NAKAMURA.UITS.IUPUI.EDU (LOCALHOST [127.0.0.1])
# 	BY NAKAMURA.UITS.IUPUI.EDU (8.12.11.20060308/8.12.11) WITH ESMTP ID M04FFV85007052
# 	FOR <SOURCE@COLLAB.SAKAIPROJECT.ORG>; FRI, 4 JAN 2008 10:15:57 -0500
# RECEIVED: (FROM APACHE@LOCALHOST)
# 	BY NAKAMURA.UITS.IUPUI.EDU (8.12.11.20060308/8.12.11/SUBMIT) ID M04FFV42007050
# 	FOR SOURCE@COLLAB.SAKAIPROJECT.ORG; FRI, 4 JAN 2008 10:15:57 -0500
# DATE: FRI, 4 JAN 2008 10:15:57 -0500
# X-AUTHENTICATION-WARNING: NAKAMURA.UITS.IUPUI.EDU: APACHE SET SENDER TO ZQIAN@UMICH.EDU USING -F
# TO: SOURCE@COLLAB.SAKAIPROJECT.ORG
# FROM: ZQIAN@UMICH.EDU
# SUBJECT: [SAKAI] SVN COMMIT: R39757 - IN ASSIGNMENT/TRUNK: ASSIGNMENT-IMPL/IMPL/SRC/JAVA/ORG/SAKAIPROJECT/ASSIGNMENT/IMPL ASSIGNMENT-TOOL/TOOL/SRC/WEBAPP/VM/ASSIGNMENT
# X-CONTENT-TYPE-OUTER-ENVELOPE: TEXT/PLAIN; CHARSET=UTF-8
# X-CONTENT-TYPE-MESSAGE-BODY: TEXT/PLAIN; CHARSET=UTF-8
# CONTENT-TYPE: TEXT/PLAIN; CHARSET=UTF-8
# X-DSPAM-RESULT: INNOCENT
# X-DSPAM-PROCESSED: FRI JAN  4 10:17:42 2008
# X-DSPAM-CONFIDENCE: 0.7605
# X-DSPAM-PROBABILITY: 0.0000
#
# DETAILS: HTTP://SOURCE.SAKAIPROJECT.ORG/VIEWSVN/?VIEW=REV&REV=39757
#
# AUTHOR: ZQIAN@UMICH.EDU
# DATE: 2008-01-04 10:15:54 -0500 (FRI, 04 JAN 2008)
# NEW REVISION: 39757
#
# MODIFIED:
# ASSIGNMENT/TRUNK/ASSIGNMENT-IMPL/IMPL/SRC/JAVA/ORG/SAKAIPROJECT/ASSIGNMENT/IMPL/BASEASSIGNMENTSERVICE.JAVA
# ASSIGNMENT/TRUNK/ASSIGNMENT-TOOL/TOOL/SRC/WEBAPP/VM/ASSIGNMENT/CHEF_ASSIGNMENTS_INSTRUCTOR_LIST_SUBMISSIONS.VM
# LOG:
# FIX TO SAK-12604:DON'T SHOW GROUPS/SECTIONS FILTER IF THE SITE DOESN'T HAVE ANY
#
# ----------------------
# THIS AUTOMATIC NOTIFICATION MESSAGE WAS SENT BY SAKAI COLLAB (HTTPS://COLLAB.SAKAIPROJECT.ORG/PORTAL) FROM THE SOURCE SITE.
# YOU CAN MODIFY HOW YOU RECEIVE NOTIFICATIONS AT MY WORKSPACE > PREFERENCES.
#
#
#
# FROM ANTRANIG@CARET.CAM.AC.UK FRI JAN  4 10:04:14 2008
# RETURN-PATH: <POSTMASTER@COLLAB.SAKAIPROJECT.ORG>
# RECEIVED: FROM MURDER (MAIL.UMICH.EDU [141.211.14.25])
# 	 BY FRANKENSTEIN.MAIL.UMICH.EDU (CYRUS V2.3.8) WITH LMTPA;
# 	 FRI, 04 JAN 2008 10:04:14 -0500
# X-SIEVE: CMU SIEVE 2.3
# RECEIVED: FROM MURDER ([UNIX SOCKET])
# 	 BY MAIL.UMICH.EDU (CYRUS V2.2.12) WITH LMTPA;
# 	 FRI, 04 JAN 2008 10:04:14 -0500
# RECEIVED: FROM HOLES.MR.ITD.UMICH.EDU (HOLES.MR.ITD.UMICH.EDU [141.211.14.79])
# 	BY PANTHER.MAIL.UMICH.EDU () WITH ESMTP ID M04F4DCI015108;
# 	FRI, 4 JAN 2008 10:04:13 -0500
# RECEIVED: FROM PAPLOO.UHI.AC.UK (APP1.PROD.COLLAB.UHI.AC.UK [194.35.219.184])
# 	BY HOLES.MR.ITD.UMICH.EDU ID 477E4AE3.D7AF.31669 ;
# 	 4 JAN 2008 10:04:05 -0500
# RECEIVED: FROM PAPLOO.UHI.AC.UK (LOCALHOST [127.0.0.1])
# 	BY PAPLOO.UHI.AC.UK (POSTFIX) WITH ESMTP ID 933E3BAC17;
# 	FRI,  4 JAN 2008 15:04:00 +0000 (GMT)
# ...
# 	 BY FRANKENSTEIN.MAIL.UMICH.EDU (CYRUS V2.3.8) WITH LMTPA;
# 	 THU, 03 JAN 2008 17:18:23 -0500
# X-SIEVE: CMU SIEVE 2.3
# RECEIVED: FROM MURDER ([UNIX SOCKET])
# 	 BY MAIL.UMICH.EDU (CYRUS V2.2.12) WITH LMTPA;
# 	 THU, 03 JAN 2008 17:18:23 -0500
# RECEIVED: FROM SALEMSLOT.MR.ITD.UMICH.EDU (SALEMSLOT.MR.ITD.UMICH.EDU [141.211.14.58])
# 	BY JACKNIFE.MAIL.UMICH.EDU () WITH ESMTP ID M03MIMXY027729;
# 	THU, 3 JAN 2008 17:18:22 -0500
# RECEIVED: FROM PAPLOO.UHI.AC.UK (APP1.PROD.COLLAB.UHI.AC.UK [194.35.219.184])
# 	BY SALEMSLOT.MR.ITD.UMICH.EDU ID 477D5F23.797F6.16348 ;
# 	 3 JAN 2008 17:18:14 -0500
# RECEIVED: FROM PAPLOO.UHI.AC.UK (LOCALHOST [127.0.0.1])
# 	BY PAPLOO.UHI.AC.UK (POSTFIX) WITH ESMTP ID EF439B98CE;
# 	THU,  3 JAN 2008 22:18:19 +0000 (GMT)
# MESSAGE-ID: <200801032216.M03MGHDA005292@NAKAMURA.UITS.IUPUI.EDU>
# MIME-VERSION: 1.0
# CONTENT-TRANSFER-ENCODING: 7BIT
# RECEIVED: FROM PROD.COLLAB.UHI.AC.UK ([194.35.219.182])
#           BY PAPLOO.UHI.AC.UK (JAMES SMTP SERVER 2.1.3) WITH SMTP ID 236
#           FOR <SOURCE@COLLAB.SAKAIPROJECT.ORG>;
#           THU, 3 JAN 2008 22:18:04 +0000 (GMT)
# RECEIVED: FROM NAKAMURA.UITS.IUPUI.EDU (NAKAMURA.UITS.IUPUI.EDU [134.68.220.122])
# 	BY SHMI.UHI.AC.UK (POSTFIX) WITH ESMTP ID 905D53C2FD
# 	FOR <SOURCE@COLLAB.SAKAIPROJECT.ORG>; THU,  3 JAN 2008 22:17:52 +0000 (GMT)
# RECEIVED: FROM NAKAMURA.UITS.IUPUI.EDU (LOCALHOST [127.0.0.1])
# 	BY NAKAMURA.UITS.IUPUI.EDU (8.12.11.20060308/8.12.11) WITH ESMTP ID M03MGHRS005294
# 	FOR <SOURCE@COLLAB.SAKAIPROJECT.ORG>; THU, 3 JAN 2008 17:16:43 -0500
# RECEIVED: (FROM APACHE@LOCALHOST)
# 	BY NAKAMURA.UITS.IUPUI.EDU (8.12.11.20060308/8.12.11/SUBMIT) ID M03MGHDA005292
# 	FOR SOURCE@COLLAB.SAKAIPROJECT.ORG; THU, 3 JAN 2008 17:16:43 -0500
# DATE: THU, 3 JAN 2008 17:16:43 -0500
# X-AUTHENTICATION-WARNING: NAKAMURA.UITS.IUPUI.EDU: APACHE SET SENDER TO LOUIS@MEDIA.BERKELEY.EDU USING -F
# TO: SOURCE@COLLAB.SAKAIPROJECT.ORG
# FROM: LOUIS@MEDIA.BERKELEY.EDU
# SUBJECT: [SAKAI] SVN COMMIT: R39746 - IN BSPACE/SITE-MANAGE/SAKAI_2-4-X/SITE-MANAGE-TOOL/TOOL/SRC: BUNDLE WEBAPP/VM/SITESETUP
# X-CONTENT-TYPE-OUTER-ENVELOPE: TEXT/PLAIN; CHARSET=UTF-8
# X-CONTENT-TYPE-MESSAGE-BODY: TEXT/PLAIN; CHARSET=UTF-8
# CONTENT-TYPE: TEXT/PLAIN; CHARSET=UTF-8
# X-DSPAM-RESULT: INNOCENT
# X-DSPAM-PROCESSED: THU JAN  3 17:18:23 2008
# X-DSPAM-CONFIDENCE: 0.6959
# X-DSPAM-PROBABILITY: 0.0000
#
# DETAILS: HTTP://SOURCE.SAKAIPROJECT.ORG/VIEWSVN/?VIEW=REV&REV=39746
#
# AUTHOR: LOUIS@MEDIA.BERKELEY.EDU
# DATE: 2008-01-03 17:16:39 -0500 (THU, 03 JAN 2008)
# NEW REVISION: 39746
#
# MODIFIED:
# BSPACE/SITE-MANAGE/SAKAI_2-4-X/SITE-MANAGE-TOOL/TOOL/SRC/BUNDLE/SITESETUPGENERIC.PROPERTIES
# BSPACE/SITE-MANAGE/SAKAI_2-4-X/SITE-MANAGE-TOOL/TOOL/SRC/WEBAPP/VM/SITESETUP/CHEF_SITE-SITEINFO-DUPLICATE.VM
# LOG:
# BSP-1421 ADD TEXT TO CLARIFY "DUPLICATE SITE" OPTION IN SITE INFO
#
# ----------------------
# THIS AUTOMATIC NOTIFICATION MESSAGE WAS SENT BY SAKAI COLLAB (HTTPS://COLLAB.SAKAIPROJECT.ORG/PORTAL) FROM THE SOURCE SITE.
# YOU CAN MODIFY HOW YOU RECEIVE NOTIFICATIONS AT MY WORKSPACE > PREFERENCES.
#
#
#
# FROM RAY@MEDIA.BERKELEY.EDU THU JAN  3 17:07:00 2008
# RETURN-PATH: <POSTMASTER@COLLAB.SAKAIPROJECT.ORG>
# RECEIVED: FROM MURDER (MAIL.UMICH.EDU [141.211.14.39])
# 	 BY FRANKENSTEIN.MAIL.UMICH.EDU (CYRUS V2.3.8) WITH LMTPA;
# 	 THU, 03 JAN 2008 17:07:00 -0500
# X-SIEVE: CMU SIEVE 2.3
# RECEIVED: FROM MURDER ([UNIX SOCKET])
# 	 BY MAIL.UMICH.EDU (CYRUS V2.2.12) WITH LMTPA;
# 	 THU, 03 JAN 2008 17:07:00 -0500
# RECEIVED: FROM ANNIEHALL.MR.ITD.UMICH.EDU (ANNIEHALL.MR.ITD.UMICH.EDU [141.211.93.141])
# 	BY FAITHFUL.MAIL.UMICH.EDU () WITH ESMTP ID M03M6XAQ014868;
# 	THU, 3 JAN 2008 17:06:59 -0500
# RECEIVED: FROM PAPLOO.UHI.AC.UK (APP1.PROD.COLLAB.UHI.AC.UK [194.35.219.184])
# 	BY ANNIEHALL.MR.ITD.UMICH.EDU ID 477D5C7A.4FE1F.22211 ;
# 	 3 JAN 2008 17:06:53 -0500
# RECEIVED: FROM PAPLOO.UHI.AC.UK (LOCALHOST [127.0.0.1])
# 	BY PAPLOO.UHI.AC.UK (POSTFIX) WITH ESMTP ID 0BC8D7225E;
# 	THU,  3 JAN 2008 22:06:57 +0000 (GMT)
# MESSAGE-ID: <200801032205.M03M5EA7005273@NAKAMURA.UITS.IUPUI.EDU>
# MIME-VERSION: 1.0
# CONTENT-TRANSFER-ENCODING: 7BIT
# RECEIVED: FROM PROD.COLLAB.UHI.AC.UK ([194.35.219.182])
#           BY PAPLOO.UHI.AC.UK (JAMES SMTP SERVER 2.1.3) WITH SMTP ID 554
#           FOR <SOURCE@COLLAB.SAKAIPROJECT.ORG>;
#           THU, 3 JAN 2008 22:06:34 +0000 (GMT)
# RECEIVED: FROM NAKAMURA.UITS.IUPUI.EDU (NAKAMURA.UITS.IUPUI.EDU [134.68.220.122])
# 	BY SHMI.UHI.AC.UK (POSTFIX) WITH ESMTP ID 2AB513C2FD
# 	FOR <SOURCE@COLLAB.SAKAIPROJECT.ORG>; THU,  3 JAN 2008 22:06:23 +0000 (GMT)
# RECEIVED: FROM NAKAMURA.UITS.IUPUI.EDU (LOCALHOST [127.0.0.1])
# 	BY NAKAMURA.UITS.IUPUI.EDU (8.12.11.20060308/8.12.11) WITH ESMTP ID M03M5EQA005275
# 	FOR <SOURCE@COLLAB.SAKAIPROJECT.ORG>; THU, 3 JAN 2008 17:05:14 -0500
# RECEIVED: (FROM APACHE@LOCALHOST)
# 	BY NAKAMURA.UITS.IUPUI.EDU (8.12.11.20060308/8.12.11/SUBMIT) ID M03M5EA7005273
# 	FOR SOURCE@COLLAB.SAKAIPROJECT.ORG; THU, 3 JAN 2008 17:05:14 -0500
# DATE: THU, 3 JAN 2008 17:05:14 -0500
# X-AUTHENTICATION-WARNING: NAKAMURA.UITS.IUPUI.EDU: APACHE SET SENDER TO RAY@MEDIA.BERKELEY.EDU USING -F
# TO: SOURCE@COLLAB.SAKAIPROJECT.ORG
# FROM: RAY@MEDIA.BERKELEY.EDU
# SUBJECT: [SAKAI] SVN COMMIT: R39745 - PROVIDERS/TRUNK/CM/CM-AUTHZ-PROVIDER/SRC/JAVA/ORG/SAKAIPROJECT/COURSEMANAGEMENT/IMPL/PROVIDER
# X-CONTENT-TYPE-OUTER-ENVELOPE: TEXT/PLAIN; CHARSET=UTF-8
# X-CONTENT-TYPE-MESSAGE-BODY: TEXT/PLAIN; CHARSET=UTF-8
# CONTENT-TYPE: TEXT/PLAIN; CHARSET=UTF-8
# X-DSPAM-RESULT: INNOCENT
# X-DSPAM-PROCESSED: THU JAN  3 17:07:00 2008
# X-DSPAM-CONFIDENCE: 0.7556
# X-DSPAM-PROBABILITY: 0.0000
#
# DETAILS: HTTP://SOURCE.SAKAIPROJECT.ORG/VIEWSVN/?VIEW=REV&REV=39745
#
# AUTHOR: RAY@MEDIA.BERKELEY.EDU
# DATE: 2008-01-03 17:05:11 -0500 (THU, 03 JAN 2008)
# NEW REVISION: 39745
#
# MODIFIED:
# PROVIDERS/TRUNK/CM/CM-AUTHZ-PROVIDER/SRC/JAVA/ORG/SAKAIPROJECT/COURSEMANAGEMENT/IMPL/PROVIDER/COURSEMANAGEMENTGROUPPROVIDER.JAVA
# LOG:
# SAK-12602 FIX LOGIC WHEN A USER HAS MULTIPLE ROLES IN A SECTION
#
# ----------------------
# THIS AUTOMATIC NOTIFICATION MESSAGE WAS SENT BY SAKAI COLLAB (HTTPS://COLLAB.SAKAIPROJECT.ORG/PORTAL) FROM THE SOURCE SITE.
# YOU CAN MODIFY HOW YOU RECEIVE NOTIFICATIONS AT MY WORKSPACE > PREFERENCES.
#
#
#
# FROM CWEN@IUPUI.EDU THU JAN  3 16:34:40 2008
# RETURN-PATH: <POSTMASTER@COLLAB.SAKAIPROJECT.ORG>
# RECEIVED: FROM MURDER (MAIL.UMICH.EDU [141.211.14.34])
# 	 BY FRANKENSTEIN.MAIL.UMICH.EDU (CYRUS V2.3.8) WITH LMTPA;
# 	 THU, 03 JAN 2008 16:34:40 -0500
# X-SIEVE: CMU SIEVE 2.3
# RECEIVED: FROM MURDER ([UNIX SOCKET])
# 	 BY MAIL.UMICH.EDU (CYRUS V2.2.12) WITH LMTPA;
# 	 THU, 03 JAN 2008 16:34:40 -0500
# RECEIVED: FROM ICESTORM.MR.ITD.UMICH.EDU (ICESTORM.MR.ITD.UMICH.EDU [141.211.93.149])
# 	BY CHAOS.MAIL.UMICH.EDU () WITH ESMTP ID M03LYDY1029538;
# 	THU, 3 JAN 2008 16:34:39 -0500
# RECEIVED: FROM PAPLOO.UHI.AC.UK (APP1.PROD.COLLAB.UHI.AC.UK [194.35.219.184])
# 	BY ICESTORM.MR.ITD.UMICH.EDU ID 477D54EA.13F34.26602 ;
# 	 3 JAN 2008 16:34:36 -0500
# RECEIVED: FROM PAPLOO.UHI.AC.UK (LOCALHOST [127.0.0.1])
# 	BY PAPLOO.UHI.AC.UK (POSTFIX) WITH ESMTP ID CC710ADC79;
# 	THU,  3 JAN 2008 21:34:29 +0000 (GMT)
# MESSAGE-ID: <200801032133.M03LX3GG005191@NAKAMURA.UITS.IUPUI.EDU>
# MIME-VERSION: 1.0
# CONTENT-TRANSFER-ENCODING: 7BIT
# RECEIVED: FROM PROD.COLLAB.UHI.AC.UK ([194.35.219.182])
#           BY PAPLOO.UHI.AC.UK (JAMES SMTP SERVER 2.1.3) WITH SMTP ID 611
#           FOR <SOURCE@COLLAB.SAKAIPROJECT.ORG>;
#           THU, 3 JAN 2008 21:34:08 +0000 (GMT)
# RECEIVED: FROM NAKAMURA.UITS.IUPUI.EDU (NAKAMURA.UITS.IUPUI.EDU [134.68.220.122])
# 	BY SHMI.UHI.AC.UK (POSTFIX) WITH ESMTP ID 43C4242B55
# 	FOR <SOURCE@COLLAB.SAKAIPROJECT.ORG>; THU,  3 JAN 2008 21:34:12 +0000 (GMT)
# RECEIVED: FROM NAKAMURA.UITS.IUPUI.EDU (LOCALHOST [127.0.0.1])
# 	BY NAKAMURA.UITS.IUPUI.EDU (8.12.11.20060308/8.12.11) WITH ESMTP ID M03LX3VB005193
# 	FOR <SOURCE@COLLAB.SAKAIPROJECT.ORG>; THU, 3 JAN 2008 16:33:03 -0500
# RECEIVED: (FROM APACHE@LOCALHOST)
# 	BY NAKAMURA.UITS.IUPUI.EDU (8.12.11.20060308/8.12.11/SUBMIT) ID M03LX3GG005191
# 	FOR SOURCE@COLLAB.SAKAIPROJECT.ORG; THU, 3 JAN 2008 16:33:03 -0500
# DATE: THU, 3 JAN 2008 16:33:03 -0500
# X-AUTHENTICATION-WARNING: NAKAMURA.UITS.IUPUI.EDU: APACHE SET SENDER TO CWEN@IUPUI.EDU USING -F
# TO: SOURCE@COLLAB.SAKAIPROJECT.ORG
# FROM: CWEN@IUPUI.EDU
# SUBJECT: [SAKAI] SVN COMMIT: R39744 - ONCOURSE/BRANCHES/ONCOURSE_OPC_122007
# X-CONTENT-TYPE-OUTER-ENVELOPE: TEXT/PLAIN; CHARSET=UTF-8
# X-CONTENT-TYPE-MESSAGE-BODY: TEXT/PLAIN; CHARSET=UTF-8
# CONTENT-TYPE: TEXT/PLAIN; CHARSET=UTF-8
# X-DSPAM-RESULT: INNOCENT
# X-DSPAM-PROCESSED: THU JAN  3 16:34:40 2008
# X-DSPAM-CONFIDENCE: 0.9846
# X-DSPAM-PROBABILITY: 0.0000
#
# DETAILS: HTTP://SOURCE.SAKAIPROJECT.ORG/VIEWSVN/?VIEW=REV&REV=39744
#
# AUTHOR: CWEN@IUPUI.EDU
# DATE: 2008-01-03 16:33:02 -0500 (THU, 03 JAN 2008)
# NEW REVISION: 39744
#
# MODIFIED:
# ONCOURSE/BRANCHES/ONCOURSE_OPC_122007/
# ONCOURSE/BRANCHES/ONCOURSE_OPC_122007/.EXTERNALS
# LOG:
# UPDATE EXTERNAL FOR GB.
#
# ----------------------
# THIS AUTOMATIC NOTIFICATION MESSAGE WAS SENT BY SAKAI COLLAB (HTTPS://COLLAB.SAKAIPROJECT.ORG/PORTAL) FROM THE SOURCE SITE.
# YOU CAN MODIFY HOW YOU RECEIVE NOTIFICATIONS AT MY WORKSPACE > PREFERENCES.
#
#
#
# FROM CWEN@IUPUI.EDU THU JAN  3 16:29:07 2008
# RETURN-PATH: <POSTMASTER@COLLAB.SAKAIPROJECT.ORG>
# RECEIVED: FROM MURDER (MAIL.UMICH.EDU [141.211.14.46])
# 	 BY FRANKENSTEIN.MAIL.UMICH.EDU (CYRUS V2.3.8) WITH LMTPA;
# 	 THU, 03 JAN 2008 16:29:07 -0500
# X-SIEVE: CMU SIEVE 2.3
# RECEIVED: FROM MURDER ([UNIX SOCKET])
# 	 BY MAIL.UMICH.EDU (CYRUS V2.2.12) WITH LMTPA;
# 	 THU, 03 JAN 2008 16:29:07 -0500
# RECEIVED: FROM GALAXYQUEST.MR.ITD.UMICH.EDU (GALAXYQUEST.MR.ITD.UMICH.EDU [141.211.93.145])
# 	BY FAN.MAIL.UMICH.EDU () WITH ESMTP ID M03LT6UW027749;
# 	THU, 3 JAN 2008 16:29:06 -0500
# RECEIVED: FROM PAPLOO.UHI.AC.UK (APP1.PROD.COLLAB.UHI.AC.UK [194.35.219.184])
# 	BY GALAXYQUEST.MR.ITD.UMICH.EDU ID 477D5397.E161D.20326 ;
# 	 3 JAN 2008 16:28:58 -0500
# RECEIVED: FROM PAPLOO.UHI.AC.UK (LOCALHOST [127.0.0.1])
# 	BY PAPLOO.UHI.AC.UK (POSTFIX) WITH ESMTP ID DEC65ADC79;
# 	THU,  3 JAN 2008 21:28:52 +0000 (GMT)
# MESSAGE-ID: <200801032127.M03LRUQH005177@NAKAMURA.UITS.IUPUI.EDU>
# MIME-VERSION: 1.0
# CONTENT-TRANSFER-ENCODING: 7BIT
# RECEIVED: FROM PROD.COLLAB.UHI.AC.UK ([194.35.219.182])
#           BY PAPLOO.UHI.AC.UK (JAMES SMTP SERVER 2.1.3) WITH SMTP ID 917
#           FOR <SOURCE@COLLAB.SAKAIPROJECT.ORG>;
#           THU, 3 JAN 2008 21:28:39 +0000 (GMT)
# RECEIVED: FROM NAKAMURA.UITS.IUPUI.EDU (NAKAMURA.UITS.IUPUI.EDU [134.68.220.122])
# 	BY SHMI.UHI.AC.UK (POSTFIX) WITH ESMTP ID 1FBB042B30
# 	FOR <SOURCE@COLLAB.SAKAIPROJECT.ORG>; THU,  3 JAN 2008 21:28:38 +0000 (GMT)
# RECEIVED: FROM NAKAMURA.UITS.IUPUI.EDU (LOCALHOST [127.0.0.1])
# 	BY NAKAMURA.UITS.IUPUI.EDU (8.12.11.20060308/8.12.11) WITH ESMTP ID M03LRUK4005179
# 	FOR <SOURCE@COLLAB.SAKAIPROJECT.ORG>; THU, 3 JAN 2008 16:27:30 -0500
# RECEIVED: (FROM APACHE@LOCALHOST)
# 	BY NAKAMURA.UITS.IUPUI.EDU (8.12.11.20060308/8.12.11/SUBMIT) ID M03LRUQH005177
# 	FOR SOURCE@COLLAB.SAKAIPROJECT.ORG; THU, 3 JAN 2008 16:27:30 -0500
# DATE: THU, 3 JAN 2008 16:27:30 -0500
# X-AUTHENTICATION-WARNING: NAKAMURA.UITS.IUPUI.EDU: APACHE SET SENDER TO CWEN@IUPUI.EDU USING -F
# TO: SOURCE@COLLAB.SAKAIPROJECT.ORG
# FROM: CWEN@IUPUI.EDU
# SUBJECT: [SAKAI] SVN COMMIT: R39743 - GRADEBOOK/BRANCHES/ONCOURSE_2-4-2/APP/UI/SRC/JAVA/ORG/SAKAIPROJECT/TOOL/GRADEBOOK/UI
# X-CONTENT-TYPE-OUTER-ENVELOPE: TEXT/PLAIN; CHARSET=UTF-8
# X-CONTENT-TYPE-MESSAGE-BODY: TEXT/PLAIN; CHARSET=UTF-8
# CONTENT-TYPE: TEXT/PLAIN; CHARSET=UTF-8
# X-DSPAM-RESULT: INNOCENT
# X-DSPAM-PROCESSED: THU JAN  3 16:29:07 2008
# X-DSPAM-CONFIDENCE: 0.8509
# X-DSPAM-PROBABILITY: 0.0000
#
# DETAILS: HTTP://SOURCE.SAKAIPROJECT.ORG/VIEWSVN/?VIEW=REV&REV=39743
#
# AUTHOR: CWEN@IUPUI.EDU
# DATE: 2008-01-03 16:27:29 -0500 (THU, 03 JAN 2008)
# NEW REVISION: 39743
#
# MODIFIED:
# GRADEBOOK/BRANCHES/ONCOURSE_2-4-2/APP/UI/SRC/JAVA/ORG/SAKAIPROJECT/TOOL/GRADEBOOK/UI/ROSTERBEAN.JAVA
# LOG:
# SVN MERGE -C 39403 HTTPS://SOURCE.SAKAIPROJECT.ORG/SVN/GRADEBOOK/TRUNK
# U    APP/UI/SRC/JAVA/ORG/SAKAIPROJECT/TOOL/GRADEBOOK/UI/ROSTERBEAN.JAVA
#
# SVN LOG -R 39403 HTTPS://SOURCE.SAKAIPROJECT.ORG/SVN/GRADEBOOK/TRUNK
# ------------------------------------------------------------------------
# R39403 | WAGNERMR@IUPUI.EDU | 2007-12-17 17:11:08 -0500 (MON, 17 DEC 2007) | 3 LINES
#
# SAK-12504
# HTTP://JIRA.SAKAIPROJECT.ORG/JIRA/BROWSE/SAK-12504
# VIEWING "ALL GRADES" PAGE AS A TA WITH GRADER PERMISSIONS CAUSES STACK TRACE
# ------------------------------------------------------------------------
#
#
# ----------------------
# THIS AUTOMATIC NOTIFICATION MESSAGE WAS SENT BY SAKAI COLLAB (HTTPS://COLLAB.SAKAIPROJECT.ORG/PORTAL) FROM THE SOURCE SITE.
# YOU CAN MODIFY HOW YOU RECEIVE NOTIFICATIONS AT MY WORKSPACE > PREFERENCES.
#
#
#
# FROM CWEN@IUPUI.EDU THU JAN  3 16:23:48 2008
# RETURN-PATH: <POSTMASTER@COLLAB.SAKAIPROJECT.ORG>
# RECEIVED: FROM MURDER (MAIL.UMICH.EDU [141.211.14.91])
# 	 BY FRANKENSTEIN.MAIL.UMICH.EDU (CYRUS V2.3.8) WITH LMTPA;
# 	 THU, 03 JAN 2008 16:23:48 -0500
# X-SIEVE: CMU SIEVE 2.3
# RECEIVED: FROM MURDER ([UNIX SOCKET])
# 	 BY MAIL.UMICH.EDU (CYRUS V2.2.12) WITH LMTPA;
# 	 THU, 03 JAN 2008 16:23:48 -0500
# RECEIVED: FROM SALEMSLOT.MR.ITD.UMICH.EDU (SALEMSLOT.MR.ITD.UMICH.EDU [141.211.14.58])
# 	BY JACKNIFE.MAIL.UMICH.EDU () WITH ESMTP ID M03LNLF0002115;
# 	THU, 3 JAN 2008 16:23:47 -0500
# RECEIVED: FROM PAPLOO.UHI.AC.UK (APP1.PROD.COLLAB.UHI.AC.UK [194.35.219.184])
# 	BY SALEMSLOT.MR.ITD.UMICH.EDU ID 477D525E.1448.30389 ;
# 	 3 JAN 2008 16:23:44 -0500
# RECEIVED: FROM PAPLOO.UHI.AC.UK (LOCALHOST [127.0.0.1])
# 	BY PAPLOO.UHI.AC.UK (POSTFIX) WITH ESMTP ID 9D005B9D06;
# 	THU,  3 JAN 2008 21:23:38 +0000 (GMT)
# MESSAGE-ID: <200801032122.M03LMFO4005148@NAKAMURA.UITS.IUPUI.EDU>
# MIME-VERSION: 1.0
# CONTENT-TRANSFER-ENCODING: 7BIT
# RECEIVED: FROM PROD.COLLAB.UHI.AC.UK ([194.35.219.182])
#           BY PAPLOO.UHI.AC.UK (JAMES SMTP SERVER 2.1.3) WITH SMTP ID 6
#           FOR <SOURCE@COLLAB.SAKAIPROJECT.ORG>;
#           THU, 3 JAN 2008 21:23:24 +0000 (GMT)
# RECEIVED: FROM NAKAMURA.UITS.IUPUI.EDU (NAKAMURA.UITS.IUPUI.EDU [134.68.220.122])
# 	BY SHMI.UHI.AC.UK (POSTFIX) WITH ESMTP ID 3535542B69
# 	FOR <SOURCE@COLLAB.SAKAIPROJECT.ORG>; THU,  3 JAN 2008 21:23:24 +0000 (GMT)
# RECEIVED: FROM NAKAMURA.UITS.IUPUI.EDU (LOCALHOST [127.0.0.1])
# 	BY NAKAMURA.UITS.IUPUI.EDU (8.12.11.20060308/8.12.11) WITH ESMTP ID M03LMFTT005150
# 	FOR <SOURCE@COLLAB.SAKAIPROJECT.ORG>; THU, 3 JAN 2008 16:22:15 -0500
# RECEIVED: (FROM APACHE@LOCALHOST)
# 	BY NAKAMURA.UITS.IUPUI.EDU (8.12.11.20060308/8.12.11/SUBMIT) ID M03LMFO4005148
# 	FOR SOURCE@COLLAB.SAKAIPROJECT.ORG; THU, 3 JAN 2008 16:22:15 -0500
# DATE: THU, 3 JAN 2008 16:22:15 -0500
# X-AUTHENTICATION-WARNING: NAKAMURA.UITS.IUPUI.EDU: APACHE SET SENDER TO CWEN@IUPUI.EDU USING -F
# TO: SOURCE@COLLAB.SAKAIPROJECT.ORG
# FROM: CWEN@IUPUI.EDU
# SUBJECT: [SAKAI] SVN COMMIT: R39742 - GRADEBOOK/BRANCHES/ONCOURSE_2-4-2/APP/UI/SRC/JAVA/ORG/SAKAIPROJECT/TOOL/GRADEBOOK/UI
# X-CONTENT-TYPE-OUTER-ENVELOPE: TEXT/PLAIN; CHARSET=UTF-8
# X-CONTENT-TYPE-MESSAGE-BODY: TEXT/PLAIN; CHARSET=UTF-8
# CONTENT-TYPE: TEXT/PLAIN; CHARSET=UTF-8
# X-DSPAM-RESULT: INNOCENT
# X-DSPAM-PROCESSED: THU JAN  3 16:23:48 2008
# X-DSPAM-CONFIDENCE: 0.9907
# X-DSPAM-PROBABILITY: 0.0000
#
# DETAILS: HTTP://SOURCE.SAKAIPROJECT.ORG/VIEWSVN/?VIEW=REV&REV=39742
#
# AUTHOR: CWEN@IUPUI.EDU
# DATE: 2008-01-03 16:22:14 -0500 (THU, 03 JAN 2008)
# NEW REVISION: 39742
#
# MODIFIED:
# GRADEBOOK/BRANCHES/ONCOURSE_2-4-2/APP/UI/SRC/JAVA/ORG/SAKAIPROJECT/TOOL/GRADEBOOK/UI/ROSTERBEAN.JAVA
# LOG:
# SVN MERGE -C 35014 HTTPS://SOURCE.SAKAIPROJECT.ORG/SVN/GRADEBOOK/TRUNK
# U    APP/UI/SRC/JAVA/ORG/SAKAIPROJECT/TOOL/GRADEBOOK/UI/ROSTERBEAN.JAVA
#
# SVN LOG -R 35014 HTTPS://SOURCE.SAKAIPROJECT.ORG/SVN/GRADEBOOK/TRUNK
# ------------------------------------------------------------------------
# R35014 | WAGNERMR@IUPUI.EDU | 2007-09-12 16:17:59 -0400 (WED, 12 SEP 2007) | 3 LINES
#
# SAK-11458
# HTTP://BUGS.SAKAIPROJECT.ORG/JIRA/BROWSE/SAK-11458
# COURSE GRADE DOES NOT APPEAR ON "ALL GRADES" PAGE IF NO CATEGORIES IN GB
# ------------------------------------------------------------------------
#
#
# ----------------------
# THIS AUTOMATIC NOTIFICATION MESSAGE WAS SENT BY SAKAI COLLAB (HTTPS://COLLAB.SAKAIPROJECT.ORG/PORTAL) FROM THE SOURCE SITE.
# YOU CAN MODIFY HOW YOU RECEIVE NOTIFICATIONS AT MY WORKSPACE > PREFERENCES.

# %%
print(range(4))
# Out:
# range(0, 4)

# %%
t = [1,2,3,4,5,6,7,8,9]
t[0:4]
print(t[4:])
# Out:
# [5, 6, 7, 8, 9]

# %%
fh = open('mbox-short.txt')
for line in fh:
    if line.startswith('From'):
        line = line.rstrip()
        line = line.split()
        if len(line) > 2:
            line = line[2]
            print(line)
# Out:
# Sat
# Fri
# Fri
# Fri
# Fri
# Fri
# Fri
# Fri
# Fri
# Fri
# Fri
# Fri
# Fri
# Fri
# Fri
# Fri
# Fri
# Fri
# Fri
# Fri
# Fri
# Thu
# Thu
# Thu
# Thu
# Thu
# Thu

# %%
fh = open('intro.txt')
words = {}
for line in fh:
    line = line.split()
    for x in line:
        words[x] = words.get(x,0)+1
        
totalCount = 0
maxWord = 0
for a,b in words.items():
    if words[a] > totalCount:
        maxWord = a
        totalCount = b
print('the max word is',maxWord,' and its',totalCount,'times repeated')
# Out:
# the max word is the  and its 226 times repeated

# %%
filename = input('Enter the filename: ')
if len(filename) < 1: filename = 'clown.txt'

t = {}

fh = open(filename)

for line in fh:
    line = line.rstrip()
    line = line.split()
    for x in line:
        t[x]=t.get(x,0)+1
        
l = list()
for a,b in t.items():
    newt = (b,a)
    l.append(newt)
    
l = sorted(l,reverse = True)
for b,a in l[:5]:
    print(b,a)
# Out:
# Enter the filename:
# 7 the
# 3 car
# 3 and
# 2 tent
# 2 ran

# %%
import socket

mysock = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
mysock.connect(('data.pr4e.org',80))
cmd = 'GET http://data.pr4e.org/romeo.txt HTTP/1.0\r\n\r\n'.encode()
mysock.send(cmd)

while True:
    data = mysock.recv(512)
    if len(data)<1:
        break
    print(data.decode())
mysock.close()
# Out:
# HTTP/1.1 200 OK
# Date: Sat, 20 Mar 2021 07:43:42 GMT
# Server: Apache/2.4.18 (Ubuntu)
# Last-Modified: Sat, 13 May 2017 11:22:22 GMT
# ETag: "a7-54f6609245537"
# Accept-Ranges: bytes
# Content-Length: 167
# Cache-Control: max-age=0, no-cache, no-store, must-revalidate
# Pragma: no-cache
# Expires: Wed, 11 Jan 1984 05:00:00 GMT
# Connection: close
# Content-Type: text/plain
#
# But soft what light through yonder window breaks
# It is the east and Juliet is the sun
# Arise fair sun and kill the envious moon
# Who is already s
# ick and pale with grief

# %%
import urllib.parse,urllib.request,urllib.error

fhand = urllib.request.urlopen('http://data.pr4e.org/romeo.txt ')
for line in fhand:
    print(line.decode().strip())
# Out:
# But soft what light through yonder window breaks
# It is the east and Juliet is the sun
# Arise fair sun and kill the envious moon
# Who is already sick and pale with grief

# %%
# To run this, download the BeautifulSoup zip file
# http://www.py4e.com/code3/bs4.zip
# and unzip it in the same directory as this file

import urllib.request, urllib.parse, urllib.error
from bs4 import BeautifulSoup
import ssl

# Ignore SSL certificate errors
ctx = ssl.create_default_context()
ctx.check_hostname = False
ctx.verify_mode = ssl.CERT_NONE

url = input('Enter - ')
html = urllib.request.urlopen(url, context=ctx).read()
soup = BeautifulSoup(html, 'html.parser')

# Retrieve all of the anchor tags
tags = soup('a')
for tag in tags:
    print(tag.get('href', None))

# Code: http://www.py4e.com/code3/urllinks.py
# Out:
# Enter - https://www.twitter.com/
# https://help.twitter.com/using-twitter/twitter-supported-browsers
# https://twitter.com/tos
# https://twitter.com/privacy
# https://support.twitter.com/articles/20170514
# https://legal.twitter.com/imprint
# https://business.twitter.com/en/help/troubleshooting/how-twitter-ads-work.html

# %%
import xml.etree.ElementTree as Et

data = '''
        <person>
          <name>Asmit</name>
          <country>Nepal</country>
          <phone type = "int1">
              2354
          </phone>
          <email hide = 'Yes'/>
        </person>
'''

tree = Et.fromstring(data)
print('Name :',tree.find('name').text)
print('Country:',tree.find('country').text)
print('Phone:',tree.find('phone').text.strip())
print('Phone type :',tree.find('phone').get('type'))
print('email type:',tree.find('email').get('hide'))
# Out:
# Name : Asmit
# Country: Nepal
# Phone: 2354
# Phone type : int1
# email type: Yes

# %%
import xml.etree.ElementTree as ET

input = '''
<stuff>
  <users>
    <user x="2">
      <id>001</id>
      <name>Chuck</name>
    </user>
    <user x="7">
      <id>009</id>
      <name>Brent</name>
    </user>
  </users>
</stuff>'''

data = ET.fromstring(input)
l = data.findall('users/user')
print('user count :',len(l))

for item in l:
    print('name:',item.find('name').text)
    print('id:',item.find('id').text)
    print('attribute:',item.get('x'))
# Out:
# user count : 2
# name: Chuck
# id: 001
# attribute: 2
# name: Brent
# id: 009
# attribute: 7

# %%
import json

data = '''
{
  "name" : "chuck",
  "phone" : {
    "type" : "int1",
    "number" : "6562315456"
    
  },
  "email" : {
  "hide" : "yes"
  }

}
'''

info = json.loads(data)
print("name:",info["name"])
print("email hide:",info["email"]["hide"])
# Out:
# name: chuck
# email hide: yes

# %%
import json

data = '''
[
  { "id" : "001",
    "x" : "2",
    "name" : "Chuck"
  } ,
  { "id" : "009",
    "x" : "7",
    "name" : "Brent"
  }
]'''

info = json.loads(data)
for i in range(len(info)):
        print("name:",info[i]["name"])
        print("id:",info[i]["id"])
        print("x:",info[i]["x"])
        
#OR        
print()
print()
for item in info:
    print(item["name"])
    print(item["id"])
    print(item["x"])
# Out:
# name: Chuck
# id: 001
# x: 2
# name: Brent
# id: 009
# x: 7
#
#
# Chuck
# 001
# 2
# Brent
# 009
# 7

# %%
import urllib.request, urllib.parse, urllib.error
import json
import ssl

api_key = False
# If you have a Google Places API key, enter it here
# api_key = 'AIzaSy___IDByT70'
# https://developers.google.com/maps/documentation/geocoding/intro

if api_key is False:
    api_key = 42
    serviceurl = 'http://py4e-data.dr-chuck.net/json?'
else :
    serviceurl = 'https://maps.googleapis.com/maps/api/geocode/json?'

# Ignore SSL certificate errors
ctx = ssl.create_default_context()
ctx.check_hostname = False
ctx.verify_mode = ssl.CERT_NONE

while True:
    address = input('Enter location: ')
    if len(address) < 1: break

    parms = dict()
    parms['address'] = address
    if api_key is not False: parms['key'] = api_key
    url = serviceurl + urllib.parse.urlencode(parms)

    print('Retrieving', url)
    uh = urllib.request.urlopen(url, context=ctx)
    data = uh.read().decode()
    print('Retrieved', len(data), 'characters')

    try:
        js = json.loads(data)
    except:
        js = None

    if not js or 'status' not in js or js['status'] != 'OK':
        print('==== Failure To Retrieve ====')
        print(data)
        continue

    print(json.dumps(js, indent=4))

    lat = js['results'][0]['geometry']['location']['lat']
    lng = js['results'][0]['geometry']['location']['lng']
    print('lat', lat, 'lng', lng)
    location = js['results'][0]['formatted_address']
    print(location)
# Out:
# Enter location: kathmandu
# Retrieving http://py4e-data.dr-chuck.net/json?address=kathmandu&key=42
# Retrieved 1916 characters
# {
#     "results": [
#         {
#             "address_components": [
#                 {
#                     "long_name": "Kathmandu",
#                     "short_name": "Kathmandu",
#                     "types": [
#                         "locality",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "Bagmati",
#                     "short_name": "Bagmati",
#                     "types": [
#                         "administrative_area_level_2",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "Central Development Region",
#                     "short_name": "Central Development Region",
#                     "types": [
#                         "administrative_area_level_1",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "Nepal",
#                     "short_name": "NP",
#                     "types": [
#                         "country",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "44600",
#                     "short_name": "44600",
#                     "types": [
#                         "postal_code"
#                     ]
#                 }
#             ],
#             "formatted_address": "Kathmandu 44600, Nepal",
#             "geometry": {
#                 "bounds": {
#                     "northeast": {
#                         "lat": 27.7499367,
#                         "lng": 85.37316799999999
#                     },
#                     "southwest": {
#                         "lat": 27.667984,
#                         "lng": 85.2790976
#                     }
#                 },
#                 "location": {
#                     "lat": 27.7172453,
#                     "lng": 85.3239605
#                 },
#                 "location_type": "APPROXIMATE",
#                 "viewport": {
#                     "northeast": {
#                         "lat": 27.7499367,
#                         "lng": 85.37316799999999
#                     },
#                     "southwest": {
#                         "lat": 27.667984,
#                         "lng": 85.2790976
#                     }
#                 }
#             },
#             "place_id": "ChIJv6p7MIoZ6zkR6rGN8Rt8E7U",
#             "types": [
#                 "locality",
#                 "political"
#             ]
#         }
#     ],
#     "status": "OK"
# }
# lat 27.7172453 lng 85.3239605
# Kathmandu 44600, Nepal
# Enter location:

# %%
import urllib.request, urllib.parse, urllib.error
import twurl
import json
import ssl

# https://apps.twitter.com/
# Create App and get the four strings, put them in hidden.py

TWITTER_URL = 'https://api.twitter.com/1.1/friends/list.json'

# Ignore SSL certificate errors
ctx = ssl.create_default_context()
ctx.check_hostname = False
ctx.verify_mode = ssl.CERT_NONE

while True:
    print('')
    acct = input('Enter Twitter Account:')
    if (len(acct) < 1): break
    url = twurl.augment(TWITTER_URL,
                        {'screen_name': acct, 'count': '5'})
    print('Retrieving', url)
    connection = urllib.request.urlopen(url, context=ctx)
    data = connection.read().decode()

    js = json.loads(data)
    print(json.dumps(js, indent=2))

    headers = dict(connection.getheaders())
    print('Remaining', headers['x-rate-limit-remaining'])

    for u in js['users']:
        print(u['screen_name'])
        if 'status' not in u:
            print('   * No status found')
            continue
        s = u['status']['text']
        print('  ', s[:50])
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-9-79bc6a9b3109> in <module>
#       1 import urllib.request, urllib.parse, urllib.error
# ----> 2 import twurl
#       3 import json
#       4 import ssl
#       5
#
# ModuleNotFoundError: No module named 'twurl'

# %%
import sqlite3

conn = sqlite3.connect('emaildb.sqlite')
cur = conn.cursor()

cur.execute('DROP TABLE IF EXISTS Counts')

cur.execute('''
CREATE TABLE Counts (email TEXT, count INTEGER)''')


fname = input('Enter file name: ')
if len(fname) < 1: fname = 'mbox-short.txt'
fh = open(fname)
for line in fh:
    if not line.startswith('From: '): continue
    pieces = line.split()
    email = pieces[1]
    cur.execute('SELECT count FROM Counts WHERE email = ? ', (email,))
    row = cur.fetchone()
    if row is None:
        cur.execute('''INSERT INTO Counts (email, count)
                VALUES (?, 1)''', (email,))
    else:
        cur.execute('UPDATE Counts SET count = count + 1 WHERE email = ?',
                    (email,))
    conn.commit()

# https://www.sqlite.org/lang_select.html
sqlstr = 'SELECT email, count FROM Counts ORDER BY count DESC LIMIT 10'

for row in cur.execute(sqlstr):
    print(str(row[0]), row[1])

cur.close()
# Out:
# Enter file name:
# cwen@iupui.edu 5
# zqian@umich.edu 4
# david.horwitz@uct.ac.za 4
# louis@media.berkeley.edu 3
# gsilver@umich.edu 3
# stephen.marquard@uct.ac.za 2
# rjlowe@iupui.edu 2
# wagnermr@iupui.edu 1
# antranig@caret.cam.ac.uk 1
# gopal.ramasammycook@gmail.com 1

# %%
import json
import sqlite3

conn = sqlite3.connect('rosterdb.sqlite')
cur = conn.cursor()

# Do some setup
cur.executescript('''
DROP TABLE IF EXISTS User;
DROP TABLE IF EXISTS Member;
DROP TABLE IF EXISTS Course;

CREATE TABLE User (
    id     INTEGER NOT NULL PRIMARY KEY AUTOINCREMENT UNIQUE,
    name   TEXT UNIQUE
);

CREATE TABLE Course (
    id     INTEGER NOT NULL PRIMARY KEY AUTOINCREMENT UNIQUE,
    title  TEXT UNIQUE
);

CREATE TABLE Member (
    user_id     INTEGER,
    course_id   INTEGER,
    role        INTEGER,
    PRIMARY KEY (user_id, course_id)
)
''')

fname = input('Enter file name: ')
if len(fname) < 1:
    fname = 'roster_data_sample.json'

# [
#   [ "Charley", "si110", 1 ],
#   [ "Mea", "si110", 0 ],

str_data = open(fname).read()
json_data = json.loads(str_data)

for entry in json_data:

    name = entry[0]
    title = entry[1]
    role = entry[2]

    #print((name, title))

    cur.execute('''INSERT OR IGNORE INTO User (name)
        VALUES ( ? )''', ( name, ) )
    cur.execute('SELECT id FROM User WHERE name = ? ', (name, ))
    user_id = cur.fetchone()[0]

    cur.execute('''INSERT OR IGNORE INTO Course (title)
        VALUES ( ? )''', ( title, ) )
    cur.execute('SELECT id FROM Course WHERE title = ? ', (title, ))
    course_id = cur.fetchone()[0]

    cur.execute('''INSERT OR REPLACE INTO Member
        (user_id, course_id,role) VALUES ( ?, ?,? )''',
        ( user_id, course_id,role ) )

    conn.commit()
    
sqlstr='''SELECT User.name, Member.role, Course.title
  FROM User JOIN Member JOIN Course
  ON Member.user_id = User.id AND Member.course_id = Course.id
  ORDER BY Course.title, Member.role DESC, User.name 
   
'''
for entry in cur.execute(sqlstr):
       print(entry[0],entry[1],entry[2])
# Out:
# Enter file name:
# Rosa 1 si106
# Betsy 0 si106
# Buse 0 si106
# Davie 0 si106
# Dineo 0 si106
# Honie 0 si106
# Jeanna 0 si106
# Kareena 0 si106
# Kayah 0 si106
# Larissa 0 si106
# Mairin 0 si106
# Mohammed 0 si106
# Nora 0 si106
# Philippa 0 si106
# Shania 0 si106
# Shaurya 0 si106
# Sorcha 0 si106
# Temba 0 si106
# Zendel 0 si106
# Charley 1 si110
# Allen 0 si110
# Aneshia 0 si110
# Aria 0 si110
# Dylan 0 si110
# Ellyce 0 si110
# Faizaan 0 si110
# Hattie 0 si110
# Ioannis 0 si110
# Kamron 0 si110
# Keiara 0 si110
# Keziah 0 si110
# Kiran 0 si110
# Lyena 0 si110
# Marshall 0 si110
# Marykate 0 si110
# Mea 0 si110
# Meabh 0 si110
# Reena 0 si110
# Reily 0 si110
# Sidharth 0 si110
# Thalia 0 si110
# Yann 0 si110
# Lia 1 si206
# Abubakar 0 si206
# Anisa 0 si206
# Areez 0 si206
# Caralee 0 si206
# Charlee 0 si206
# Derryn 0 si206
# Elan 0 si206
# Elana 0 si206
# Eryk 0 si206
# Karyn 0 si206
# Klevis 0 si206
# Linton 0 si206
# MacCartney 0 si206
# Maggie 0 si206
# Pearsen 0 si206
# Rhea 0 si206
# Sharlyn 0 si206
# Skye 0 si206
# Tait 0 si206
# Temilade 0 si206
# Vikki 0 si206
# Willow 0 si206
# Zulaikha 1 si301
# Anastasia 0 si301
# Anay 0 si301
# Aria 0 si301
# Basher 0 si301
# Belle 0 si301
# Cai 0 si301
# Codie 0 si301
# Colette 0 si301
# Connar 0 si301
# Dayna 0 si301
# Elleanne 0 si301
# Elshan 0 si301
# Jayla 0 si301
# Laranya 0 si301
# Lowri 0 si301
# Lucee 0 si301
# Maggy 0 si301
# Riana 0 si301
# Tanika 0 si301
# Tatiana 0 si301
# Zhong 0 si301
# Zijie 0 si301
# Maanav 1 si310
# Abel 0 si310
# Ahtasham 0 si310
# Aidan 0 si310
# Alexzander 0 si310
# Anthony 0 si310
# Avinash 0 si310
# Cohen 0 si310
# Colette 0 si310
# Frazer 0 si310
# Ida 0 si310
# Jamey 0 si310
# Kavita 0 si310
# Makenzie 0 si310
# Rori 0 si310
# Sacha 0 si310
# Talia 0 si310
# Tamta 0 si310
# Youer 0 si310
# Elona 1 si334
# Ainsley 0 si334
# Camryn 0 si334
# Caoilainn 0 si334
# Corrie 0 si334
# Cullen 0 si334
# Diane 0 si334
# Franciszek 0 si334
# Honie 0 si334
# Inan 0 si334
# Kensey 0 si334
# Kiran 0 si334
# Makala 0 si334
# Nolan 0 si334
# Obieluem 0 si334
# Ole 0 si334
# Raine 0 si334
# Schekina 0 si334
# Taylor 0 si334
# Tyllor 0 si334
# Tymoteusz 0 si334
# Zhi 0 si334
# Windsor 1 si363
# Airen 0 si363
# Alx 0 si363
# Brooklynn 0 si363
# Diarmid 0 si363
# Erika 0 si363
# Heddle 0 si363
# Jaskaran 0 si363
# Kashish 0 si363
# Laura 0 si363
# Mackie 0 si363
# Meghan 0 si363
# Presley 0 si363
# Ryaan 0 si363
# Seaan 0 si363
# Travis 0 si363
# Wen 0 si363
# Imogem 1 si364
# Adelaide 0 si364
# Anneliese 0 si364
# Baillie 0 si364
# Declan 0 si364
# Emelie 0 si364
# Enzo 0 si364
# Harlie 0 si364
# Ieuan 0 si364
# Katarzyna 0 si364
# LLeyton 0 si364
# Lucca 0 si364
# Nawal 0 si364
# Rhia 0 si364
# Ronnie 0 si364
# Shanelle 0 si364
# Shola 0 si364
# Simon 0 si364
# Sorche 0 si364
# Jenna 1 si422
# Alx 0 si422
# Bailie 0 si422
# Brigitte 0 si422
# Cassy 0 si422
# Eliana 0 si422
# Hafiza 0 si422
# Hebe 0 si422
# Jamaal 0 si422
# Jaydyn 0 si422
# Kayden 0 si422
# Keanna 0 si422
# Man 0 si422
# Melanie 0 si422
# Miles 0 si422
# Nikash 0 si422
# Sakina 0 si422
# Sia 0 si422
# Skyla 0 si422
# Temperance 0 si422
# Vanya 0 si422
# Soukina 1 si430
# Abel 0 si430
# Buddy 0 si430
# Cassie 0 si430
# Deano 0 si430
# Georgia 0 si430
# Holly 0 si430
# Kamilia 0 si430
# Kassie 0 si430
# Kris 0 si430
# Louie 0 si430
# Maia 0 si430
# Manwen 0 si430
# Mutinta 0 si430
# Rosa 0 si430
# Stephenjunior 0 si430
# Tamika 0 si430

# %%
import xml.etree.ElementTree as ET
import sqlite3

conn = sqlite3.connect('trackdb.sqlite')
cur = conn.cursor()

# Make some fresh tables using executescript()
cur.executescript('''
DROP TABLE IF EXISTS Artist;
DROP TABLE IF EXISTS Album;
DROP TABLE IF EXISTS Track;

CREATE TABLE Artist (
    id  INTEGER NOT NULL PRIMARY KEY AUTOINCREMENT UNIQUE,
    name    TEXT UNIQUE
);

CREATE TABLE Album (
    id  INTEGER NOT NULL PRIMARY KEY AUTOINCREMENT UNIQUE,
    artist_id  INTEGER,
    title   TEXT UNIQUE
);

CREATE TABLE Track (
    id  INTEGER NOT NULL PRIMARY KEY 
        AUTOINCREMENT UNIQUE,
    title TEXT  UNIQUE,
    album_id  INTEGER,
    len INTEGER, rating INTEGER, count INTEGER
);
''')


fname = input('Enter file name: ')
if ( len(fname) < 1 ) : fname = 'Library.xml'

# <key>Track ID</key><integer>369</integer>
# <key>Name</key><string>Another One Bites The Dust</string>
# <key>Artist</key><string>Queen</string>
def lookup(d, key):
    found = False
    for child in d:
        if found : return child.text
        if child.tag == 'key' and child.text == key :
            found = True
    return None

stuff = ET.parse(fname)
all = stuff.findall('dict/dict/dict')
print('Dict count:', len(all))
for entry in all:
    if ( lookup(entry, 'Track ID') is None ) : continue

    name = lookup(entry, 'Name')
    artist = lookup(entry, 'Artist')
    album = lookup(entry, 'Album')
    count = lookup(entry, 'Play Count')
    rating = lookup(entry, 'Rating')
    length = lookup(entry, 'Total Time')

    if name is None or artist is None or album is None : 
        continue

    #print(name, artist, album, count, rating, length)

    cur.execute('''INSERT OR IGNORE INTO Artist (name) 
        VALUES ( ? )''', ( artist, ) )
    cur.execute('SELECT id FROM Artist WHERE name = ? ', (artist, ))
    artist_id = cur.fetchone()[0]

    cur.execute('''INSERT OR IGNORE INTO Album (title, artist_id) 
        VALUES ( ?, ? )''', ( album, artist_id ) )
    cur.execute('SELECT id FROM Album WHERE title = ? ', (album, ))
    album_id = cur.fetchone()[0]

    cur.execute('''INSERT OR REPLACE INTO Track
        (title, album_id, len, rating, count) 
        VALUES ( ?, ?, ?, ?, ? )''', 
        ( name, album_id, length, rating, count ) )

    conn.commit()
    
sqlstr =('Select Track.title,Album.title,Artist.name From Track join Album join Artist on Track.album_id = Album.id AND Album.artist_id = Artist.id')
for row in cur.execute(sqlstr):
    print(row)
# Out:
# Enter file name:
# Dict count: 404
# ('Another One Bites The Dust', 'Greatest Hits', 'Queen')
# ('Asche Zu Asche', 'Herzeleid', 'Rammstein')
# ('Beauty School Dropout', 'Grease', 'Various')
# ('Black Dog', 'IV', 'Led Zeppelin')
# ('Bring The Boys Back Home', 'The Wall [Disc 2]', 'Pink Floyd')
# ('Circles', 'Blues Is', 'Bryan Lee')
# ('Comfortably Numb', 'The Wall [Disc 2]', 'Pink Floyd')
# ('Crazy Little Thing Called Love', 'Greatest Hits', 'Queen')
# ('Electric Funeral', 'Paranoid', 'Black Sabbath')
# ('Fat Bottomed Girls', 'Greatest Hits', 'Queen')
# ('For Those About To Rock (We Salute You)', 'Who Made Who', 'AC/DC')
# ('Four Sticks', 'IV', 'Led Zeppelin')
# ('Furious Angels', 'The Matrix Reloaded', 'Rob Dougan')
# ('Gelle', 'Blues Is', 'Bryan Lee')
# ('Going To California', 'IV', 'Led Zeppelin')
# ('Grease', 'Grease', 'Various')
# ('Hand of Doom', 'Paranoid', 'Black Sabbath')
# ('Hells Bells', 'Who Made Who', 'AC/DC')
# ('Hey You', 'The Wall [Disc 2]', 'Pink Floyd')
# ('I Worry', 'Blues Is', 'Bryan Lee')
# ('Iron Man', 'Paranoid', 'Black Sabbath')
# ('Is There Anybody Out There?', 'The Wall [Disc 2]', 'Pink Floyd')
# ('It was a Very Good Year', 'Greatest Hits', 'Queen')
# ('Its Your Move', 'Blues Is', 'Bryan Lee')
# ('Jack the Stripper/Fairies Wear Boots', 'Paranoid', 'Black Sabbath')
# ('Killer Queen', 'Greatest Hits', 'Queen')
# ('Laichzeit', 'Herzeleid', 'Rammstein')
# ('Let me Down Easy', 'Blues Is', 'Bryan Lee')
# ('Misty Mountain Hop', 'IV', 'Led Zeppelin')
# ('No Low Down', 'Blues Is', 'Bryan Lee')
# ('Now You Are Gone', 'Greatest Hits', 'Queen')
# ('Outside The Wall', 'The Wall [Disc 2]', 'Pink Floyd')
# ('Paranoid', 'Paranoid', 'Black Sabbath')
# ('Planet Caravan', 'Paranoid', 'Black Sabbath')
# ('Pretty Jeanie', 'Blues Is', 'Bryan Lee')
# ('Rammstein', 'Herzeleid', 'Rammstein')
# ('Rat Salad', 'Paranoid', 'Black Sabbath')
# ('Rock & Roll', 'IV', 'Led Zeppelin')
# ('Rode Across the Desert', 'Greatest Hits', 'Queen')
# ('Sandy', 'Grease', 'Various')
# ('Shake Your Foundations', 'Who Made Who', 'AC/DC')
# ('Sister Golden Hair', 'Greatest Hits', 'Queen')
# ('Somebody To Love', 'Greatest Hits', 'Queen')
# ('Stairway To Heaven', 'IV', 'Led Zeppelin')
# ('Strangers in the Night', 'Greatest Hits', 'Queen')
# ('Summer Nights', 'Grease', 'Various')
# ('Summer Wind', 'Greatest Hits', 'Queen')
# ('Thats Life', 'Greatest Hits', 'Queen')
# ('The Battle Of Evermore', 'IV', 'Led Zeppelin')
# ('The Blues "Is"', 'Blues Is', 'Bryan Lee')
# ('There it Is', 'Blues Is', 'Bryan Lee')
# ('Think', 'Blues Is', 'Bryan Lee')
# ('This Town', 'Greatest Hits', 'Queen')
# ('Tin Man', 'Greatest Hits', 'Queen')
# ('Track 01', 'Danger Zone', 'Billy Price')
# ('Track 02', 'Danger Zone', 'Billy Price')
# ('Track 03', 'Danger Zone', 'Billy Price')
# ('Messin with the Kid', 'Self Titled', 'The Canettes Blues Band')
# ('Track 04', 'Danger Zone', 'Billy Price')
# ('Stormy Monday', 'Self Titled', 'The Canettes Blues Band')
# ('Track 05', 'Danger Zone', 'Billy Price')
# ('Waiting on Ice', 'Blues Is', 'Bryan Lee')
# ("War Pigs/Luke's Wall", 'Paranoid', 'Black Sabbath')
# ('We Are The Champions', 'Greatest Hits', 'Queen')
# ('We Will Rock You', 'Greatest Hits', 'Queen')
# ('When Somebody Loves You', 'Greatest Hits', 'Queen')
# ('When The Levee Breaks', 'IV', 'Led Zeppelin')
# ('You are the One that I Want', 'Grease', 'Various')
# ('You Done Me Wrong', 'Blues Is', 'Bryan Lee')
# ('You Shook Me All Night Long', 'Who Made Who', 'AC/DC')
# ("You're My Best Friend", 'Greatest Hits', 'Queen')
# ('Zion', 'The Matrix Reloaded', 'Rob Dougan')
# ('Who Made Who', 'Who Made Who', 'AC/DC')
# ('D.T.', 'Who Made Who', 'AC/DC')
# ('Sink the Pink', 'Who Made Who', 'AC/DC')
# ('Ride On', 'Who Made Who', 'AC/DC')
# ('Chase the Ace', 'Who Made Who', 'AC/DC')
# ('Wollt Ihr Das Bett In Flammen Sehen', 'Herzeleid', 'Rammstein')
# ('Der Meister', 'Herzeleid', 'Rammstein')
# ('Weisses Fleisch', 'Herzeleid', 'Rammstein')
# ('Seemann', 'Herzeleid', 'Rammstein')
# ('Du Riechst So Gut', 'Herzeleid', 'Rammstein')
# ('Das Alte Leid', 'Herzeleid', 'Rammstein')
# ('Heirate Mich', 'Herzeleid', 'Rammstein')
# ('Herzeleid', 'Herzeleid', 'Rammstein')
# ("Baba O'Riley", "Who's Next", 'The Who')
# ('Bargain', "Who's Next", 'The Who')
# ("Love Ain't for Keeping", "Who's Next", 'The Who')
# ('My Wife', "Who's Next", 'The Who')
# ('The Song Is Over', "Who's Next", 'The Who')
# ('Getting In Tune', "Who's Next", 'The Who')
# ('Going Mobile', "Who's Next", 'The Who')
# ('Behind Blue Eyes', "Who's Next", 'The Who')
# ("Won't Get Fooled Again", "Who's Next", 'The Who')
# ('Folsom Prison Blues', 'The Legend Of Johnny Cash', 'Johnny Cash')
# ('I Walk The Line', 'The Legend Of Johnny Cash', 'Johnny Cash')
# ('Get Rhythm', 'The Legend Of Johnny Cash', 'Johnny Cash')
# ('Big River', 'The Legend Of Johnny Cash', 'Johnny Cash')
# ('Guess Things Happen That Way', 'The Legend Of Johnny Cash', 'Johnny Cash')
# ('Ring Of Fire', 'The Legend Of Johnny Cash', 'Johnny Cash')
# ('Jackson', 'The Legend Of Johnny Cash', 'Johnny Cash')
# ('A Boy Named Sue (live)', 'The Legend Of Johnny Cash', 'Johnny Cash')
# ('You Raise Me Up', 'Hiding Place', 'Selah')
# ("Hold On, I'm Coming", 'On Tap & In the Can', 'The Canettes Blues Band')
# ('Got my Mojo Working', 'On Tap & In the Can', 'The Canettes Blues Band')
# ('Sweet Home Chicago', 'On Tap & In the Can', 'The Canettes Blues Band')
# ('Heavy Love', 'On Tap & In the Can', 'The Canettes Blues Band')
# ('Cold Cold Feeling', 'On Tap & In the Can', 'The Canettes Blues Band')
# ('Lonely Avenue', 'On Tap & In the Can', 'The Canettes Blues Band')
# ('Good Morning Little Schoolgirl', 'On Tap & In the Can', 'The Canettes Blues Band')
# ('Dust My Broom', 'On Tap & In the Can', 'The Canettes Blues Band')
# ("Gimme' Some Lovin", 'On Tap & In the Can', 'The Canettes Blues Band')
# ('Everybody Needs Somebody to Love', 'On Tap & In the Can', 'The Canettes Blues Band')
# ('Black Magic Woman', 'On Tap & In the Can', 'The Canettes Blues Band')
# ("Steppin' Rooster", 'On Tap & In the Can', 'The Canettes Blues Band')
# ('Our Love is Drifting', 'On Tap & In the Can', 'The Canettes Blues Band')
# ("Doin' 100", 'On Tap & In the Can', 'The Canettes Blues Band')
# ('Mother Joy', 'Natural Wonders Music Sampler 1999', 'Matt Ender')
# ("Soldier's Lament", 'Natural Wonders Music Sampler 1999', 'Matt Ender')
# ('Dulaman', 'Natural Wonders Music Sampler 1999', 'Matt Ender')
# ('The Arrow', 'Natural Wonders Music Sampler 1999', 'Matt Ender')
# ('Spanish Eyes', 'Natural Wonders Music Sampler 1999', 'Matt Ender')
# ('Banana Bay', 'Natural Wonders Music Sampler 1999', 'Matt Ender')
# ('Aguas De Marco', 'Natural Wonders Music Sampler 1999', 'Matt Ender')
# ('Tamborea', 'Natural Wonders Music Sampler 1999', 'Matt Ender')
# ('Gone', 'Natural Wonders Music Sampler 1999', 'Matt Ender')
# ('The Immigrant', 'Natural Wonders Music Sampler 1999', 'Matt Ender')
# ('Pahrump-Big Water', 'Natural Wonders Music Sampler 1999', 'Matt Ender')
# ("Seeker's Quest", 'Natural Wonders Music Sampler 1999', 'Matt Ender')
# ('Floating To Forever', 'Natural Wonders Music Sampler 1999', 'Matt Ender')
# ('Open Road', 'Relaxing Jazz', 'Jeff Bailey')
# ('Ruby', 'Yours Truly, Angry Mob', 'Kaiser Chiefs')
# ('The Angry Mob', 'Yours Truly, Angry Mob', 'Kaiser Chiefs')
# ('Heat Dies Down', 'Yours Truly, Angry Mob', 'Kaiser Chiefs')
# ('Highroyds', 'Yours Truly, Angry Mob', 'Kaiser Chiefs')
# ("Love's Not A Competition (But I'm Winning)", 'Yours Truly, Angry Mob', 'Kaiser Chiefs')
# ('Thank You Very Much', 'Yours Truly, Angry Mob', 'Kaiser Chiefs')
# ('I Can Do It Without You', 'Yours Truly, Angry Mob', 'Kaiser Chiefs')
# ('My Kind Of Guy', 'Yours Truly, Angry Mob', 'Kaiser Chiefs')
# ('Everything Is Average Nowadays', 'Yours Truly, Angry Mob', 'Kaiser Chiefs')
# ('Learnt My Lesson Well', 'Yours Truly, Angry Mob', 'Kaiser Chiefs')
# ('Try Your Best', 'Yours Truly, Angry Mob', 'Kaiser Chiefs')
# ('Retirement', 'Yours Truly, Angry Mob', 'Kaiser Chiefs')
# ('The Angry Mob [Live From Berlin]', 'Yours Truly, Angry Mob', 'Kaiser Chiefs')
# ('I Like To Fight', 'Yours Truly, Angry Mob', 'Kaiser Chiefs')
# ('From The Neck Down', 'Yours Truly, Angry Mob', 'Kaiser Chiefs')
# ('Bomb Squad (TECH)', "Brent's Album", 'Brent')
# ('BYURY ME', 'Peanut Butter & Jam ', 'Brent')
# ('Charlie and the Rising Moon', 'Charlie and The Rising Moon', 'Charlie And The Rising Moon')
# ('clay techno ', "Brent's Album", 'Brent')
# ('Cloud Nine Times Over ', 'Charlie and The Rising Moon', 'Charlie And The Rising Moon')
# ('Depression in Session', 'Peanut Butter and Jam ', 'Brent')
# ('Heavy', "Brent's Album", 'Brent')
# ('Hi metal man', "Brent's Album", 'Brent')
# ('Mistro', "Brent's Album", 'Brent')
# ('Pirate spirit', "Brent's Album", 'Brent')
# ('Run Away (New) ', "Brent's Album", 'Brent')
# ('Star Gaze (Inspired)', 'Charlie and The Rising Moon', 'Charlie And The Rising Moon')
# ('The Dictator (New', 'Peanut Butter & Jam ', 'Brent')
# ('Town From Town', "Brent's Album", 'Brent')
# ('The Wisdom of Crowds: Why the Many Are Smarter than the Few Part 1 of 3', 'The Wisdom of Crowds: Why the Many Are Smarter than the Few (Abridged Nonfiction)', 'James Surowiecki')
# ('The Wisdom of Crowds: Why the Many Are Smarter than the Few Part 2 of 3', 'The Wisdom of Crowds: Why the Many Are Smarter than the Few (Abridged Nonfiction)', 'James Surowiecki')
# ('The Wisdom of Crowds: Why the Many Are Smarter than the Few Part 3 of 3', 'The Wisdom of Crowds: Why the Many Are Smarter than the Few (Abridged Nonfiction)', 'James Surowiecki')
# ('The Wisdom of Crowds: Why the Many Are Smarter Than the Few (Unabridged) Part 1 of 5', 'The Wisdom of Crowds: Why the Many Are Smarter Than the Few (Unabridged)', 'James Surowiecki')
# ('The Wisdom of Crowds: Why the Many Are Smarter Than the Few (Unabridged) Part 2 of 5', 'The Wisdom of Crowds: Why the Many Are Smarter Than the Few (Unabridged)', 'James Surowiecki')
# ('The Wisdom of Crowds: Why the Many Are Smarter Than the Few (Unabridged) Part 3 of 5', 'The Wisdom of Crowds: Why the Many Are Smarter Than the Few (Unabridged)', 'James Surowiecki')
# ('The Wisdom of Crowds: Why the Many Are Smarter Than the Few (Unabridged) Part 4 of 5', 'The Wisdom of Crowds: Why the Many Are Smarter Than the Few (Unabridged)', 'James Surowiecki')
# ('The Wisdom of Crowds: Why the Many Are Smarter Than the Few (Unabridged) Part 5 of 5', 'The Wisdom of Crowds: Why the Many Are Smarter Than the Few (Unabridged)', 'James Surowiecki')
# ('Misty', 'Moonlight And Love Songs', 'David Osborne')
# ('My Funny Valentine', 'Moonlight And Love Songs', 'David Osborne')
# ("Since I Don't Have You", 'Moonlight And Love Songs', 'David Osborne')
# ('Tenderly', 'Moonlight And Love Songs', 'David Osborne')
# ('When I Fall In Love', 'Moonlight And Love Songs', 'David Osborne')
# ('Unforgettable', 'Moonlight And Love Songs', 'David Osborne')
# ('The Way You Look Tonight', 'Moonlight And Love Songs', 'David Osborne')
# ("I've Grown Accustomed To Your Face", 'Moonlight And Love Songs', 'David Osborne')
# ('Smoke Gets In Your Eyes', 'Moonlight And Love Songs', 'David Osborne')
# ('Fly Me To The Moon', 'Moonlight And Love Songs', 'David Osborne')
# ('Unchained Melody', 'Moonlight And Love Songs', 'David Osborne')
# ('These Foolish Things Remind Me Of You', 'Moonlight And Love Songs', 'David Osborne')
# ('La Vie En Rose', 'Moonlight And Love Songs', 'David Osborne')
# ('As Time Goes By', 'Moonlight And Love Songs', 'David Osborne')
# ('Pilot', 'Fairly Legal, Season 1', 'Fairly Legal')
# ('Jobs2a', "csev's Album", 'csev')
# ('hte postal service - the impor', 'unreleased demo', 'The Postal Service')
# ('Winter Wonderland', 'Seasons Greatings', 'Bing Crosby')
# ('Jingle Bells', 'Seasons Greatings', 'Bing Crosby')
# ('White Christmas', 'Seasons Greatings', 'Bing Crosby')
# ('The Christmas Song', 'Seasons Greatings', 'Bing Crosby')
# ('Little Drummer Boy', 'Seasons Greatings', 'Bing Crosby')
# ('Silent Night', 'Seasons Greatings', 'Bing Crosby')
# ('Let It Snow', 'Seasons Greatings', 'Bing Crosby')
# ('Mistletoe And Holly', 'Seasons Greatings', 'Bing Crosby')
# ('O Holy Night', 'Seasons Greatings', 'Bing Crosby')
# ('Have Yourself A Merry Little Christmas', 'Seasons Greatings', 'Bing Crosby')
# ('Do You Hear What I Hear', 'Seasons Greatings', 'Bing Crosby')
# ("I'll Be Home For Christmas", 'Seasons Greatings', 'Bing Crosby')
# ('Voices', 'The Sickness', 'Disturbed')
# ('The Game', 'The Sickness', 'Disturbed')
# ('Stupify', 'The Sickness', 'Disturbed')
# ('Down With The Sickness', 'The Sickness', 'Disturbed')
# ('Violence Fetish', 'The Sickness', 'Disturbed')
# ('Fear', 'The Sickness', 'Disturbed')
# ('Numb', 'The Sickness', 'Disturbed')
# ('Want', 'The Sickness', 'Disturbed')
# ('Conflict', 'The Sickness', 'Disturbed')
# ('Shout 2000', 'The Sickness', 'Disturbed')
# ("Droppin' Plates", 'The Sickness', 'Disturbed')
# ('Meaning Of Life', 'The Sickness', 'Disturbed')
# ('Eben Upton: Raspberry Pi', 'Computing Conversations', 'IEEE Computer Society')
# ('Andrew Tanenbaum: Writing the Book on Networks', 'Computing Conversations', 'IEEE Computer Society')
# ('Massimo Banzi: Building Arduino', 'Computing Conversations', 'IEEE Computer Society')
# ('John C. Hollar: History of Computing', 'Computing Conversations', 'IEEE Computer Society')
# ('Bob Metcalfe: Ethernet at Forty', 'Computing Conversations', 'IEEE Computer Society')
# ('Gordon Bell: Building Blocks of Computing', 'Computing Conversations', 'IEEE Computer Society')
# ('Ian Horrocks: Standardizing OWL', 'Computing Conversations', 'IEEE Computer Society')
# ('Katie Hafner: The Origins of the Internet', 'Computing Conversations', 'IEEE Computer Society')
# ('Larry Smarr: Building Mosaic', 'Computing Conversations', 'IEEE Computer Society')
# ('Len Kleinrock: The Theory of Packets', 'Computing Conversations', 'IEEE Computer Society')
# ('Mitchell Baker: The Mozilla Foundation', 'Computing Conversations', 'IEEE Computer Society')
# ('Pooja Sankar: Building the Piazza Collaboration System', 'Computing Conversations', 'IEEE Computer Society')
# ('Van Jacobson: Content-Centric Networking', 'Computing Conversations', 'IEEE Computer Society')
# ('The Apache Software Foundation', 'Computing Conversations', 'IEEE Computer Society')
# ('A Brief History of Packets', 'Computing Conversations', 'IEEE Computer Society')
# ('Discovering JavaScript Object Notation', 'Computing Conversations', 'IEEE Computer Society')
# ('Inventing PHP', 'Computing Conversations', 'IEEE Computer Society')
# ('Monash Museum of Computing History', 'Computing Conversations', 'IEEE Computer Society')
# ('The Rise of JavaScript', 'Computing Conversations', 'IEEE Computer Society')
# ('Joseph Hardin: NCSA Mosaic', 'Computing Conversations', 'IEEE Computer Society')
# ("Len Kleinrock on the Internet's First Two Packets", 'Computing Conversations', 'IEEE Computer Society')
# ('Doug Van Houweling on Building the NSFNet', 'Computing Conversations', 'IEEE Computer Society')
# ('Computing Conversations: Nathaniel Borenstein on MIME', 'Computing Conversations', 'IEEE Computer Society')
# ("You Don't Mess Around With Jim", 'Classic Hits', 'Jim Croce')
# ('Andrew S. Tanenbaum on MINIX', 'Computing Conversations', 'IEEE Computer Society')
# ('Computing Conversations: Elizabeth Fong on SQL Standards', 'Computing Conversations', 'IEEE Computer Society')
# ('Nii Quaynor on Bringing the Internet to Africa', 'Computing Conversations', 'IEEE Computer Society')
# ('PHP-09-Transactions.mp3', "SI 664 W14's official Podcast.", 'Created by Sakai')
# ('PHP-01-Intro.mp3', "SI 664 W14's official Podcast.", 'Created by Sakai')
# ('PHP-02-Install.mp3', "SI 664 W14's official Podcast.", 'Created by Sakai')
# ('PHP-04-Expressions.mp3', "SI 664 W14's official Podcast.", 'Created by Sakai')
# ('PHP-05-Functions.mp3', "SI 664 W14's official Podcast.", 'Created by Sakai')
# ('PHP-06-Strings.mp3', "SI 664 W14's official Podcast.", 'Created by Sakai')
# ('PHP-12-Sessions.mp3', "SI 664 W14's official Podcast.", 'Created by Sakai')
# ('PHP-06-Objects.mp3', "SI 664 W14's official Podcast.", 'Created by Sakai')
# ('SI664-13-JSON-A.mp3', "SI 664 W14's official Podcast.", 'Created by Sakai')
# ('PHP-13-JavaScript.mp3', "SI 664 W14's official Podcast.", 'Created by Sakai')
# ('PHP-09-Database-Design.mp3', "SI 664 W14's official Podcast.", 'Created by Sakai')
# ('PHP-Tsugi-Install.mp3', "SI 664 W14's official Podcast.", 'Created by Sakai')
# ('PHP-10-MySQL-PDO.mp3', "SI 664 W14's official Podcast.", 'Created by Sakai')
# ('PHP-08-MySQL.mp3', "SI 664 W14's official Podcast.", 'Created by Sakai')
# ('SI664-13-JSON-B.mp3', "SI 664 W14's official Podcast.", 'Created by Sakai')
# ('IMS-Learning-Tools-Interoperability.mp3', "SI 664 W14's official Podcast.", 'Created by Sakai')
# ('An Interview with Don Waters', 'CNI Event Coverage', 'Matt Pasiewicz')
# ('PY4INF-11-Regex.mp3', "Python for Informatics's official Podcast.", 'Recording by Dr. Chuck')
# ('PY4INF-10-Tuples.mp3', "Python for Informatics's official Podcast.", 'Recording by Dr. Chuck')
# ('PY4INF-09-Dictionaries.mp3', "Python for Informatics's official Podcast.", 'Recording by Dr. Chuck')
# ('PY4INF-08-Lists.mp3', "Python for Informatics's official Podcast.", 'Recording by Dr. Chuck')
# ('PY4INF-07-Files.mp3', "Python for Informatics's official Podcast.", 'Recording by Dr. Chuck')
# ('PY4INF-06-Strings.mp3', "Python for Informatics's official Podcast.", 'Recording by Dr. Chuck')
# ('PY4INF-05-Iterations.mp3', "Python for Informatics's official Podcast.", 'Recording by Dr. Chuck')
# ('PY4INF-04-Functions.mp3', "Python for Informatics's official Podcast.", 'Recording by Dr. Chuck')
# ('PY4INF-03-Conditional.mp3', "Python for Informatics's official Podcast.", 'Recording by Dr. Chuck')
# ('PY4INF-02-Expressions.mp3', "Python for Informatics's official Podcast.", 'Recording by Dr. Chuck')
# ('PY4INF-01-Intro.mp3', "Python for Informatics's official Podcast.", 'Recording by Dr. Chuck')
# ('Py4Inf-11-Regex.mp3', "Python for Informatics's official Podcast.", 'Recording by Dr. Chuck')
# ('Py4Inf-10-Tuples.mp3', "Python for Informatics's official Podcast.", 'Recording by Dr. Chuck')
# ('Py4Inf-09-Dictionaries.mp3', "Python for Informatics's official Podcast.", 'Recording by Dr. Chuck')
# ('Py4Inf-08-Lists.mp3', "Python for Informatics's official Podcast.", 'Recording by Dr. Chuck')
# ('Py4Inf-07-Files.mp3', "Python for Informatics's official Podcast.", 'Recording by Dr. Chuck')
# ('Py4Inf-06-Strings.mp3', "Python for Informatics's official Podcast.", 'Recording by Dr. Chuck')
# ('Py4Inf-05-Iterations.mp3', "Python for Informatics's official Podcast.", 'Recording by Dr. Chuck')
# ('Py4Inf-04-Functions.mp3', "Python for Informatics's official Podcast.", 'Recording by Dr. Chuck')
# ('Py4Inf-03-Conditional.mp3', "Python for Informatics's official Podcast.", 'Recording by Dr. Chuck')
# ('Py4Inf-02-Expressions.mp3', "Python for Informatics's official Podcast.", 'Recording by Dr. Chuck')
# ('Py4Inf-01-Intro.mp3', "Python for Informatics's official Podcast.", 'Recording by Dr. Chuck')
# ('Ian Foster on the Globus Project', 'Computing Conversations', 'IEEE Computer Society')
# ('Khan Academy and Computer Science', 'Computing Conversations', 'IEEE Computer Society')
# ('Guido van Rossumon the Early Years of Python', 'Computing Conversations', 'IEEE Computer Society')
# ('Guido van Rossum on the Modern Era of Python', 'Computing Conversations', 'IEEE Computer Society')
# ('John Resig on Building jQuery', 'Computing Conversations', 'IEEE Computer Society')
# ('Roy T. Fielding on Understanding the REST Style', 'Computing Conversations', 'IEEE Computer Society')
# ('Anil Jain: 25 Years of Biometric Recognition', 'Computing Conversations', 'IEEE Computer Society')
# ('Waste Management', 'Undercover Boss, Season 1', 'Undercover Boss')
# ('Sleep Like a Baby Tonight', 'Songs of Innocence', 'U2')
# ('Evergreen', 'Warpaint', 'The Black Crowes')
# ('Oh Josephine', 'Warpaint', 'The Black Crowes')
# ("Movin' On Down the Line", 'Warpaint', 'The Black Crowes')
# ('Wounded Bird', 'Warpaint', 'The Black Crowes')
# ('Volcano', 'Songs of Innocence', 'U2')
# ('Wee Who See the Deep', 'Warpaint', 'The Black Crowes')
# ('Cedarwood Road', 'Songs of Innocence', 'U2')
# ('Locust Street', 'Warpaint', 'The Black Crowes')
# ('Raised By Wolves', 'Songs of Innocence', 'U2')
# ('The Troubles', 'Songs of Innocence', 'U2')
# ('This Is Where You Can Reach Me Now', 'Songs of Innocence', 'U2')
# ("God's Got It", 'Warpaint', 'The Black Crowes')
# ('California (There Is No End to Love)', 'Songs of Innocence', 'U2')
# ('Every Breaking Wave', 'Songs of Innocence', 'U2')
# ('Interview With the Onion News Network', 'Onion News Network, Season 1', 'Onion News Network')
# ('Song for Someone', 'Songs of Innocence', 'U2')
# ('The Miracle (Of Joey Ramone)', 'Songs of Innocence', 'U2')
# ('Iris (Hold Me Close)', 'Songs of Innocence', 'U2')
# ('Goodbye Daughters of the Revolution', 'Warpaint', 'The Black Crowes')
# ('Walk Believer Walk', 'Warpaint', 'The Black Crowes')
# ('Choice Hotels International', 'Undercover Boss, Season 2', 'Undercover Boss')
# ('Microchip', 'YouTube Audio Library', 'Jason Farnham')
# ('Anant Agarwal', 'Computing Conversations', 'IEEE Computer Society')

# %%
sqlstr =('Select Track.title,Album.title,Artist.name From Track join Album join Artist on Track.album_id = Album.id AND Album.artist_id = Artist.id order by Artist.name')
for row in cur.execute(sqlstr):
    print(row)
# Out:
# ('For Those About To Rock (We Salute You)', 'Who Made Who', 'AC/DC')
# ('Hells Bells', 'Who Made Who', 'AC/DC')
# ('Shake Your Foundations', 'Who Made Who', 'AC/DC')
# ('You Shook Me All Night Long', 'Who Made Who', 'AC/DC')
# ('Who Made Who', 'Who Made Who', 'AC/DC')
# ('D.T.', 'Who Made Who', 'AC/DC')
# ('Sink the Pink', 'Who Made Who', 'AC/DC')
# ('Ride On', 'Who Made Who', 'AC/DC')
# ('Chase the Ace', 'Who Made Who', 'AC/DC')
# ('Track 01', 'Danger Zone', 'Billy Price')
# ('Track 02', 'Danger Zone', 'Billy Price')
# ('Track 03', 'Danger Zone', 'Billy Price')
# ('Track 04', 'Danger Zone', 'Billy Price')
# ('Track 05', 'Danger Zone', 'Billy Price')
# ('Winter Wonderland', 'Seasons Greatings', 'Bing Crosby')
# ('Jingle Bells', 'Seasons Greatings', 'Bing Crosby')
# ('White Christmas', 'Seasons Greatings', 'Bing Crosby')
# ('The Christmas Song', 'Seasons Greatings', 'Bing Crosby')
# ('Little Drummer Boy', 'Seasons Greatings', 'Bing Crosby')
# ('Silent Night', 'Seasons Greatings', 'Bing Crosby')
# ('Let It Snow', 'Seasons Greatings', 'Bing Crosby')
# ('Mistletoe And Holly', 'Seasons Greatings', 'Bing Crosby')
# ('O Holy Night', 'Seasons Greatings', 'Bing Crosby')
# ('Have Yourself A Merry Little Christmas', 'Seasons Greatings', 'Bing Crosby')
# ('Do You Hear What I Hear', 'Seasons Greatings', 'Bing Crosby')
# ("I'll Be Home For Christmas", 'Seasons Greatings', 'Bing Crosby')
# ('Electric Funeral', 'Paranoid', 'Black Sabbath')
# ('Hand of Doom', 'Paranoid', 'Black Sabbath')
# ('Iron Man', 'Paranoid', 'Black Sabbath')
# ('Jack the Stripper/Fairies Wear Boots', 'Paranoid', 'Black Sabbath')
# ('Paranoid', 'Paranoid', 'Black Sabbath')
# ('Planet Caravan', 'Paranoid', 'Black Sabbath')
# ('Rat Salad', 'Paranoid', 'Black Sabbath')
# ("War Pigs/Luke's Wall", 'Paranoid', 'Black Sabbath')
# ('Bomb Squad (TECH)', "Brent's Album", 'Brent')
# ('BYURY ME', 'Peanut Butter & Jam ', 'Brent')
# ('clay techno ', "Brent's Album", 'Brent')
# ('Depression in Session', 'Peanut Butter and Jam ', 'Brent')
# ('Heavy', "Brent's Album", 'Brent')
# ('Hi metal man', "Brent's Album", 'Brent')
# ('Mistro', "Brent's Album", 'Brent')
# ('Pirate spirit', "Brent's Album", 'Brent')
# ('Run Away (New) ', "Brent's Album", 'Brent')
# ('The Dictator (New', 'Peanut Butter & Jam ', 'Brent')
# ('Town From Town', "Brent's Album", 'Brent')
# ('Circles', 'Blues Is', 'Bryan Lee')
# ('Gelle', 'Blues Is', 'Bryan Lee')
# ('I Worry', 'Blues Is', 'Bryan Lee')
# ('Its Your Move', 'Blues Is', 'Bryan Lee')
# ('Let me Down Easy', 'Blues Is', 'Bryan Lee')
# ('No Low Down', 'Blues Is', 'Bryan Lee')
# ('Pretty Jeanie', 'Blues Is', 'Bryan Lee')
# ('The Blues "Is"', 'Blues Is', 'Bryan Lee')
# ('There it Is', 'Blues Is', 'Bryan Lee')
# ('Think', 'Blues Is', 'Bryan Lee')
# ('Waiting on Ice', 'Blues Is', 'Bryan Lee')
# ('You Done Me Wrong', 'Blues Is', 'Bryan Lee')
# ('Charlie and the Rising Moon', 'Charlie and The Rising Moon', 'Charlie And The Rising Moon')
# ('Cloud Nine Times Over ', 'Charlie and The Rising Moon', 'Charlie And The Rising Moon')
# ('Star Gaze (Inspired)', 'Charlie and The Rising Moon', 'Charlie And The Rising Moon')
# ('PHP-09-Transactions.mp3', "SI 664 W14's official Podcast.", 'Created by Sakai')
# ('PHP-01-Intro.mp3', "SI 664 W14's official Podcast.", 'Created by Sakai')
# ('PHP-02-Install.mp3', "SI 664 W14's official Podcast.", 'Created by Sakai')
# ('PHP-04-Expressions.mp3', "SI 664 W14's official Podcast.", 'Created by Sakai')
# ('PHP-05-Functions.mp3', "SI 664 W14's official Podcast.", 'Created by Sakai')
# ('PHP-06-Strings.mp3', "SI 664 W14's official Podcast.", 'Created by Sakai')
# ('PHP-12-Sessions.mp3', "SI 664 W14's official Podcast.", 'Created by Sakai')
# ('PHP-06-Objects.mp3', "SI 664 W14's official Podcast.", 'Created by Sakai')
# ('SI664-13-JSON-A.mp3', "SI 664 W14's official Podcast.", 'Created by Sakai')
# ('PHP-13-JavaScript.mp3', "SI 664 W14's official Podcast.", 'Created by Sakai')
# ('PHP-09-Database-Design.mp3', "SI 664 W14's official Podcast.", 'Created by Sakai')
# ('PHP-Tsugi-Install.mp3', "SI 664 W14's official Podcast.", 'Created by Sakai')
# ('PHP-10-MySQL-PDO.mp3', "SI 664 W14's official Podcast.", 'Created by Sakai')
# ('PHP-08-MySQL.mp3', "SI 664 W14's official Podcast.", 'Created by Sakai')
# ('SI664-13-JSON-B.mp3', "SI 664 W14's official Podcast.", 'Created by Sakai')
# ('IMS-Learning-Tools-Interoperability.mp3', "SI 664 W14's official Podcast.", 'Created by Sakai')
# ('Misty', 'Moonlight And Love Songs', 'David Osborne')
# ('My Funny Valentine', 'Moonlight And Love Songs', 'David Osborne')
# ("Since I Don't Have You", 'Moonlight And Love Songs', 'David Osborne')
# ('Tenderly', 'Moonlight And Love Songs', 'David Osborne')
# ('When I Fall In Love', 'Moonlight And Love Songs', 'David Osborne')
# ('Unforgettable', 'Moonlight And Love Songs', 'David Osborne')
# ('The Way You Look Tonight', 'Moonlight And Love Songs', 'David Osborne')
# ("I've Grown Accustomed To Your Face", 'Moonlight And Love Songs', 'David Osborne')
# ('Smoke Gets In Your Eyes', 'Moonlight And Love Songs', 'David Osborne')
# ('Fly Me To The Moon', 'Moonlight And Love Songs', 'David Osborne')
# ('Unchained Melody', 'Moonlight And Love Songs', 'David Osborne')
# ('These Foolish Things Remind Me Of You', 'Moonlight And Love Songs', 'David Osborne')
# ('La Vie En Rose', 'Moonlight And Love Songs', 'David Osborne')
# ('As Time Goes By', 'Moonlight And Love Songs', 'David Osborne')
# ('Voices', 'The Sickness', 'Disturbed')
# ('The Game', 'The Sickness', 'Disturbed')
# ('Stupify', 'The Sickness', 'Disturbed')
# ('Down With The Sickness', 'The Sickness', 'Disturbed')
# ('Violence Fetish', 'The Sickness', 'Disturbed')
# ('Fear', 'The Sickness', 'Disturbed')
# ('Numb', 'The Sickness', 'Disturbed')
# ('Want', 'The Sickness', 'Disturbed')
# ('Conflict', 'The Sickness', 'Disturbed')
# ('Shout 2000', 'The Sickness', 'Disturbed')
# ("Droppin' Plates", 'The Sickness', 'Disturbed')
# ('Meaning Of Life', 'The Sickness', 'Disturbed')
# ('Pilot', 'Fairly Legal, Season 1', 'Fairly Legal')
# ('Eben Upton: Raspberry Pi', 'Computing Conversations', 'IEEE Computer Society')
# ('Andrew Tanenbaum: Writing the Book on Networks', 'Computing Conversations', 'IEEE Computer Society')
# ('Massimo Banzi: Building Arduino', 'Computing Conversations', 'IEEE Computer Society')
# ('John C. Hollar: History of Computing', 'Computing Conversations', 'IEEE Computer Society')
# ('Bob Metcalfe: Ethernet at Forty', 'Computing Conversations', 'IEEE Computer Society')
# ('Gordon Bell: Building Blocks of Computing', 'Computing Conversations', 'IEEE Computer Society')
# ('Ian Horrocks: Standardizing OWL', 'Computing Conversations', 'IEEE Computer Society')
# ('Katie Hafner: The Origins of the Internet', 'Computing Conversations', 'IEEE Computer Society')
# ('Larry Smarr: Building Mosaic', 'Computing Conversations', 'IEEE Computer Society')
# ('Len Kleinrock: The Theory of Packets', 'Computing Conversations', 'IEEE Computer Society')
# ('Mitchell Baker: The Mozilla Foundation', 'Computing Conversations', 'IEEE Computer Society')
# ('Pooja Sankar: Building the Piazza Collaboration System', 'Computing Conversations', 'IEEE Computer Society')
# ('Van Jacobson: Content-Centric Networking', 'Computing Conversations', 'IEEE Computer Society')
# ('The Apache Software Foundation', 'Computing Conversations', 'IEEE Computer Society')
# ('A Brief History of Packets', 'Computing Conversations', 'IEEE Computer Society')
# ('Discovering JavaScript Object Notation', 'Computing Conversations', 'IEEE Computer Society')
# ('Inventing PHP', 'Computing Conversations', 'IEEE Computer Society')
# ('Monash Museum of Computing History', 'Computing Conversations', 'IEEE Computer Society')
# ('The Rise of JavaScript', 'Computing Conversations', 'IEEE Computer Society')
# ('Joseph Hardin: NCSA Mosaic', 'Computing Conversations', 'IEEE Computer Society')
# ("Len Kleinrock on the Internet's First Two Packets", 'Computing Conversations', 'IEEE Computer Society')
# ('Doug Van Houweling on Building the NSFNet', 'Computing Conversations', 'IEEE Computer Society')
# ('Computing Conversations: Nathaniel Borenstein on MIME', 'Computing Conversations', 'IEEE Computer Society')
# ('Andrew S. Tanenbaum on MINIX', 'Computing Conversations', 'IEEE Computer Society')
# ('Computing Conversations: Elizabeth Fong on SQL Standards', 'Computing Conversations', 'IEEE Computer Society')
# ('Nii Quaynor on Bringing the Internet to Africa', 'Computing Conversations', 'IEEE Computer Society')
# ('Ian Foster on the Globus Project', 'Computing Conversations', 'IEEE Computer Society')
# ('Khan Academy and Computer Science', 'Computing Conversations', 'IEEE Computer Society')
# ('Guido van Rossumon the Early Years of Python', 'Computing Conversations', 'IEEE Computer Society')
# ('Guido van Rossum on the Modern Era of Python', 'Computing Conversations', 'IEEE Computer Society')
# ('John Resig on Building jQuery', 'Computing Conversations', 'IEEE Computer Society')
# ('Roy T. Fielding on Understanding the REST Style', 'Computing Conversations', 'IEEE Computer Society')
# ('Anil Jain: 25 Years of Biometric Recognition', 'Computing Conversations', 'IEEE Computer Society')
# ('Anant Agarwal', 'Computing Conversations', 'IEEE Computer Society')
# ('The Wisdom of Crowds: Why the Many Are Smarter than the Few Part 1 of 3', 'The Wisdom of Crowds: Why the Many Are Smarter than the Few (Abridged Nonfiction)', 'James Surowiecki')
# ('The Wisdom of Crowds: Why the Many Are Smarter than the Few Part 2 of 3', 'The Wisdom of Crowds: Why the Many Are Smarter than the Few (Abridged Nonfiction)', 'James Surowiecki')
# ('The Wisdom of Crowds: Why the Many Are Smarter than the Few Part 3 of 3', 'The Wisdom of Crowds: Why the Many Are Smarter than the Few (Abridged Nonfiction)', 'James Surowiecki')
# ('The Wisdom of Crowds: Why the Many Are Smarter Than the Few (Unabridged) Part 1 of 5', 'The Wisdom of Crowds: Why the Many Are Smarter Than the Few (Unabridged)', 'James Surowiecki')
# ('The Wisdom of Crowds: Why the Many Are Smarter Than the Few (Unabridged) Part 2 of 5', 'The Wisdom of Crowds: Why the Many Are Smarter Than the Few (Unabridged)', 'James Surowiecki')
# ('The Wisdom of Crowds: Why the Many Are Smarter Than the Few (Unabridged) Part 3 of 5', 'The Wisdom of Crowds: Why the Many Are Smarter Than the Few (Unabridged)', 'James Surowiecki')
# ('The Wisdom of Crowds: Why the Many Are Smarter Than the Few (Unabridged) Part 4 of 5', 'The Wisdom of Crowds: Why the Many Are Smarter Than the Few (Unabridged)', 'James Surowiecki')
# ('The Wisdom of Crowds: Why the Many Are Smarter Than the Few (Unabridged) Part 5 of 5', 'The Wisdom of Crowds: Why the Many Are Smarter Than the Few (Unabridged)', 'James Surowiecki')
# ('Microchip', 'YouTube Audio Library', 'Jason Farnham')
# ('Open Road', 'Relaxing Jazz', 'Jeff Bailey')
# ("You Don't Mess Around With Jim", 'Classic Hits', 'Jim Croce')
# ('Folsom Prison Blues', 'The Legend Of Johnny Cash', 'Johnny Cash')
# ('I Walk The Line', 'The Legend Of Johnny Cash', 'Johnny Cash')
# ('Get Rhythm', 'The Legend Of Johnny Cash', 'Johnny Cash')
# ('Big River', 'The Legend Of Johnny Cash', 'Johnny Cash')
# ('Guess Things Happen That Way', 'The Legend Of Johnny Cash', 'Johnny Cash')
# ('Ring Of Fire', 'The Legend Of Johnny Cash', 'Johnny Cash')
# ('Jackson', 'The Legend Of Johnny Cash', 'Johnny Cash')
# ('A Boy Named Sue (live)', 'The Legend Of Johnny Cash', 'Johnny Cash')
# ('Ruby', 'Yours Truly, Angry Mob', 'Kaiser Chiefs')
# ('The Angry Mob', 'Yours Truly, Angry Mob', 'Kaiser Chiefs')
# ('Heat Dies Down', 'Yours Truly, Angry Mob', 'Kaiser Chiefs')
# ('Highroyds', 'Yours Truly, Angry Mob', 'Kaiser Chiefs')
# ("Love's Not A Competition (But I'm Winning)", 'Yours Truly, Angry Mob', 'Kaiser Chiefs')
# ('Thank You Very Much', 'Yours Truly, Angry Mob', 'Kaiser Chiefs')
# ('I Can Do It Without You', 'Yours Truly, Angry Mob', 'Kaiser Chiefs')
# ('My Kind Of Guy', 'Yours Truly, Angry Mob', 'Kaiser Chiefs')
# ('Everything Is Average Nowadays', 'Yours Truly, Angry Mob', 'Kaiser Chiefs')
# ('Learnt My Lesson Well', 'Yours Truly, Angry Mob', 'Kaiser Chiefs')
# ('Try Your Best', 'Yours Truly, Angry Mob', 'Kaiser Chiefs')
# ('Retirement', 'Yours Truly, Angry Mob', 'Kaiser Chiefs')
# ('The Angry Mob [Live From Berlin]', 'Yours Truly, Angry Mob', 'Kaiser Chiefs')
# ('I Like To Fight', 'Yours Truly, Angry Mob', 'Kaiser Chiefs')
# ('From The Neck Down', 'Yours Truly, Angry Mob', 'Kaiser Chiefs')
# ('Black Dog', 'IV', 'Led Zeppelin')
# ('Four Sticks', 'IV', 'Led Zeppelin')
# ('Going To California', 'IV', 'Led Zeppelin')
# ('Misty Mountain Hop', 'IV', 'Led Zeppelin')
# ('Rock & Roll', 'IV', 'Led Zeppelin')
# ('Stairway To Heaven', 'IV', 'Led Zeppelin')
# ('The Battle Of Evermore', 'IV', 'Led Zeppelin')
# ('When The Levee Breaks', 'IV', 'Led Zeppelin')
# ('Mother Joy', 'Natural Wonders Music Sampler 1999', 'Matt Ender')
# ("Soldier's Lament", 'Natural Wonders Music Sampler 1999', 'Matt Ender')
# ('Dulaman', 'Natural Wonders Music Sampler 1999', 'Matt Ender')
# ('The Arrow', 'Natural Wonders Music Sampler 1999', 'Matt Ender')
# ('Spanish Eyes', 'Natural Wonders Music Sampler 1999', 'Matt Ender')
# ('Banana Bay', 'Natural Wonders Music Sampler 1999', 'Matt Ender')
# ('Aguas De Marco', 'Natural Wonders Music Sampler 1999', 'Matt Ender')
# ('Tamborea', 'Natural Wonders Music Sampler 1999', 'Matt Ender')
# ('Gone', 'Natural Wonders Music Sampler 1999', 'Matt Ender')
# ('The Immigrant', 'Natural Wonders Music Sampler 1999', 'Matt Ender')
# ('Pahrump-Big Water', 'Natural Wonders Music Sampler 1999', 'Matt Ender')
# ("Seeker's Quest", 'Natural Wonders Music Sampler 1999', 'Matt Ender')
# ('Floating To Forever', 'Natural Wonders Music Sampler 1999', 'Matt Ender')
# ('An Interview with Don Waters', 'CNI Event Coverage', 'Matt Pasiewicz')
# ('Interview With the Onion News Network', 'Onion News Network, Season 1', 'Onion News Network')
# ('Bring The Boys Back Home', 'The Wall [Disc 2]', 'Pink Floyd')
# ('Comfortably Numb', 'The Wall [Disc 2]', 'Pink Floyd')
# ('Hey You', 'The Wall [Disc 2]', 'Pink Floyd')
# ('Is There Anybody Out There?', 'The Wall [Disc 2]', 'Pink Floyd')
# ('Outside The Wall', 'The Wall [Disc 2]', 'Pink Floyd')
# ('Another One Bites The Dust', 'Greatest Hits', 'Queen')
# ('Crazy Little Thing Called Love', 'Greatest Hits', 'Queen')
# ('Fat Bottomed Girls', 'Greatest Hits', 'Queen')
# ('It was a Very Good Year', 'Greatest Hits', 'Queen')
# ('Killer Queen', 'Greatest Hits', 'Queen')
# ('Now You Are Gone', 'Greatest Hits', 'Queen')
# ('Rode Across the Desert', 'Greatest Hits', 'Queen')
# ('Sister Golden Hair', 'Greatest Hits', 'Queen')
# ('Somebody To Love', 'Greatest Hits', 'Queen')
# ('Strangers in the Night', 'Greatest Hits', 'Queen')
# ('Summer Wind', 'Greatest Hits', 'Queen')
# ('Thats Life', 'Greatest Hits', 'Queen')
# ('This Town', 'Greatest Hits', 'Queen')
# ('Tin Man', 'Greatest Hits', 'Queen')
# ('We Are The Champions', 'Greatest Hits', 'Queen')
# ('We Will Rock You', 'Greatest Hits', 'Queen')
# ('When Somebody Loves You', 'Greatest Hits', 'Queen')
# ("You're My Best Friend", 'Greatest Hits', 'Queen')
# ('Asche Zu Asche', 'Herzeleid', 'Rammstein')
# ('Laichzeit', 'Herzeleid', 'Rammstein')
# ('Rammstein', 'Herzeleid', 'Rammstein')
# ('Wollt Ihr Das Bett In Flammen Sehen', 'Herzeleid', 'Rammstein')
# ('Der Meister', 'Herzeleid', 'Rammstein')
# ('Weisses Fleisch', 'Herzeleid', 'Rammstein')
# ('Seemann', 'Herzeleid', 'Rammstein')
# ('Du Riechst So Gut', 'Herzeleid', 'Rammstein')
# ('Das Alte Leid', 'Herzeleid', 'Rammstein')
# ('Heirate Mich', 'Herzeleid', 'Rammstein')
# ('Herzeleid', 'Herzeleid', 'Rammstein')
# ('PY4INF-11-Regex.mp3', "Python for Informatics's official Podcast.", 'Recording by Dr. Chuck')
# ('PY4INF-10-Tuples.mp3', "Python for Informatics's official Podcast.", 'Recording by Dr. Chuck')
# ('PY4INF-09-Dictionaries.mp3', "Python for Informatics's official Podcast.", 'Recording by Dr. Chuck')
# ('PY4INF-08-Lists.mp3', "Python for Informatics's official Podcast.", 'Recording by Dr. Chuck')
# ('PY4INF-07-Files.mp3', "Python for Informatics's official Podcast.", 'Recording by Dr. Chuck')
# ('PY4INF-06-Strings.mp3', "Python for Informatics's official Podcast.", 'Recording by Dr. Chuck')
# ('PY4INF-05-Iterations.mp3', "Python for Informatics's official Podcast.", 'Recording by Dr. Chuck')
# ('PY4INF-04-Functions.mp3', "Python for Informatics's official Podcast.", 'Recording by Dr. Chuck')
# ('PY4INF-03-Conditional.mp3', "Python for Informatics's official Podcast.", 'Recording by Dr. Chuck')
# ('PY4INF-02-Expressions.mp3', "Python for Informatics's official Podcast.", 'Recording by Dr. Chuck')
# ('PY4INF-01-Intro.mp3', "Python for Informatics's official Podcast.", 'Recording by Dr. Chuck')
# ('Py4Inf-11-Regex.mp3', "Python for Informatics's official Podcast.", 'Recording by Dr. Chuck')
# ('Py4Inf-10-Tuples.mp3', "Python for Informatics's official Podcast.", 'Recording by Dr. Chuck')
# ('Py4Inf-09-Dictionaries.mp3', "Python for Informatics's official Podcast.", 'Recording by Dr. Chuck')
# ('Py4Inf-08-Lists.mp3', "Python for Informatics's official Podcast.", 'Recording by Dr. Chuck')
# ('Py4Inf-07-Files.mp3', "Python for Informatics's official Podcast.", 'Recording by Dr. Chuck')
# ('Py4Inf-06-Strings.mp3', "Python for Informatics's official Podcast.", 'Recording by Dr. Chuck')
# ('Py4Inf-05-Iterations.mp3', "Python for Informatics's official Podcast.", 'Recording by Dr. Chuck')
# ('Py4Inf-04-Functions.mp3', "Python for Informatics's official Podcast.", 'Recording by Dr. Chuck')
# ('Py4Inf-03-Conditional.mp3', "Python for Informatics's official Podcast.", 'Recording by Dr. Chuck')
# ('Py4Inf-02-Expressions.mp3', "Python for Informatics's official Podcast.", 'Recording by Dr. Chuck')
# ('Py4Inf-01-Intro.mp3', "Python for Informatics's official Podcast.", 'Recording by Dr. Chuck')
# ('Furious Angels', 'The Matrix Reloaded', 'Rob Dougan')
# ('Zion', 'The Matrix Reloaded', 'Rob Dougan')
# ('You Raise Me Up', 'Hiding Place', 'Selah')
# ('Evergreen', 'Warpaint', 'The Black Crowes')
# ('Oh Josephine', 'Warpaint', 'The Black Crowes')
# ("Movin' On Down the Line", 'Warpaint', 'The Black Crowes')
# ('Wounded Bird', 'Warpaint', 'The Black Crowes')
# ('Wee Who See the Deep', 'Warpaint', 'The Black Crowes')
# ('Locust Street', 'Warpaint', 'The Black Crowes')
# ("God's Got It", 'Warpaint', 'The Black Crowes')
# ('Goodbye Daughters of the Revolution', 'Warpaint', 'The Black Crowes')
# ('Walk Believer Walk', 'Warpaint', 'The Black Crowes')
# ('Messin with the Kid', 'Self Titled', 'The Canettes Blues Band')
# ('Stormy Monday', 'Self Titled', 'The Canettes Blues Band')
# ("Hold On, I'm Coming", 'On Tap & In the Can', 'The Canettes Blues Band')
# ('Got my Mojo Working', 'On Tap & In the Can', 'The Canettes Blues Band')
# ('Sweet Home Chicago', 'On Tap & In the Can', 'The Canettes Blues Band')
# ('Heavy Love', 'On Tap & In the Can', 'The Canettes Blues Band')
# ('Cold Cold Feeling', 'On Tap & In the Can', 'The Canettes Blues Band')
# ('Lonely Avenue', 'On Tap & In the Can', 'The Canettes Blues Band')
# ('Good Morning Little Schoolgirl', 'On Tap & In the Can', 'The Canettes Blues Band')
# ('Dust My Broom', 'On Tap & In the Can', 'The Canettes Blues Band')
# ("Gimme' Some Lovin", 'On Tap & In the Can', 'The Canettes Blues Band')
# ('Everybody Needs Somebody to Love', 'On Tap & In the Can', 'The Canettes Blues Band')
# ('Black Magic Woman', 'On Tap & In the Can', 'The Canettes Blues Band')
# ("Steppin' Rooster", 'On Tap & In the Can', 'The Canettes Blues Band')
# ('Our Love is Drifting', 'On Tap & In the Can', 'The Canettes Blues Band')
# ("Doin' 100", 'On Tap & In the Can', 'The Canettes Blues Band')
# ('hte postal service - the impor', 'unreleased demo', 'The Postal Service')
# ("Baba O'Riley", "Who's Next", 'The Who')
# ('Bargain', "Who's Next", 'The Who')
# ("Love Ain't for Keeping", "Who's Next", 'The Who')
# ('My Wife', "Who's Next", 'The Who')
# ('The Song Is Over', "Who's Next", 'The Who')
# ('Getting In Tune', "Who's Next", 'The Who')
# ('Going Mobile', "Who's Next", 'The Who')
# ('Behind Blue Eyes', "Who's Next", 'The Who')
# ("Won't Get Fooled Again", "Who's Next", 'The Who')
# ('Sleep Like a Baby Tonight', 'Songs of Innocence', 'U2')
# ('Volcano', 'Songs of Innocence', 'U2')
# ('Cedarwood Road', 'Songs of Innocence', 'U2')
# ('Raised By Wolves', 'Songs of Innocence', 'U2')
# ('The Troubles', 'Songs of Innocence', 'U2')
# ('This Is Where You Can Reach Me Now', 'Songs of Innocence', 'U2')
# ('California (There Is No End to Love)', 'Songs of Innocence', 'U2')
# ('Every Breaking Wave', 'Songs of Innocence', 'U2')
# ('Song for Someone', 'Songs of Innocence', 'U2')
# ('The Miracle (Of Joey Ramone)', 'Songs of Innocence', 'U2')
# ('Iris (Hold Me Close)', 'Songs of Innocence', 'U2')
# ('Waste Management', 'Undercover Boss, Season 1', 'Undercover Boss')
# ('Choice Hotels International', 'Undercover Boss, Season 2', 'Undercover Boss')
# ('Beauty School Dropout', 'Grease', 'Various')
# ('Grease', 'Grease', 'Various')
# ('Sandy', 'Grease', 'Various')
# ('Summer Nights', 'Grease', 'Various')
# ('You are the One that I Want', 'Grease', 'Various')
# ('Jobs2a', "csev's Album", 'csev')

# %%
import xml.etree.ElementTree as ET
import sqlite3

conn = sqlite3.connect('trackdb.sqlite')
cur = conn.cursor()

# Make some fresh tables using executescript()
cur.executescript('''
DROP TABLE IF EXISTS Artist;
DROP TABLE IF EXISTS Album;
DROP TABLE IF EXISTS Track;

CREATE TABLE Artist (
    id  INTEGER NOT NULL PRIMARY KEY AUTOINCREMENT UNIQUE,
    name    TEXT UNIQUE
);

CREATE TABLE Album (
    id  INTEGER NOT NULL PRIMARY KEY AUTOINCREMENT UNIQUE,
    artist_id  INTEGER,
    title   TEXT UNIQUE
);

CREATE TABLE Track (
    id  INTEGER NOT NULL PRIMARY KEY 
        AUTOINCREMENT UNIQUE,
    title TEXT  UNIQUE,
    album_id  INTEGER,
    len INTEGER, rating INTEGER, count INTEGER
);
''')

fname = input('Enter a filename:')
if len(fname) < 1 : fname = 'Library.xml'
    
def lookup(d,key):
    found = False
    for child in d:
        if found: return child.text
        if (child.tag == 'key' and child.text == key):
            found = True
        
    return None

stuff = ET.parse(fname)
all = stuff.findall('dict/dict/dict')
print('Data retrieved:',len(all))

for entry in all:
    
    if (lookup(entry,'Track ID') is None): continue
    name = lookup(entry,'Name')
    artist = lookup(entry,'Artist')
    album = lookup(entry, 'Album')
    length = lookup(entry,'Total Time') 
    count = lookup(entry,'Play Count')
    rating = lookup(entry,'Rating')
    
    if name is None or artist is None or album is None : continue
        
    print(name,artist,album,count,rating,length)
    
    cur.execute('Insert or Ignore into Artist(name) values(?)',(artist,))
    cur.execute('Select id from Artist where name = ?',(artist,))
    artist_id = cur.fetchone()[0]
    
    cur.execute('Insert or Ignore into Album(artist_id,title) values(?,?)',(artist_id,album))
    cur.execute('Select id from Album where title = ?',(album,))
    album_id = cur.fetchone()[0]
    
    cur.execute('Insert or Ignore into Track(title,album_id,len,rating,count) values(?,?,?,?,?)',(name,album_id,length,rating,count))
    
    conn.commit()
# Out:
# Enter a filename:
# Data retrieved: 404
# Another One Bites The Dust Queen Greatest Hits 55 100 217103
# Asche Zu Asche Rammstein Herzeleid 79 100 231810
# Beauty School Dropout Various Grease 48 100 239960
# Black Dog Led Zeppelin IV 109 100 296620
# Bring The Boys Back Home Pink Floyd The Wall [Disc 2] 33 100 87118
# Circles Bryan Lee Blues Is 54 60 355369
# Comfortably Numb Pink Floyd The Wall [Disc 2] 36 100 384130
# Crazy Little Thing Called Love Queen Greatest Hits 38 100 163631
# Electric Funeral Black Sabbath Paranoid 44 100 293015
# Fat Bottomed Girls Queen Greatest Hits 38 100 257515
# For Those About To Rock (We Salute You) AC/DC Who Made Who 84 100 353750
# Four Sticks Led Zeppelin IV 84 100 284421
# Furious Angels Rob Dougan The Matrix Reloaded 54 100 330004
# Gelle Bryan Lee Blues Is 45 60 199836
# Going To California Led Zeppelin IV 100 100 215666
# Grease Various Grease 42 100 205792
# Hand of Doom Black Sabbath Paranoid 36 100 429609
# Hells Bells AC/DC Who Made Who 82 100 312946
# Hey You Pink Floyd The Wall [Disc 2] 23 100 282305
# I Worry Bryan Lee Blues Is 33 100 341315
# Iron Man Black Sabbath Paranoid 39 100 358530
# Is There Anybody Out There? Pink Floyd The Wall [Disc 2] 26 100 160679
# It was a Very Good Year Frank Sinatra Greatest Hits 39 100 268852
# Its Your Move Bryan Lee Blues Is 40 100 245002
# Jack the Stripper/Fairies Wear Boots Black Sabbath Paranoid 35 100 373995
# Killer Queen Queen Greatest Hits 34 100 181368
# Laichzeit Rammstein Herzeleid 41 100 262844
# Let me Down Easy Bryan Lee Blues Is 43 100 331441
# Misty Mountain Hop Led Zeppelin IV 88 100 278831
# No Low Down Bryan Lee Blues Is 39 100 245760
# Now You Are Gone America Greatest Hits 52 100 187559
# Outside The Wall Pink Floyd The Wall [Disc 2] 16 100 104437
# Paranoid Black Sabbath Paranoid 36 100 172930
# Planet Caravan Black Sabbath Paranoid 38 100 274938
# Pretty Jeanie Bryan Lee Blues Is 34 100 225175
# Rammstein Rammstein Herzeleid 45 100 265090
# Rat Salad Black Sabbath Paranoid 46 100 150230
# Rock & Roll Led Zeppelin IV 109 100 220891
# Rode Across the Desert America Greatest Hits 60 100 249887
# Sandy Various Grease 36 100 155742
# Shake Your Foundations AC/DC Who Made Who 85 100 233769
# Sister Golden Hair America Greatest Hits 60 100 202057
# Somebody To Love Queen Greatest Hits 17 100 297586
# Stairway To Heaven Led Zeppelin IV 93 100 481567
# Strangers in the Night Frank Sinatra Greatest Hits 42 100 158484
# Summer Nights Various Grease 35 100 216973
# Summer Wind Frank Sinatra Greatest Hits 46 100 177554
# Thats Life Frank Sinatra Greatest Hits 43 100 189988
# The Battle Of Evermore Led Zeppelin IV 110 100 351529
# The Blues "Is" Bryan Lee Blues Is 45 100 252238
# There it Is Bryan Lee Blues Is 35 100 395441
# Think Bryan Lee Blues Is 41 100 320339
# This Town Frank Sinatra Greatest Hits 44 100 185051
# Tin Man America Greatest Hits 50 100 210076
# Track 01 Billy Price Danger Zone 47 100 261825
# Track 02 Billy Price Danger Zone 42 100 165459
# Track 03 Billy Price Danger Zone 41 100 206471
# Messin with the Kid The Canettes Blues Band Self Titled 23 100 226377
# Track 04 Billy Price Danger Zone 37 100 257175
# Stormy Monday The Canettes Blues Band Self Titled 29 100 464143
# Track 05 Billy Price Danger Zone 42 100 230295
# Waiting on Ice Bryan Lee Blues Is 37 100 289384
# War Pigs/Luke's Wall Black Sabbath Paranoid 38 100 478197
# We Are The Champions Queen Greatest Hits 24 100 181864
# We Will Rock You Queen Greatest Hits 33 100 123559
# When Somebody Loves You Frank Sinatra Greatest Hits 43 100 117263
# When The Levee Breaks Led Zeppelin IV 83 100 427624
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-52-6175f0f88ec5> in <module>
#      71     cur.execute('Insert or Ignore into Track(title,album_id,len,rating,count) values(?,?,?,?,?)',(name,album_id,length,rating,count))
#      72
# ---> 73     conn.commit()
#      74
#      75
#
# KeyboardInterrupt:

# %%
import urllib.request,urllib.parse,urllib.error
import sqlite3
import json
import time
import sys
import ssl
import http

api_key = False
# If you have a Google Places API key, enter it here
# api_key = 'AIzaSy___IDByT70'

if api_key is False:
    api_key = 42
    serviceurl = "http://py4e-data.dr-chuck.net/json?"
else :
    serviceurl = "https://maps.googleapis.com/maps/api/geocode/json?"

# Additional detail for urllib
# http.client.HTTPConnection.debuglevel = 1

# Ignore SSL certificate errors
ctx = ssl.create_default_context()
ctx.check_hostname = False
ctx.verify_mode = ssl.CERT_NONE



conn = sqlite3.connect('geodata.sqlite')
cur = conn.cursor()

cur.execute('Create table if not exists Location(address text,geodata text)')

fh = open('where.data')
for line in fh:
    address = line.strip()
    
    cur.execute('Select geodata from Location where address = ?',(memoryview(address.encode()), ))
    
    try:
        data = cur.fetchone()[0]
        print('Found in database:',address)
        continue
    except: pass
    
    parms = dict()
    parms["address"] = address
    if api_key is not False: parms['key'] = api_key
    url = serviceurl + urllib.parse.urlencode(parms)
    
    print('Retrieving ',url)
    uh = urllib.request.urlopen(url,context = ctx)
    data = uh.read().decode()
    print('Retrieved', len(data), 'characters', data[:20].replace('\n', ' '))   
    
    try:
        js = js.loads(data)
    except:
        #print(data)
        continue
        
    if 'status' not in js or (js['status'] != 'OK' and js['status'] != 'ZERO_RESULTS') :
        print('Failure to Retrive')
        #print(data)
        break
        
    cur.execute('Insert into Location(address,geodata) values(?,?)',(memoryview(address.encode()),memoryview(data.encode())))
    
    conn.commit()
# Out:
# Retrieving  http://py4e-data.dr-chuck.net/json?address=AGH+University+of+Science+and+Technology&key=42
# Retrieved 2315 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=Academy+of+Fine+Arts+Warsaw+Poland&key=42
# Retrieved 4250 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=American+University+in+Cairo&key=42
# Retrieved 1830 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=Arizona+State+University&key=42
# Retrieved 1972 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=Athens+Information+Technology&key=42
# Retrieved 1964 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=BITS+Pilani&key=42
# Retrieved 1807 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=Babcock+University&key=42
# Retrieved 3251 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=Banaras+Hindu+University&key=42
# Retrieved 1989 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=Bangalore+University&key=42
# Retrieved 2200 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=Baylor+University&key=42
# Retrieved 2095 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=Beijing+normal+university&key=42
# Retrieved 2209 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=Belarusian+State+University&key=42
# Retrieved 2184 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=Belgrade+University&key=42
# Retrieved 1944 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=Beloit+College&key=42
# Retrieved 2248 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=Belorussian+State+University&key=42
# Retrieved 2217 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=Ben+Gurion+University&key=42
# Retrieved 2337 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=Bharthidasan+University&key=42
# Retrieved 1893 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=Boston+University&key=42
# Retrieved 1982 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=California+Polytechnic+State+University+of+San+Luis+Obispo&key=42
# Retrieved 1842 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=California+State+University+San+Bernardino&key=42
# Retrieved 2164 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=City+of+Westminster+College&key=42
# Retrieved 2108 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=Columbia+University&key=42
# Retrieved 4410 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=Cranfield+University&key=42
# Retrieved 2155 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=Czech+Technical+University+in+Prague&key=42
# Retrieved 1830 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=Dartmouth&key=42
# Retrieved 21951 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=De+Anza+College&key=42
# Retrieved 2152 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=Distant+University+of+Hagen&key=42
# Retrieved 2109 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=Dnipropetrovsk+National+University&key=42
# Retrieved 2442 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=Dokuz+Eylul+University&key=42
# Retrieved 1991 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=Drexel&key=42
# Retrieved 2331 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=Drexel+University+and+University+of+Texas+at+Austin&key=42
# Retrieved 1782 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=Duke+University&key=42
# Retrieved 1971 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=EM+Lyon&key=42
# Retrieved 2129 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=Ecole+centrale+de+PARIS&key=42
# Retrieved 2325 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=Elon+University&key=42
# Retrieved 2298 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=Erhvervsakademi+Sydvest&key=42
# Retrieved 1735 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=Escuela+Superior+Politecnica+del+Litoral&key=42
# Retrieved 1954 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=Fachhochschule+Dusseldorf&key=42
# Retrieved 2355 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=Fachhochschule+FH+Salzburg&key=42
# Retrieved 2110 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=Faculdade+de+Tecnologia+do+Estado+de+Sao+Paulo&key=42
# Retrieved 1961 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=Faculty+of+Technical+Sciences+Novi+Sad+Serbia&key=42
# Retrieved 2130 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=Farmingdale+State+University&key=42
# Retrieved 2111 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=Federal+University+of+Minas+Gerais&key=42
# Retrieved 2253 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=Florida+Atlantic+University&key=42
# Retrieved 2122 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=Franklin+Pierce+College&key=42
# Retrieved 2269 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=Gauhati+University&key=42
# Retrieved 2260 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=George+Mason+University&key=42
# Retrieved 2297 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=Georgetown+University+Law+Center&key=42
# Retrieved 2159 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=Georgia+State+University&key=42
# Retrieved 1979 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=Grandville&key=42
# Retrieved 1752 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=Groep+T+University&key=42
# Retrieved 2106 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=Hanoi+University+of+Science+and+Technology&key=42
# Retrieved 1811 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=Hebrew+University&key=42
# Retrieved 1248 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=IIIT+Hyderabad&key=42
# Retrieved 2225 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=IIT+KANPUR&key=42
# Retrieved 4140 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=IT+College+of+Estonia&key=42
# Retrieved 2089 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=IU&key=42
# Retrieved 2288 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=IUAV+Venezia&key=42
# Retrieved 2306 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=Illinois+Institute+of+Technology&key=42
# Retrieved 2259 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=Illinois+State+University+Joliet+Junior+College&key=42
# Retrieved 2318 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=Indian+Institute+of+Technology&key=42
# Retrieved 2187 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=Indian+Institute+of+Technology+Kharagpur+India&key=42
# Retrieved 1817 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=Indian+School+of+Mines+Dhanbad&key=42
# Retrieved 2616 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=Indiana+University&key=42
# Retrieved 2288 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=Indiana+University+at+Bloomington&key=42
# Retrieved 2288 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=Institut+Superieur+de+technologies&key=42
# Retrieved 2378 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=Institute+of+Business+and+Modern+Technologies&key=42
# Retrieved 2495 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=Instituto+Tecnologico+de+Santo+Domingo&key=42
# Retrieved 2424 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=International+Institute+of+Information+Technology+Hyderabad&key=42
# Retrieved 2225 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=Irkutsk+State+University&key=42
# Retrieved 4264 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=JADAVPUR+UNIVERSITY&key=42
# Retrieved 2449 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=Jawaharlal+Nehru+Technological+University&key=42
# Retrieved 2444 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=Jawaharlal+Nehru+University&key=42
# Retrieved 1977 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=Jordan+University+of+Science+and+Technology&key=42
# Retrieved 1474 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=K-State&key=42
# Retrieved 1793 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=KUL&key=42
# Retrieved 1268 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=Kalamazoo+College&key=42
# Retrieved 2297 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=Kaunas+Technology+University&key=42
# Retrieved 2120 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=Kaunas+university+of+technology&key=42
# Retrieved 2120 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=Kazan+Federal+University&key=42
# Retrieved 2362 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=Kent+State+University&key=42
# Retrieved 2108 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=Kharkiv+State+Academy+of+Municipal+Economy+Ukraine&key=42
# Retrieved 2399 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=King+Mongkuts+University+of+Technology+Thonburi&key=42
# Retrieved 4292 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=Kokshetau+Institute+of+Economics+and+Management&key=42
# Retrieved 1821 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=Kyiv+Polytechnic+Institute&key=42
# Retrieved 2128 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=Kyiv+Polytechnical+Institute&key=42
# Retrieved 4450 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=Kyiv+Unisersity+of+Oriental+Language&key=42
# Retrieved 2175 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=Laurentian+University&key=42
# Retrieved 2367 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=Lisandro+Alvarado&key=42
# Retrieved 1988 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=Lodz+University+of+Technology&key=42
# Retrieved 2268 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=Lviv+University&key=42
# Retrieved 2379 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=MSU&key=42
# Retrieved 1494 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=Madras+university&key=42
# Retrieved 2419 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=Magnitogorsk+State+Technical+University&key=42
# Retrieved 2209 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=Malayer+Azad+University&key=42
# Retrieved 1663 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=Marietta+College&key=42
# Retrieved 2097 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=Masdar+Institute&key=42
# Retrieved 1719 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=Matematicki+fakultet+Beograd&key=42
# Retrieved 2107 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=Michigan+State+University&key=42
# Retrieved 1494 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=Middle+East+Technical+University&key=42
# Retrieved 4725 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=Missouri+University+of+Science+and+Technology&key=42
# Retrieved 2469 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=Monash&key=42
# Retrieved 1963 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=Monash+University&key=42
# Retrieved 1963 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=Monash+University+Churchill+Australia&key=42
# Retrieved 1968 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=Monterrey+Institute+of+Technology+and+Higher+Education&key=42
# Retrieved 2187 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=Moscow+Engineering-Physics+Institute&key=42
# Retrieved 2376 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=Moscow+Institute+of+Physics+%26+Technology&key=42
# Retrieved 2177 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=Moscow+State+University&key=42
# Retrieved 2353 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=NIT+ROURKELA&key=42
# Retrieved 2630 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=NYU&key=42
# Retrieved 1997 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=Nagpur+University&key=42
# Retrieved 4279 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=Nanyang+Technological+University&key=42
# Retrieved 1620 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=National+Institute+of+Technology+Jalandhar&key=42
# Retrieved 2030 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=National+Taiwan+University&key=42
# Retrieved 2191 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=National+University+of+Engineering&key=42
# Retrieved 2169 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=North+Central+College&key=42
# Retrieved 2517 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=Northeastern+University&key=42
# Retrieved 2301 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=Northwestern+University&key=42
# Retrieved 2101 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=Obninsk+Technical+University+of+Nuclear+Power+Engineering+Russia&key=42
# Retrieved 1834 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=Old+Dominion+University&key=42
# Retrieved 1916 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=Oregon+Institute+of+Technology&key=42
# Retrieved 2124 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=PUCMM&key=42
# Retrieved 2213 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=Payame+Noor+University&key=42
# Retrieved 1843 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=Penn+State+University&key=42
# Retrieved 1823 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=Politecnico+di+Milano&key=42
# Retrieved 2345 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=Politehnica+University+Bucharest&key=42
# Retrieved 2343 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=Polytechnic+University+of+Timisoara&key=42
# Retrieved 2124 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=Pondicherry+University&key=42
# Retrieved 2226 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=Pontificia+universidad+catolica+de+chile&key=42
# Retrieved 4373 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=Portland+State+University&key=42
# Retrieved 2461 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=Purdue+University+Indianapolis&key=42
# Retrieved 2333 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=R+V+College+of+Engineering&key=42
# Retrieved 2387 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=RPI&key=42
# Retrieved 2090 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=Ramapo+College+of+New+Jersey&key=42
# Retrieved 2266 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=Rochester+Institute+of+Technology&key=42
# Retrieved 2468 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=SASTRA+University&key=42
# Retrieved 1854 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=Saint+Petersburg+State+University&key=42
# Retrieved 1995 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=Saint+Petersburg+State+University+of+Aerospace+Instrumentation&key=42
# Retrieved 1998 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=Saint-Petersburg+Polytechnic+Univesity&key=42
# Retrieved 2022 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=San+Francisco+State+University&key=42
# Retrieved 2320 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=San+Jose+State+University&key=42
# Retrieved 2301 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=Shanghai+Jiao+Tong+University&key=42
# Retrieved 1677 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=Sharif+University+of+Technology&key=42
# Retrieved 1468 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=Simon+Bolivar+University&key=42
# Retrieved 1658 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=Simon+Fraser+University&key=42
# Retrieved 2126 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=Smolensk+State+University&key=42
# Retrieved 2186 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=Sonoma+State+University&key=42
# Retrieved 2134 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=South+Federal+University&key=42
# Retrieved 2458 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=Spiru+Haret+University&key=42
# Retrieved 2325 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=Stanford&key=42
# Retrieved 1910 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=State+University+of+Campinas&key=42
# Retrieved 2103 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=State+University+of+New+York+College+at+Oswego&key=42
# Retrieved 2098 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=Stellenbosch+University&key=42
# Retrieved 1903 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=Stonehill+College&key=42
# Retrieved 2316 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=Tallinn+University&key=42
# Retrieved 4210 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=Tallinn+University+of+Technology&key=42
# Retrieved 2116 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=Tampere+University+of+Technology&key=42
# Retrieved 1441 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=Tanta+University&key=42
# Retrieved 1849 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=Tarrant+County+College&key=42
# Retrieved 2299 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=Technical+University+of+Cluj-Napoca&key=42
# Retrieved 2158 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=Technion&key=42
# Retrieved 2485 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=Tel+Aviv+University&key=42
# Retrieved 1474 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=The+Jerusalem+collage+of+engineering&key=42
# Retrieved 2425 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=The+University+of+Latvia&key=42
# Retrieved 1946 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=The+University+of+Manchester&key=42
# Retrieved 1966 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=The+University+of+South+Africa&key=42
# Retrieved 2082 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=Transilvania+University&key=42
# Retrieved 2306 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=Tufts+University&key=42
# Retrieved 2115 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=UC+Berkeley&key=42
# Retrieved 1723 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=UCLA&key=42
# Retrieved 1988 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=UCSD&key=42
# Retrieved 2284 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=UIUC&key=42
# Retrieved 1654 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=UMD&key=42
# Retrieved 2449 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=UNISA&key=42
# Retrieved 2447 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=UNIVERSIDAD+DE+Buenos+Aires&key=42
# Retrieved 2132 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=UOC&key=42
# Retrieved 2474 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=USC&key=42
# Retrieved 1952 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=UW+Madison&key=42
# Retrieved 1632 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=Universidad+Central+de+Venezuela&key=42
# Retrieved 1678 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=Universidad+Complutense+de+Madrid&key=42
# Retrieved 2066 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=Universidad+Cooperativa+de+Colombia&key=42
# Retrieved 2302 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=Universidad+Nacional+Autonoma+de+Mexico&key=42
# Retrieved 1844 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=Universidad+Nacional+Costa+Rica&key=42
# Retrieved 1666 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=Universidad+Nacional+de+Colombia&key=42
# Retrieved 1888 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=Universidad+Tecnologica+Boliviana&key=42
# Retrieved 2048 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=Universidad+de+Buenos+Aires&key=42
# Retrieved 2132 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=Universidad+de+Castilla+La+Mancha&key=42
# Retrieved 2142 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=Universidad+de+Los+Andes+Colombia&key=42
# Retrieved 2033 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=Universidad+de+Oriente&key=42
# Retrieved 4747 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=Universidad+de+San+Carlos+de+Guatemala&key=42
# Retrieved 2177 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=Universidad+de+Valladolid&key=42
# Retrieved 2118 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=Universidad+de+la+Sabana&key=42
# Retrieved 3546 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=Universidad+del+Valle+de+Guatemala&key=42
# Retrieved 2040 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=Universidade+Federal+da+Paraiba&key=42
# Retrieved 1962 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=Universidade+Federal+de+Santa+Catarina&key=42
# Retrieved 2308 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=Universidade+Federal+do+Rio+Grande+do+Sul&key=42
# Retrieved 1958 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=Universidade+Federal+do+Rio+de+Janeiro&key=42
# Retrieved 2106 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=Universidade+Tecnica+de+Lisboa&key=42
# Retrieved 1920 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=Universidade+de+Sao+Paulo&key=42
# Retrieved 1704 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=Universidade+do+Minho&key=42
# Retrieved 3316 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=Universitas+Gadjah+Mada&key=42
# Retrieved 2319 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=Universitat+Politecnica+de+Valencia&key=42
# Retrieved 2100 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=Universite+Catholique+de+Louvain&key=42
# Retrieved 2407 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=University+College+Dublin&key=42
# Retrieved 1675 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=University+Munich&key=42
# Retrieved 2311 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=University+of+Akron&key=42
# Retrieved 2105 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=University+of+Alberta&key=42
# Retrieved 2016 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=University+of+Amsterdam&key=42
# Retrieved 2050 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=University+of+Arkansas&key=42
# Retrieved 2033 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=University+of+Athens&key=42
# Retrieved 1625 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=University+of+Belgrade&key=42
# Retrieved 1944 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=University+of+Birmingham&key=42
# Retrieved 1631 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=University+of+Buenos+Aires&key=42
# Retrieved 2132 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=University+of+Cambridge&key=42
# Retrieved 2126 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=University+of+Central+Oklahoma&key=42
# Retrieved 2270 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=University+of+Chicago&key=42
# Retrieved 2457 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=University+of+Cincinnati&key=42
# Retrieved 2298 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=University+of+Colorado+at+Boulder&key=42
# Retrieved 1800 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=University+of+Connecticut&key=42
# Retrieved 1794 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=University+of+Dallas&key=42
# Retrieved 2263 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=University+of+Debrecen&key=42
# Retrieved 1711 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=University+of+Delaware&key=42
# Retrieved 3857 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=University+of+Erlangen-Nuremberg&key=42
# Retrieved 2263 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=University+of+Essex&key=42
# Retrieved 1992 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=University+of+Evora&key=42
# Retrieved 1928 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=University+of+Florida&key=42
# Retrieved 1805 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=University+of+Gothenburg&key=42
# Retrieved 1983 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=University+of+Greifswald&key=42
# Retrieved 1910 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=University+of+Hamburg&key=42
# Retrieved 1787 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=University+of+Hawaii&key=42
# Retrieved 2268 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=University+of+Helsinki&key=42
# Retrieved 1720 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=University+of+Ilorin+Kwara+State&key=42
# Retrieved 2049 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=University+of+Jaffna&key=42
# Retrieved 2016 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=University+of+Kansas&key=42
# Retrieved 2115 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=University+of+Kerala&key=42
# Retrieved 2297 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=University+of+London&key=42
# Retrieved 2293 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=University+of+Malaga&key=42
# Retrieved 2080 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=University+of+Malaya&key=42
# Retrieved 1961 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=University+of+Manchester&key=42
# Retrieved 1966 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=University+of+Michigan&key=42
# Retrieved 2120 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=University+of+Missouri+-+Columbia&key=42
# Retrieved 1798 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=University+of+Moratuwa&key=42
# Retrieved 1991 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=University+of+Mumbai&key=42
# Retrieved 2258 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=University+of+Nebraska&key=42
# Retrieved 2096 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=University+of+Nebraska+-+Lincoln&key=42
# Retrieved 2096 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=University+of+New+Haven&key=42
# Retrieved 2133 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=University+of+New+South+Wales&key=42
# Retrieved 1805 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=University+of+Notre+Dame&key=42
# Retrieved 3776 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=University+of+Oklahoma&key=42
# Retrieved 2113 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=University+of+Ottawa&key=42
# Retrieved 2310 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=University+of+Oxford&key=42
# Retrieved 1773 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=University+of+Padua&key=42
# Retrieved 2288 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=University+of+Pavia+Italy&key=42
# Retrieved 2301 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=University+of+Pennsylvania&key=42
# Retrieved 1826 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=University+of+Piraeus+Athens&key=42
# Retrieved 1916 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=University+of+Pretoria&key=42
# Retrieved 2222 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=University+of+Salamanca&key=42
# Retrieved 1785 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=University+of+Sao+Paulo&key=42
# Retrieved 1704 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=University+of+Sarajevo&key=42
# Retrieved 2214 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=University+of+Southern+California&key=42
# Retrieved 2004 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=University+of+Stellenbosch&key=42
# Retrieved 1903 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=University+of+Tartu&key=42
# Retrieved 1906 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=University+of+Tehran&key=42
# Retrieved 1678 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=University+of+Texas&key=42
# Retrieved 1782 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=University+of+Texas+at+Austin&key=42
# Retrieved 1782 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=University+of+Toronto&key=42
# Retrieved 2322 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=University+of+Tuebingen&key=42
# Retrieved 2175 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=University+of+Twente&key=42
# Retrieved 2104 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=University+of+Utah&key=42
# Retrieved 2145 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=University+of+Vienna&key=42
# Retrieved 2094 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=University+of+Warsaw&key=42
# Retrieved 2331 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=University+of+Washington&key=42
# Retrieved 2396 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=University+of+Washington+-+Bothell&key=42
# Retrieved 2270 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=University+of+Waterloo&key=42
# Retrieved 4260 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=University+of+West+Florida&key=42
# Retrieved 2340 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=University+of+Wisconsin&key=42
# Retrieved 1632 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=University+of+the+Punjab+Lahore&key=42
# Retrieved 4571 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=University+of+the+Witwatersrand&key=42
# Retrieved 2406 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=Vilnius+Gediminas+Technical+University&key=42
# Retrieved 2142 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=Vilnius+University&key=42
# Retrieved 4239 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=Virginia+Commonwealth+University&key=42
# Retrieved 1905 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=Virginia+Tech&key=42
# Retrieved 1822 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=Viswakarma+Institute+Pune+India&key=42
# Retrieved 2379 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=Warsaw+University&key=42
# Retrieved 2331 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=Washington+State+University&key=42
# Retrieved 3807 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=Wayne+State&key=42
# Retrieved 1921 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=Weber+State&key=42
# Retrieved 2100 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=Weizmann+Institute+of+Science&key=42
# Retrieved 1927 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=Western+Governors+University&key=42
# Retrieved 2280 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=Xavier+University&key=42
# Retrieved 2301 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=Zagazig+University&key=42
# Retrieved 2105 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=allama+iqbal+open+university+islamabad&key=42
# Retrieved 5493 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=arizona+state+university&key=42
# Retrieved 1972 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=federal+institute+of+tecnology+and+education+from+southeastern+Minas+Gerais&key=42
# Retrieved 2297 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=kansas+state+university&key=42
# Retrieved 1793 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=universidad+complutense+de+madrid&key=42
# Retrieved 2066 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=university+of+Patras&key=42
# Retrieved 1651 characters {    "results" : [
# Retrieving  http://py4e-data.dr-chuck.net/json?address=university+of+padua&key=42
# Retrieved 2288 characters {    "results" : [

# %%
import sqlite3
import json
import time
import ssl
import urllib.parse,urllib.request,urllib.error
import http
import sys

api_key = False
# If you have a Google Places API key, enter it here
# api_key = 'AIzaSy___IDByT70'

if api_key is False:
    api_key = 42
    serviceurl = "http://py4e-data.dr-chuck.net/json?"
else :
    serviceurl = "https://maps.googleapis.com/maps/api/geocode/json?"

# Additional detail for urllib
# http.client.HTTPConnection.debuglevel = 1

# Ignore SSL certificate errors
ctx = ssl.create_default_context()
ctx.check_hostname = False
ctx.verify_mode = ssl.CERT_NONE


conn = sqlite3.connect('geodata.sqlite')
cur = conn.cursor()

cur.execute('Create table if not exists Locations(address text,geodata text)')

fh = open("where.data")
count = 0
for line in fh:
    if count > 200:
        print('200 data retrived restart it to retrived more')
        break

    address = line.strip()
    cur.execute('Select geodata from Locations where address = ?',(memoryview(address.encode()),))

    try:
        data = cur.fetchone()[0]
        print('Data found in database',address)
        continue
    except: pass

    parms = dict()
    parms["address"] = address
    if api_key is not False: parms['key'] = api_key
    url = serviceurl+urllib.parse.urlencode(parms)

    print('Retrieving',url)
    uh = urllib.request.urlopen(url,context = ctx)
    data = uh.read().decode()
    print('Retrieved',len(data),'characters',data[:20].replace('\n',''))
    count = count+1

    try:
        js = json.loads(data)
    except:
        print(data)
        continue

    if 'status' not in js or js['status'] != 'OK' and js['status'] != 'ZERO_RESULTS':
        print('Failed to Retrieve data')
        print(data)
        break

    cur.execute('Insert into Locations(address,geodata) values(?,?)',
        (memoryview(address.encode()),memoryview(data.encode())))

    conn.commit()

    if count % 10 == 0:
        print('Pausing for a bit')
        #time.sleep(5)

print("Run geodump.py to read the data from the database so you can vizualize it on a map.")
# Out:
# Retrieving http://py4e-data.dr-chuck.net/json?address=AGH+University+of+Science+and+Technology&key=42
# Retrieved 2315 characters {   "results" : [
# Retrieving http://py4e-data.dr-chuck.net/json?address=Academy+of+Fine+Arts+Warsaw+Poland&key=42
# Retrieved 4250 characters {   "results" : [
# Retrieving http://py4e-data.dr-chuck.net/json?address=American+University+in+Cairo&key=42
# Retrieved 1830 characters {   "results" : [
# Retrieving http://py4e-data.dr-chuck.net/json?address=Arizona+State+University&key=42
# Retrieved 1972 characters {   "results" : [
# Retrieving http://py4e-data.dr-chuck.net/json?address=Athens+Information+Technology&key=42
# Retrieved 1964 characters {   "results" : [
# Retrieving http://py4e-data.dr-chuck.net/json?address=BITS+Pilani&key=42
# Retrieved 1807 characters {   "results" : [
# Retrieving http://py4e-data.dr-chuck.net/json?address=Babcock+University&key=42
# Retrieved 3251 characters {   "results" : [
# Retrieving http://py4e-data.dr-chuck.net/json?address=Banaras+Hindu+University&key=42
# Retrieved 1989 characters {   "results" : [
# Retrieving http://py4e-data.dr-chuck.net/json?address=Bangalore+University&key=42
# Retrieved 2200 characters {   "results" : [
# Retrieving http://py4e-data.dr-chuck.net/json?address=Baylor+University&key=42
# Retrieved 2095 characters {   "results" : [
# Pausing for a bit
# Retrieving http://py4e-data.dr-chuck.net/json?address=Beijing+normal+university&key=42
# Retrieved 2209 characters {   "results" : [
# Retrieving http://py4e-data.dr-chuck.net/json?address=Belarusian+State+University&key=42
# Retrieved 2184 characters {   "results" : [
# Retrieving http://py4e-data.dr-chuck.net/json?address=Belgrade+University&key=42
# Retrieved 1944 characters {   "results" : [
# Retrieving http://py4e-data.dr-chuck.net/json?address=Beloit+College&key=42
# Retrieved 2248 characters {   "results" : [
# Retrieving http://py4e-data.dr-chuck.net/json?address=Belorussian+State+University&key=42
# Retrieved 2217 characters {   "results" : [
# Retrieving http://py4e-data.dr-chuck.net/json?address=Ben+Gurion+University&key=42
# Retrieved 2337 characters {   "results" : [
# Retrieving http://py4e-data.dr-chuck.net/json?address=Bharthidasan+University&key=42
# Retrieved 1893 characters {   "results" : [
# Retrieving http://py4e-data.dr-chuck.net/json?address=Boston+University&key=42
# Retrieved 1982 characters {   "results" : [
# Retrieving http://py4e-data.dr-chuck.net/json?address=California+Polytechnic+State+University+of+San+Luis+Obispo&key=42
# Retrieved 1842 characters {   "results" : [
# Retrieving http://py4e-data.dr-chuck.net/json?address=California+State+University+San+Bernardino&key=42
# Retrieved 2164 characters {   "results" : [
# Pausing for a bit
# Retrieving http://py4e-data.dr-chuck.net/json?address=City+of+Westminster+College&key=42
# Retrieved 2108 characters {   "results" : [
# Retrieving http://py4e-data.dr-chuck.net/json?address=Columbia+University&key=42
# Retrieved 4410 characters {   "results" : [
# Retrieving http://py4e-data.dr-chuck.net/json?address=Cranfield+University&key=42
# Retrieved 2155 characters {   "results" : [
# Retrieving http://py4e-data.dr-chuck.net/json?address=Czech+Technical+University+in+Prague&key=42
# Retrieved 1830 characters {   "results" : [
# Retrieving http://py4e-data.dr-chuck.net/json?address=Dartmouth&key=42
# Retrieved 21951 characters {   "results" : [
# Retrieving http://py4e-data.dr-chuck.net/json?address=De+Anza+College&key=42
# Retrieved 2152 characters {   "results" : [
# Retrieving http://py4e-data.dr-chuck.net/json?address=Distant+University+of+Hagen&key=42
# Retrieved 2109 characters {   "results" : [
# Retrieving http://py4e-data.dr-chuck.net/json?address=Dnipropetrovsk+National+University&key=42
# Retrieved 2442 characters {   "results" : [
# Retrieving http://py4e-data.dr-chuck.net/json?address=Dokuz+Eylul+University&key=42
# Retrieved 1991 characters {   "results" : [
# Retrieving http://py4e-data.dr-chuck.net/json?address=Drexel&key=42
# Retrieved 2331 characters {   "results" : [
# Pausing for a bit
# Retrieving http://py4e-data.dr-chuck.net/json?address=Drexel+University+and+University+of+Texas+at+Austin&key=42
# Retrieved 1782 characters {   "results" : [
# Retrieving http://py4e-data.dr-chuck.net/json?address=Duke+University&key=42
# Retrieved 1971 characters {   "results" : [
# Retrieving http://py4e-data.dr-chuck.net/json?address=EM+Lyon&key=42
# Retrieved 2129 characters {   "results" : [
# Retrieving http://py4e-data.dr-chuck.net/json?address=Ecole+centrale+de+PARIS&key=42
# Retrieved 2325 characters {   "results" : [
# Retrieving http://py4e-data.dr-chuck.net/json?address=Elon+University&key=42
# Retrieved 2298 characters {   "results" : [
# Retrieving http://py4e-data.dr-chuck.net/json?address=Erhvervsakademi+Sydvest&key=42
# Retrieved 1735 characters {   "results" : [
# Retrieving http://py4e-data.dr-chuck.net/json?address=Escuela+Superior+Politecnica+del+Litoral&key=42
# Retrieved 1954 characters {   "results" : [
# Retrieving http://py4e-data.dr-chuck.net/json?address=Fachhochschule+Dusseldorf&key=42
# Retrieved 2355 characters {   "results" : [
# Retrieving http://py4e-data.dr-chuck.net/json?address=Fachhochschule+FH+Salzburg&key=42
# Retrieved 2110 characters {   "results" : [
# Retrieving http://py4e-data.dr-chuck.net/json?address=Faculdade+de+Tecnologia+do+Estado+de+Sao+Paulo&key=42
# Retrieved 1961 characters {   "results" : [
# Pausing for a bit
# Retrieving http://py4e-data.dr-chuck.net/json?address=Faculty+of+Technical+Sciences+Novi+Sad+Serbia&key=42
# Retrieved 2130 characters {   "results" : [
# Retrieving http://py4e-data.dr-chuck.net/json?address=Farmingdale+State+University&key=42
# Retrieved 2111 characters {   "results" : [
# Retrieving http://py4e-data.dr-chuck.net/json?address=Federal+University+of+Minas+Gerais&key=42
# Retrieved 2253 characters {   "results" : [
# Retrieving http://py4e-data.dr-chuck.net/json?address=Florida+Atlantic+University&key=42
# Retrieved 2122 characters {   "results" : [
# Retrieving http://py4e-data.dr-chuck.net/json?address=Franklin+Pierce+College&key=42
# Retrieved 2269 characters {   "results" : [
# Retrieving http://py4e-data.dr-chuck.net/json?address=Gauhati+University&key=42
# Retrieved 2260 characters {   "results" : [
# Retrieving http://py4e-data.dr-chuck.net/json?address=George+Mason+University&key=42
# Retrieved 2297 characters {   "results" : [
# Retrieving http://py4e-data.dr-chuck.net/json?address=Georgetown+University+Law+Center&key=42
# Retrieved 2159 characters {   "results" : [
# Retrieving http://py4e-data.dr-chuck.net/json?address=Georgia+State+University&key=42
# Retrieved 1979 characters {   "results" : [
# Retrieving http://py4e-data.dr-chuck.net/json?address=Grandville&key=42
# Retrieved 1752 characters {   "results" : [
# Pausing for a bit
# Retrieving http://py4e-data.dr-chuck.net/json?address=Groep+T+University&key=42
# Retrieved 2106 characters {   "results" : [
# Retrieving http://py4e-data.dr-chuck.net/json?address=Hanoi+University+of+Science+and+Technology&key=42
# Retrieved 1811 characters {   "results" : [
# Retrieving http://py4e-data.dr-chuck.net/json?address=Hebrew+University&key=42
# Retrieved 1248 characters {   "results" : [
# Retrieving http://py4e-data.dr-chuck.net/json?address=IIIT+Hyderabad&key=42
# Retrieved 2225 characters {   "results" : [
# Retrieving http://py4e-data.dr-chuck.net/json?address=IIT+KANPUR&key=42
# Retrieved 4140 characters {   "results" : [
# Retrieving http://py4e-data.dr-chuck.net/json?address=IT+College+of+Estonia&key=42
# Retrieved 2089 characters {   "results" : [
# Retrieving http://py4e-data.dr-chuck.net/json?address=IU&key=42
# Retrieved 2288 characters {   "results" : [
# Retrieving http://py4e-data.dr-chuck.net/json?address=IUAV+Venezia&key=42
# Retrieved 2306 characters {   "results" : [
# Retrieving http://py4e-data.dr-chuck.net/json?address=Illinois+Institute+of+Technology&key=42
# Retrieved 2259 characters {   "results" : [
# Retrieving http://py4e-data.dr-chuck.net/json?address=Illinois+State+University+Joliet+Junior+College&key=42
# Retrieved 2318 characters {   "results" : [
# Pausing for a bit
# Retrieving http://py4e-data.dr-chuck.net/json?address=Indian+Institute+of+Technology&key=42
# Retrieved 2187 characters {   "results" : [
# Retrieving http://py4e-data.dr-chuck.net/json?address=Indian+Institute+of+Technology+Kharagpur+India&key=42
# Retrieved 1817 characters {   "results" : [
# Retrieving http://py4e-data.dr-chuck.net/json?address=Indian+School+of+Mines+Dhanbad&key=42
# Retrieved 2616 characters {   "results" : [
# Retrieving http://py4e-data.dr-chuck.net/json?address=Indiana+University&key=42
# Retrieved 2288 characters {   "results" : [
# Retrieving http://py4e-data.dr-chuck.net/json?address=Indiana+University+at+Bloomington&key=42
# Retrieved 2288 characters {   "results" : [
# Retrieving http://py4e-data.dr-chuck.net/json?address=Institut+Superieur+de+technologies&key=42
# Retrieved 2378 characters {   "results" : [
# Retrieving http://py4e-data.dr-chuck.net/json?address=Institute+of+Business+and+Modern+Technologies&key=42
# Retrieved 2495 characters {   "results" : [
# Retrieving http://py4e-data.dr-chuck.net/json?address=Instituto+Tecnologico+de+Santo+Domingo&key=42
# Retrieved 2424 characters {   "results" : [
# Retrieving http://py4e-data.dr-chuck.net/json?address=International+Institute+of+Information+Technology+Hyderabad&key=42
# Retrieved 2225 characters {   "results" : [
# Retrieving http://py4e-data.dr-chuck.net/json?address=Irkutsk+State+University&key=42
# Retrieved 4264 characters {   "results" : [
# Pausing for a bit
# Retrieving http://py4e-data.dr-chuck.net/json?address=JADAVPUR+UNIVERSITY&key=42
# Retrieved 2449 characters {   "results" : [
# Retrieving http://py4e-data.dr-chuck.net/json?address=Jawaharlal+Nehru+Technological+University&key=42
# Retrieved 2444 characters {   "results" : [
# Retrieving http://py4e-data.dr-chuck.net/json?address=Jawaharlal+Nehru+University&key=42
# Retrieved 1977 characters {   "results" : [
# Retrieving http://py4e-data.dr-chuck.net/json?address=Jordan+University+of+Science+and+Technology&key=42
# Retrieved 1474 characters {   "results" : [
# Retrieving http://py4e-data.dr-chuck.net/json?address=K-State&key=42
# Retrieved 1793 characters {   "results" : [
# Retrieving http://py4e-data.dr-chuck.net/json?address=KUL&key=42
# Retrieved 1268 characters {   "results" : [
# Retrieving http://py4e-data.dr-chuck.net/json?address=Kalamazoo+College&key=42
# Retrieved 2297 characters {   "results" : [
# Retrieving http://py4e-data.dr-chuck.net/json?address=Kaunas+Technology+University&key=42
# Retrieved 2120 characters {   "results" : [
# Retrieving http://py4e-data.dr-chuck.net/json?address=Kaunas+university+of+technology&key=42
# Retrieved 2120 characters {   "results" : [
# Retrieving http://py4e-data.dr-chuck.net/json?address=Kazan+Federal+University&key=42
# Retrieved 2362 characters {   "results" : [
# Pausing for a bit
# Retrieving http://py4e-data.dr-chuck.net/json?address=Kent+State+University&key=42
# Retrieved 2108 characters {   "results" : [
# Retrieving http://py4e-data.dr-chuck.net/json?address=Kharkiv+State+Academy+of+Municipal+Economy+Ukraine&key=42
# Retrieved 2399 characters {   "results" : [
# Retrieving http://py4e-data.dr-chuck.net/json?address=King+Mongkuts+University+of+Technology+Thonburi&key=42
# Retrieved 4292 characters {   "results" : [
# Retrieving http://py4e-data.dr-chuck.net/json?address=Kokshetau+Institute+of+Economics+and+Management&key=42
# Retrieved 1821 characters {   "results" : [
# Retrieving http://py4e-data.dr-chuck.net/json?address=Kyiv+Polytechnic+Institute&key=42
# Retrieved 2128 characters {   "results" : [
# Retrieving http://py4e-data.dr-chuck.net/json?address=Kyiv+Polytechnical+Institute&key=42
# Retrieved 4450 characters {   "results" : [
# Retrieving http://py4e-data.dr-chuck.net/json?address=Kyiv+Unisersity+of+Oriental+Language&key=42
# Retrieved 2175 characters {   "results" : [
# Retrieving http://py4e-data.dr-chuck.net/json?address=Laurentian+University&key=42
# Retrieved 2367 characters {   "results" : [
# Retrieving http://py4e-data.dr-chuck.net/json?address=Lisandro+Alvarado&key=42
# Retrieved 1988 characters {   "results" : [
# Retrieving http://py4e-data.dr-chuck.net/json?address=Lodz+University+of+Technology&key=42
# Retrieved 2268 characters {   "results" : [
# Pausing for a bit
# Retrieving http://py4e-data.dr-chuck.net/json?address=Lviv+University&key=42
# Retrieved 2379 characters {   "results" : [
# Retrieving http://py4e-data.dr-chuck.net/json?address=MSU&key=42
# Retrieved 1494 characters {   "results" : [
# Retrieving http://py4e-data.dr-chuck.net/json?address=Madras+university&key=42
# Retrieved 2419 characters {   "results" : [
# Retrieving http://py4e-data.dr-chuck.net/json?address=Magnitogorsk+State+Technical+University&key=42
# Retrieved 2209 characters {   "results" : [
# Retrieving http://py4e-data.dr-chuck.net/json?address=Malayer+Azad+University&key=42
# Retrieved 1663 characters {   "results" : [
# Retrieving http://py4e-data.dr-chuck.net/json?address=Marietta+College&key=42
# Retrieved 2097 characters {   "results" : [
# Retrieving http://py4e-data.dr-chuck.net/json?address=Masdar+Institute&key=42
# Retrieved 1719 characters {   "results" : [
# Retrieving http://py4e-data.dr-chuck.net/json?address=Matematicki+fakultet+Beograd&key=42
# Retrieved 2107 characters {   "results" : [
# Retrieving http://py4e-data.dr-chuck.net/json?address=Michigan+State+University&key=42
# Retrieved 1494 characters {   "results" : [
# Retrieving http://py4e-data.dr-chuck.net/json?address=Middle+East+Technical+University&key=42
# Retrieved 4725 characters {   "results" : [
# Pausing for a bit
# Retrieving http://py4e-data.dr-chuck.net/json?address=Missouri+University+of+Science+and+Technology&key=42
# Retrieved 2469 characters {   "results" : [
# Retrieving http://py4e-data.dr-chuck.net/json?address=Monash&key=42
# Retrieved 1963 characters {   "results" : [
# Retrieving http://py4e-data.dr-chuck.net/json?address=Monash+University&key=42
# Retrieved 1963 characters {   "results" : [
# Retrieving http://py4e-data.dr-chuck.net/json?address=Monash+University+Churchill+Australia&key=42
# Retrieved 1968 characters {   "results" : [
# Retrieving http://py4e-data.dr-chuck.net/json?address=Monterrey+Institute+of+Technology+and+Higher+Education&key=42
# Retrieved 2187 characters {   "results" : [
# Retrieving http://py4e-data.dr-chuck.net/json?address=Moscow+Engineering-Physics+Institute&key=42
# Retrieved 2376 characters {   "results" : [
# Retrieving http://py4e-data.dr-chuck.net/json?address=Moscow+Institute+of+Physics+%26+Technology&key=42
# Retrieved 2177 characters {   "results" : [
# Retrieving http://py4e-data.dr-chuck.net/json?address=Moscow+State+University&key=42
# Retrieved 2353 characters {   "results" : [
# Retrieving http://py4e-data.dr-chuck.net/json?address=NIT+ROURKELA&key=42
# Retrieved 2630 characters {   "results" : [
# Retrieving http://py4e-data.dr-chuck.net/json?address=NYU&key=42
# Retrieved 1997 characters {   "results" : [
# Pausing for a bit
# Retrieving http://py4e-data.dr-chuck.net/json?address=Nagpur+University&key=42
# Retrieved 4279 characters {   "results" : [
# Retrieving http://py4e-data.dr-chuck.net/json?address=Nanyang+Technological+University&key=42
# Retrieved 1620 characters {   "results" : [
# Retrieving http://py4e-data.dr-chuck.net/json?address=National+Institute+of+Technology+Jalandhar&key=42
# Retrieved 2030 characters {   "results" : [
# Retrieving http://py4e-data.dr-chuck.net/json?address=National+Taiwan+University&key=42
# Retrieved 2191 characters {   "results" : [
# Retrieving http://py4e-data.dr-chuck.net/json?address=National+University+of+Engineering&key=42
# Retrieved 2169 characters {   "results" : [
# Retrieving http://py4e-data.dr-chuck.net/json?address=North+Central+College&key=42
# Retrieved 2517 characters {   "results" : [
# Retrieving http://py4e-data.dr-chuck.net/json?address=Northeastern+University&key=42
# Retrieved 2301 characters {   "results" : [
# Retrieving http://py4e-data.dr-chuck.net/json?address=Northwestern+University&key=42
# Retrieved 2101 characters {   "results" : [
# Retrieving http://py4e-data.dr-chuck.net/json?address=Obninsk+Technical+University+of+Nuclear+Power+Engineering+Russia&key=42
# Retrieved 1834 characters {   "results" : [
# Retrieving http://py4e-data.dr-chuck.net/json?address=Old+Dominion+University&key=42
# Retrieved 1916 characters {   "results" : [
# Pausing for a bit
# Retrieving http://py4e-data.dr-chuck.net/json?address=Oregon+Institute+of+Technology&key=42
# Retrieved 2124 characters {   "results" : [
# Retrieving http://py4e-data.dr-chuck.net/json?address=PUCMM&key=42
# Retrieved 2213 characters {   "results" : [
# Retrieving http://py4e-data.dr-chuck.net/json?address=Payame+Noor+University&key=42
# Retrieved 1843 characters {   "results" : [
# Retrieving http://py4e-data.dr-chuck.net/json?address=Penn+State+University&key=42
# Retrieved 1823 characters {   "results" : [
# Retrieving http://py4e-data.dr-chuck.net/json?address=Politecnico+di+Milano&key=42
# Retrieved 2345 characters {   "results" : [
# Retrieving http://py4e-data.dr-chuck.net/json?address=Politehnica+University+Bucharest&key=42
# Retrieved 2343 characters {   "results" : [
# Retrieving http://py4e-data.dr-chuck.net/json?address=Polytechnic+University+of+Timisoara&key=42
# Retrieved 2124 characters {   "results" : [
# Retrieving http://py4e-data.dr-chuck.net/json?address=Pondicherry+University&key=42
# Retrieved 2226 characters {   "results" : [
# Retrieving http://py4e-data.dr-chuck.net/json?address=Pontificia+universidad+catolica+de+chile&key=42
# Retrieved 4373 characters {   "results" : [
# Retrieving http://py4e-data.dr-chuck.net/json?address=Portland+State+University&key=42
# Retrieved 2461 characters {   "results" : [
# Pausing for a bit
# Retrieving http://py4e-data.dr-chuck.net/json?address=Purdue+University+Indianapolis&key=42
# Retrieved 2333 characters {   "results" : [
# Retrieving http://py4e-data.dr-chuck.net/json?address=R+V+College+of+Engineering&key=42
# Retrieved 2387 characters {   "results" : [
# Retrieving http://py4e-data.dr-chuck.net/json?address=RPI&key=42
# Retrieved 2090 characters {   "results" : [
# Retrieving http://py4e-data.dr-chuck.net/json?address=Ramapo+College+of+New+Jersey&key=42
# Retrieved 2266 characters {   "results" : [
# Retrieving http://py4e-data.dr-chuck.net/json?address=Rochester+Institute+of+Technology&key=42
# Retrieved 2468 characters {   "results" : [
# Retrieving http://py4e-data.dr-chuck.net/json?address=SASTRA+University&key=42
# Retrieved 1854 characters {   "results" : [
# Retrieving http://py4e-data.dr-chuck.net/json?address=Saint+Petersburg+State+University&key=42
# Retrieved 1995 characters {   "results" : [
# Retrieving http://py4e-data.dr-chuck.net/json?address=Saint+Petersburg+State+University+of+Aerospace+Instrumentation&key=42
# Retrieved 1998 characters {   "results" : [
# Retrieving http://py4e-data.dr-chuck.net/json?address=Saint-Petersburg+Polytechnic+Univesity&key=42
# Retrieved 2022 characters {   "results" : [
# Retrieving http://py4e-data.dr-chuck.net/json?address=San+Francisco+State+University&key=42
# Retrieved 2320 characters {   "results" : [
# Pausing for a bit
# Retrieving http://py4e-data.dr-chuck.net/json?address=San+Jose+State+University&key=42
# Retrieved 2301 characters {   "results" : [
# Retrieving http://py4e-data.dr-chuck.net/json?address=Shanghai+Jiao+Tong+University&key=42
# Retrieved 1677 characters {   "results" : [
# Retrieving http://py4e-data.dr-chuck.net/json?address=Sharif+University+of+Technology&key=42
# Retrieved 1468 characters {   "results" : [
# Retrieving http://py4e-data.dr-chuck.net/json?address=Simon+Bolivar+University&key=42
# Retrieved 1658 characters {   "results" : [
# Retrieving http://py4e-data.dr-chuck.net/json?address=Simon+Fraser+University&key=42
# Retrieved 2126 characters {   "results" : [
# Retrieving http://py4e-data.dr-chuck.net/json?address=Smolensk+State+University&key=42
# Retrieved 2186 characters {   "results" : [
# Retrieving http://py4e-data.dr-chuck.net/json?address=Sonoma+State+University&key=42
# Retrieved 2134 characters {   "results" : [
# Retrieving http://py4e-data.dr-chuck.net/json?address=South+Federal+University&key=42
# Retrieved 2458 characters {   "results" : [
# Retrieving http://py4e-data.dr-chuck.net/json?address=Spiru+Haret+University&key=42
# Retrieved 2325 characters {   "results" : [
# Retrieving http://py4e-data.dr-chuck.net/json?address=Stanford&key=42
# Retrieved 1910 characters {   "results" : [
# Pausing for a bit
# Retrieving http://py4e-data.dr-chuck.net/json?address=State+University+of+Campinas&key=42
# Retrieved 2103 characters {   "results" : [
# Retrieving http://py4e-data.dr-chuck.net/json?address=State+University+of+New+York+College+at+Oswego&key=42
# Retrieved 2098 characters {   "results" : [
# Retrieving http://py4e-data.dr-chuck.net/json?address=Stellenbosch+University&key=42
# Retrieved 1903 characters {   "results" : [
# Retrieving http://py4e-data.dr-chuck.net/json?address=Stonehill+College&key=42
# Retrieved 2316 characters {   "results" : [
# Retrieving http://py4e-data.dr-chuck.net/json?address=Tallinn+University&key=42
# Retrieved 4210 characters {   "results" : [
# Retrieving http://py4e-data.dr-chuck.net/json?address=Tallinn+University+of+Technology&key=42
# Retrieved 2116 characters {   "results" : [
# Retrieving http://py4e-data.dr-chuck.net/json?address=Tampere+University+of+Technology&key=42
# Retrieved 1441 characters {   "results" : [
# Retrieving http://py4e-data.dr-chuck.net/json?address=Tanta+University&key=42
# Retrieved 1849 characters {   "results" : [
# Retrieving http://py4e-data.dr-chuck.net/json?address=Tarrant+County+College&key=42
# Retrieved 2299 characters {   "results" : [
# Retrieving http://py4e-data.dr-chuck.net/json?address=Technical+University+of+Cluj-Napoca&key=42
# Retrieved 2158 characters {   "results" : [
# Pausing for a bit
# Retrieving http://py4e-data.dr-chuck.net/json?address=Technion&key=42
# Retrieved 2485 characters {   "results" : [
# Retrieving http://py4e-data.dr-chuck.net/json?address=Tel+Aviv+University&key=42
# Retrieved 1474 characters {   "results" : [
# Retrieving http://py4e-data.dr-chuck.net/json?address=The+Jerusalem+collage+of+engineering&key=42
# Retrieved 2425 characters {   "results" : [
# Retrieving http://py4e-data.dr-chuck.net/json?address=The+University+of+Latvia&key=42
# Retrieved 1946 characters {   "results" : [
# Retrieving http://py4e-data.dr-chuck.net/json?address=The+University+of+Manchester&key=42
# Retrieved 1966 characters {   "results" : [
# Retrieving http://py4e-data.dr-chuck.net/json?address=The+University+of+South+Africa&key=42
# Retrieved 2082 characters {   "results" : [
# Retrieving http://py4e-data.dr-chuck.net/json?address=Transilvania+University&key=42
# Retrieved 2306 characters {   "results" : [
# Retrieving http://py4e-data.dr-chuck.net/json?address=Tufts+University&key=42
# Retrieved 2115 characters {   "results" : [
# Retrieving http://py4e-data.dr-chuck.net/json?address=UC+Berkeley&key=42
# Retrieved 1723 characters {   "results" : [
# Retrieving http://py4e-data.dr-chuck.net/json?address=UCLA&key=42
# Retrieved 1988 characters {   "results" : [
# Pausing for a bit
# Retrieving http://py4e-data.dr-chuck.net/json?address=UCSD&key=42
# Retrieved 2284 characters {   "results" : [
# Retrieving http://py4e-data.dr-chuck.net/json?address=UIUC&key=42
# Retrieved 1654 characters {   "results" : [
# Retrieving http://py4e-data.dr-chuck.net/json?address=UMD&key=42
# Retrieved 2449 characters {   "results" : [
# Retrieving http://py4e-data.dr-chuck.net/json?address=UNISA&key=42
# Retrieved 2447 characters {   "results" : [
# Retrieving http://py4e-data.dr-chuck.net/json?address=UNIVERSIDAD+DE+Buenos+Aires&key=42
# Retrieved 2132 characters {   "results" : [
# Retrieving http://py4e-data.dr-chuck.net/json?address=UOC&key=42
# Retrieved 2474 characters {   "results" : [
# Retrieving http://py4e-data.dr-chuck.net/json?address=USC&key=42
# Retrieved 1952 characters {   "results" : [
# Retrieving http://py4e-data.dr-chuck.net/json?address=UW+Madison&key=42
# Retrieved 1632 characters {   "results" : [
# Retrieving http://py4e-data.dr-chuck.net/json?address=Universidad+Central+de+Venezuela&key=42
# Retrieved 1678 characters {   "results" : [
# Retrieving http://py4e-data.dr-chuck.net/json?address=Universidad+Complutense+de+Madrid&key=42
# Retrieved 2066 characters {   "results" : [
# Pausing for a bit
# Retrieving http://py4e-data.dr-chuck.net/json?address=Universidad+Cooperativa+de+Colombia&key=42
# Retrieved 2302 characters {   "results" : [
# Retrieving http://py4e-data.dr-chuck.net/json?address=Universidad+Nacional+Autonoma+de+Mexico&key=42
# Retrieved 1844 characters {   "results" : [
# Retrieving http://py4e-data.dr-chuck.net/json?address=Universidad+Nacional+Costa+Rica&key=42
# Retrieved 1666 characters {   "results" : [
# Retrieving http://py4e-data.dr-chuck.net/json?address=Universidad+Nacional+de+Colombia&key=42
# Retrieved 1888 characters {   "results" : [
# Retrieving http://py4e-data.dr-chuck.net/json?address=Universidad+Tecnologica+Boliviana&key=42
# Retrieved 2048 characters {   "results" : [
# Retrieving http://py4e-data.dr-chuck.net/json?address=Universidad+de+Buenos+Aires&key=42
# Retrieved 2132 characters {   "results" : [
# Retrieving http://py4e-data.dr-chuck.net/json?address=Universidad+de+Castilla+La+Mancha&key=42
# Retrieved 2142 characters {   "results" : [
# Retrieving http://py4e-data.dr-chuck.net/json?address=Universidad+de+Los+Andes+Colombia&key=42
# Retrieved 2033 characters {   "results" : [
# Retrieving http://py4e-data.dr-chuck.net/json?address=Universidad+de+Oriente&key=42
# Retrieved 4747 characters {   "results" : [
# Retrieving http://py4e-data.dr-chuck.net/json?address=Universidad+de+San+Carlos+de+Guatemala&key=42
# Retrieved 2177 characters {   "results" : [
# Pausing for a bit
# Retrieving http://py4e-data.dr-chuck.net/json?address=Universidad+de+Valladolid&key=42
# Retrieved 2118 characters {   "results" : [
# Retrieving http://py4e-data.dr-chuck.net/json?address=Universidad+de+la+Sabana&key=42
# Retrieved 3546 characters {   "results" : [
# Retrieving http://py4e-data.dr-chuck.net/json?address=Universidad+del+Valle+de+Guatemala&key=42
# Retrieved 2040 characters {   "results" : [
# Retrieving http://py4e-data.dr-chuck.net/json?address=Universidade+Federal+da+Paraiba&key=42
# Retrieved 1962 characters {   "results" : [
# Retrieving http://py4e-data.dr-chuck.net/json?address=Universidade+Federal+de+Santa+Catarina&key=42
# Retrieved 2308 characters {   "results" : [
# Retrieving http://py4e-data.dr-chuck.net/json?address=Universidade+Federal+do+Rio+Grande+do+Sul&key=42
# Retrieved 1958 characters {   "results" : [
# Retrieving http://py4e-data.dr-chuck.net/json?address=Universidade+Federal+do+Rio+de+Janeiro&key=42
# Retrieved 2106 characters {   "results" : [
# Retrieving http://py4e-data.dr-chuck.net/json?address=Universidade+Tecnica+de+Lisboa&key=42
# Retrieved 1920 characters {   "results" : [
# Retrieving http://py4e-data.dr-chuck.net/json?address=Universidade+de+Sao+Paulo&key=42
# Retrieved 1704 characters {   "results" : [
# Retrieving http://py4e-data.dr-chuck.net/json?address=Universidade+do+Minho&key=42
# Retrieved 3316 characters {   "results" : [
# Pausing for a bit
# Retrieving http://py4e-data.dr-chuck.net/json?address=Universitas+Gadjah+Mada&key=42
# Retrieved 2319 characters {   "results" : [
# 200 data retrived restart it to retrived more
# Run geodump.py to read the data from the database so you can vizualize it on a map.

# %%
import urllib.parse,urllib.error,urllib.request
import sqlite3
import json
import sys
import time
import ssl
import http

conn = sqlite3.connect('test.sqlite')
cur = conn.cursor()

cur.execute('Create table if not exists Locations(address text,geodata text)')

#context = ssl.SSLContext(ssl.PROTOCOL_TLSv1)
#context.verify_mode = ssl.CERT_NONE

# Ignore SSL certificate errors
ctx = ssl.create_default_context()
ctx.check_hostname = False
ctx.verify_mode = ssl.CERT_NONE

api_key = 42
serviceurl = 'http://python-data.dr-chuck.net/geojson?'


#https://maps.googleapis.com/maps/api/geocode/xml?address=Kathmandu
fh = open('where.data')

for line in fh:
    address = line.strip()
    
    cur.execute('Select geodata from Locations where address = ?',(memoryview(address.encode()),))
    
    try:
        data = cur.fetchone()[0]
        print('found in database')
        print(address)
        continue
    except:
        pass
    
    pearl = dict()
    pearl['address'] = address
    if api_key is not False: pearl['key'] = api_key
    url = serviceurl+urllib.parse.urlencode(pearl)
    
    uh = urllib.request.urlopen(url,context = ctx)
    data = uh.read().decode()
    
    try:
        js = json.loads(data)
    except:
        print('json syntax failed for that address',address)
        continue
        
    if 'status' not in js or js['status'] != 'OK' and js['status'] != 'Zero_Results':
        print('json faied ')
        break
        
    

    cur.execute('''INSERT INTO Locations (address, geodata)
            VALUES ( ?, ? )''', (memoryview(address.encode()), memoryview(data.encode()) ) )
    print(address,'-------------',data[:20])
    
    conn.commit()
# Out:
# found in database
# AGH University of Science and Technology
# found in database
# Academy of Fine Arts Warsaw Poland
# found in database
# American University in Cairo
# found in database
# Arizona State University
# found in database
# Athens Information Technology
# found in database
# BITS Pilani
# found in database
# Babcock University
# found in database
# Banaras Hindu University
# found in database
# Bangalore University
# found in database
# Baylor University
# found in database
# Beijing normal university
# found in database
# Belarusian State University
# found in database
# Belgrade University
# found in database
# Beloit College
# found in database
# Belorussian State University
# found in database
# Ben Gurion University
# found in database
# Bharthidasan University
# found in database
# Boston University
# found in database
# California Polytechnic State University of San Luis Obispo
# found in database
# California State University San Bernardino
# found in database
# City of Westminster College
# found in database
# Columbia University
# found in database
# Cranfield University
# found in database
# Czech Technical University in Prague
# found in database
# Dartmouth
# found in database
# De Anza College
# found in database
# Distant University of Hagen
# found in database
# Dnipropetrovsk National University
# found in database
# Dokuz Eylul University
# found in database
# Drexel
# found in database
# Drexel University and University of Texas at Austin
# found in database
# Duke University
# found in database
# EM Lyon
# found in database
# Ecole centrale de PARIS
# found in database
# Elon University
# found in database
# Erhvervsakademi Sydvest
# found in database
# Escuela Superior Politecnica del Litoral
# found in database
# Fachhochschule Dusseldorf
# found in database
# Fachhochschule FH Salzburg
# found in database
# Faculdade de Tecnologia do Estado de Sao Paulo
# found in database
# Faculty of Technical Sciences Novi Sad Serbia
# found in database
# Farmingdale State University
# found in database
# Federal University of Minas Gerais
# found in database
# Florida Atlantic University
# found in database
# Franklin Pierce College
# found in database
# Gauhati University
# found in database
# George Mason University
# found in database
# Georgetown University Law Center
# found in database
# Georgia State University
# found in database
# Grandville
# found in database
# Groep T University
# found in database
# Hanoi University of Science and Technology
# found in database
# Hebrew University
# found in database
# IIIT Hyderabad
# found in database
# IIT KANPUR
# found in database
# IT College of Estonia
# found in database
# IU
# found in database
# IUAV Venezia
# found in database
# Illinois Institute of Technology
# found in database
# Illinois State University Joliet Junior College
# found in database
# Indian Institute of Technology
# found in database
# Indian Institute of Technology Kharagpur India
# found in database
# Indian School of Mines Dhanbad
# found in database
# Indiana University
# found in database
# Indiana University at Bloomington
# found in database
# Institut Superieur de technologies
# found in database
# Institute of Business and Modern Technologies
# found in database
# Instituto Tecnologico de Santo Domingo
# found in database
# International Institute of Information Technology Hyderabad
# found in database
# Irkutsk State University
# found in database
# JADAVPUR UNIVERSITY
# found in database
# Jawaharlal Nehru Technological University
# found in database
# Jawaharlal Nehru University
# found in database
# Jordan University of Science and Technology
# found in database
# K-State
# found in database
# KUL
# found in database
# Kalamazoo College
# found in database
# Kaunas Technology University
# found in database
# Kaunas university of technology
# found in database
# Kazan Federal University
# found in database
# Kent State University
# found in database
# Kharkiv State Academy of Municipal Economy Ukraine
# found in database
# King Mongkuts University of Technology Thonburi
# found in database
# Kokshetau Institute of Economics and Management
# found in database
# Kyiv Polytechnic Institute
# found in database
# Kyiv Polytechnical Institute
# found in database
# Kyiv Unisersity of Oriental Language
# found in database
# Laurentian University
# found in database
# Lisandro Alvarado
# found in database
# Lodz University of Technology
# found in database
# Lviv University
# found in database
# MSU
# found in database
# Madras university
# found in database
# Magnitogorsk State Technical University
# found in database
# Malayer Azad University
# found in database
# Marietta College
# found in database
# Masdar Institute
# found in database
# Matematicki fakultet Beograd
# found in database
# Michigan State University
# found in database
# Middle East Technical University
# found in database
# Missouri University of Science and Technology
# found in database
# Monash
# found in database
# Monash University
# found in database
# Monash University Churchill Australia
# found in database
# Monterrey Institute of Technology and Higher Education
# found in database
# Moscow Engineering-Physics Institute
# found in database
# Moscow Institute of Physics & Technology
# found in database
# Moscow State University
# found in database
# NIT ROURKELA
# found in database
# NYU
# found in database
# Nagpur University
# found in database
# Nanyang Technological University
# found in database
# National Institute of Technology Jalandhar
# found in database
# National Taiwan University
# found in database
# National University of Engineering
# found in database
# North Central College
# found in database
# Northeastern University
# found in database
# Northwestern University
# found in database
# Obninsk Technical University of Nuclear Power Engineering Russia
# found in database
# Old Dominion University
# found in database
# Oregon Institute of Technology
# found in database
# PUCMM
# found in database
# Payame Noor University
# found in database
# Penn State University
# found in database
# Politecnico di Milano
# found in database
# Politehnica University Bucharest
# found in database
# Polytechnic University of Timisoara
# found in database
# Pondicherry University
# found in database
# Pontificia universidad catolica de chile
# found in database
# Portland State University
# found in database
# Purdue University Indianapolis
# found in database
# R V College of Engineering
# found in database
# RPI
# found in database
# Ramapo College of New Jersey
# found in database
# Rochester Institute of Technology
# found in database
# SASTRA University
# found in database
# Saint Petersburg State University
# found in database
# Saint Petersburg State University of Aerospace Instrumentation
# found in database
# Saint-Petersburg Polytechnic Univesity
# found in database
# San Francisco State University
# found in database
# San Jose State University
# found in database
# Shanghai Jiao Tong University
# found in database
# Sharif University of Technology
# found in database
# Simon Bolivar University
# found in database
# Simon Fraser University
# found in database
# Smolensk State University
# found in database
# Sonoma State University
# found in database
# South Federal University
# found in database
# Spiru Haret University
# found in database
# Stanford
# found in database
# State University of Campinas
# found in database
# State University of New York College at Oswego
# found in database
# Stellenbosch University
# found in database
# Stonehill College
# found in database
# Tallinn University
# found in database
# Tallinn University of Technology
# found in database
# Tampere University of Technology
# found in database
# Tanta University
# found in database
# Tarrant County College
# found in database
# Technical University of Cluj-Napoca
# found in database
# Technion
# found in database
# Tel Aviv University
# found in database
# The Jerusalem collage of engineering
# found in database
# The University of Latvia
# found in database
# The University of Manchester
# found in database
# The University of South Africa
# found in database
# Transilvania University
# found in database
# Tufts University
# found in database
# UC Berkeley
# found in database
# UCLA
# found in database
# UCSD
# found in database
# UIUC
# found in database
# UMD
# found in database
# UNISA
# found in database
# UNIVERSIDAD DE Buenos Aires
# found in database
# UOC
# found in database
# USC
# found in database
# UW Madison
# found in database
# Universidad Central de Venezuela
# found in database
# Universidad Complutense de Madrid
# found in database
# Universidad Cooperativa de Colombia
# found in database
# Universidad Nacional Autonoma de Mexico
# found in database
# Universidad Nacional Costa Rica
# found in database
# Universidad Nacional de Colombia
# found in database
# Universidad Tecnologica Boliviana
# found in database
# Universidad de Buenos Aires
# found in database
# Universidad de Castilla La Mancha
# found in database
# Universidad de Los Andes Colombia
# found in database
# Universidad de Oriente
# found in database
# Universidad de San Carlos de Guatemala
# found in database
# Universidad de Valladolid
# found in database
# Universidad de la Sabana
# found in database
# Universidad del Valle de Guatemala
# found in database
# Universidade Federal da Paraiba
# found in database
# Universidade Federal de Santa Catarina
# found in database
# Universidade Federal do Rio Grande do Sul
# found in database
# Universidade Federal do Rio de Janeiro
# found in database
# Universidade Tecnica de Lisboa
# found in database
# Universidade de Sao Paulo
# found in database
# Universidade do Minho
# found in database
# Universitas Gadjah Mada
# found in database
# Universitat Politecnica de Valencia
# found in database
# Universite Catholique de Louvain
# found in database
# University College Dublin
# found in database
# University Munich
# found in database
# University of Akron
# found in database
# University of Alberta
# found in database
# University of Amsterdam
# found in database
# University of Arkansas
# found in database
# University of Athens
# found in database
# University of Belgrade
# found in database
# University of Birmingham
# found in database
# University of Buenos Aires
# found in database
# University of Cambridge
# found in database
# University of Central Oklahoma
# found in database
# University of Chicago
# found in database
# University of Cincinnati
# found in database
# University of Colorado at Boulder
# found in database
# University of Connecticut
# found in database
# University of Dallas
# found in database
# University of Debrecen
# found in database
# University of Delaware
# found in database
# University of Erlangen-Nuremberg
# found in database
# University of Essex
# found in database
# University of Evora
# found in database
# University of Florida
# found in database
# University of Gothenburg
# found in database
# University of Greifswald
# found in database
# University of Hamburg
# found in database
# University of Hawaii
# found in database
# University of Helsinki
# found in database
# University of Ilorin Kwara State
# found in database
# University of Jaffna
# found in database
# University of Kansas
# found in database
# University of Kerala
# found in database
# University of London
# found in database
# University of Malaga
# found in database
# University of Malaya
# found in database
# University of Manchester
# found in database
# University of Michigan
# found in database
# University of Missouri - Columbia
# found in database
# University of Moratuwa
# found in database
# University of Mumbai
# found in database
# University of Nebraska
# found in database
# University of Nebraska - Lincoln
# found in database
# University of New Haven
# found in database
# University of New South Wales
# found in database
# University of Notre Dame
# found in database
# University of Oklahoma
# found in database
# University of Ottawa
# found in database
# University of Oxford
# found in database
# University of Padua
# found in database
# University of Pavia Italy
# found in database
# University of Pennsylvania
# found in database
# University of Piraeus Athens
# found in database
# University of Pretoria
# found in database
# University of Salamanca
# found in database
# University of Sao Paulo
# found in database
# University of Sarajevo
# found in database
# University of Southern California
# found in database
# University of Stellenbosch
# found in database
# University of Tartu
# found in database
# University of Tehran
# found in database
# University of Texas
# found in database
# University of Texas at Austin
# found in database
# University of Toronto
# found in database
# University of Tuebingen
# found in database
# University of Twente
# found in database
# University of Utah
# found in database
# University of Vienna
# found in database
# University of Warsaw
# found in database
# University of Washington
# found in database
# University of Washington - Bothell
# found in database
# University of Waterloo
# found in database
# University of West Florida
# found in database
# University of Wisconsin
# found in database
# University of the Punjab Lahore
# found in database
# University of the Witwatersrand
# found in database
# Vilnius Gediminas Technical University
# found in database
# Vilnius University
# found in database
# Virginia Commonwealth University
# found in database
# Virginia Tech
# found in database
# Viswakarma Institute Pune India
# found in database
# Warsaw University
# found in database
# Washington State University
# found in database
# Wayne State
# found in database
# Weber State
# found in database
# Weizmann Institute of Science
# found in database
# Western Governors University
# found in database
# Xavier University
# found in database
# Zagazig University
# found in database
# allama iqbal open university islamabad
# found in database
# arizona state university
# found in database
# federal institute of tecnology and education from southeastern Minas Gerais
# found in database
# kansas state university
# found in database
# universidad complutense de madrid
# found in database
# university of Patras
# found in database
# university of padua

# %%
import sqlite3
import json 
import codecs

conn = sqlite3.connect('test.sqlite')
cur = conn.cursor()

cur.execute('Select * from Locations')
fhand = codecs.open('where.js','w',"utf-8")
fhand.write("Data = [\n ")
count = 0
for row in cur:
    data = cur.fetchone()[1]
    try :
        js = json.loads(str(data.decode()))
    except:
        continue
        
    if 'status' not in js or (js['status'] != 'OK' and js['status'] != 'Zero_Results') : continue
        
    lat = js['results'][0]['geometry']['location']['lat']
    lng = js['results'][0]['geometry']['location']['lng']
    address = js['results'][0]['formatted_address']
    output = "["+str(lat)+","+str(lng)+",'"+address+"'],\n"
    count+=1
    print(output)
    fhand.write(output)

cur.close()
fhand.write("]")
fhand.close()
print('Records written :',count)
# Out:
# [52.2296756,21.0122287,'Warsaw, Poland'],
#
# [33.4232051,-111.8879509,'State Ave, Tempe, AZ 85281, USA'],
#
# [28.3580163,75.5887989,'BITS, Pilani, Rajasthan 333031, India'],
#
# [25.2685304,82.9904737,'Banaras Hindu University Campus, Varanasi, Uttar Pradesh, India'],
#
# [64.8852156,-147.8009743,'Baylor Blvd, Fairbanks, AK 99709, USA'],
#
# [53.89318369999999,27.547338,'Monument to Fallen Professors and Students of the Belarusian State University, Minsk, Belarus'],
#
# [42.5030209,-89.0295642,'College St, Beloit, WI 53511, USA'],
#
# [32.0184325,34.738834,'Derech Ben Gurion, Bat Yam, Israel'],
#
# [42.3400834,-71.1669754,'Boston College, Boston, MA 02467, USA'],
#
# [34.1515641,-117.3354402,'N State St, San Bernardino, CA, USA'],
#
# [33.6520436,-117.8286548,'Columbia, Irvine, CA 92612, USA'],
#
# [50.0755381,14.4378005,'Prague, Czech Republic'],
#
# [37.319538,-122.0433207,'Campus Dr, Cupertino, CA 95014, USA'],
#
# [48.464717,35.046183,'Dnepropetrovsk, Dnipropetrovsk Oblast, Ukraine'],
#
# [38.47945929999999,-94.60856629999999,'Drexel, MO, USA'],
#
# [41.9197689,-91.649501,'Duke St SW, Cedar Rapids, IA 52404, USA'],
#
# [48.8635276,2.3272053,'Allée Centrale, 75001 Paris, France'],
#
# [55.4883363,8.4468283,'Business Academy South West, Spangsbjerg Kirkevej, 6700 Esbjerg, Denmark'],
#
# [51.1877226,6.793873400000001,'Fachhochschule Düsseldorf, 40225 Düsseldorf, Germany'],
#
# [-21.2867332,-50.3393135,'Faculdade de Ciências Tecnologia de Birigui - R. Antônio Simões, 4 - Centro, Birigui - SP, Brazil'],
#
# [40.755915,-73.42743,'State University / Farmingdale, Melville, NY 11735, USA'],
#
# [30.3135522,-81.6004765,'Atlantic University Cir, Jacksonville, FL 32207, USA'],
#
# [26.1529683,91.66392350000001,'Gauhati University, Jalukbari, Guwahati, Assam, India'],
#
# [38.0529062,-78.50964309999999,'Law School (David A. Harrison III Law Grounds), Charlottesville, VA 22901, USA'],
#
# [42.9097484,-85.7630885,'Grandville, MI, USA'],
#
# [21.0481459,105.8012935,'University of Science and Technology of Hanoi, 18 Hoàng Quốc Việt, Nghĩa Đô, Cầu Giấy, Hà Nội, Vietnam'],
#
# [17.4447918,78.3483098,'IIIT, Gachibowli, Hyderabad, Telangana 500032, India'],
#
# [59.39547889999999,24.6643169,'IT College, 12616 Tallinn, Estonia'],
#
# [45.4381291,12.3253617,'Università Iuav di Venezia Palazzo Badoer, 30125 Venezia, Italy'],
#
# [40.6331249,-89.3985283,'Illinois, USA'],
#
# [22.320423,87.309422,'AIESEC IIT Kharagpur, Indian Institute of Technology Kharagpur, IIT Kharagpur, Kharagpur, West Bengal 721302, India'],
#
# [39.1670467,-86.5269373,'Indiana University, Bloomington, IN 47405, USA'],
#
# [26.7391812,-11.6646723,'Institut Supérieur de Technologie, Samara 72000'],
#
# [17.9972951,-94.5625527,'Instituto Tecnológico, Minatitlán, Ver., Mexico'],
#
# [52.28697409999999,104.3050183,'Irkutsk, Irkutsk Oblast, Russia'],
#
# [17.4930263,78.39062179999999,'Jawaharlal Nehru Technological University, Kukatpally, Hyderabad, Telangana, India'],
#
# [22.3404614,114.2607123,'Hong Kong University Of Science And Technology Staff Quarters House Block 8, Clear Water Bay, Hong Kong'],
#
# [46.3339075,17.4542123,'Kutas, Hungary'],
#
# [54.8985207,23.9035965,'Kaunas, Lithuania'],
#
# [55.8304307,49.06608060000001,'Kazan, Tatarstan, Russia'],
#
# [49.9935,36.230383,'Kharkiv, Kharkiv Oblast, Ukraine'],
#
# [53.2948229,69.4047872,'Kokshetau 020000, Kazakhstan'],
#
# [50.4512491,30.4595543,'Kiev Polytechnic Institute Park, просп. Перемоги, Kyiv, Ukraine'],
#
# [46.46192509999999,-80.9664623,'University Laurentian, Copper Cliff, ON P0M 1N0, Canada'],
#
# [51.74580599999999,19.4489068,'Institute of Applied Computer Science, Lodz University of Technology, 90-924 Łódź, Poland'],
#
# [31.6005881,-2.2269965,'MSU، Béchar, Algeria'],
#
# [53.4129429,59.00162330000001,'Magnitogorsk, Chelyabinsk Oblast, Russia'],
#
# [64.859787,-147.7224427,'Marietta Ave, Fairbanks, AK 99701, USA'],
#
# [44.786568,20.4489216,'Belgrade, Serbia'],
#
# [35.246756,33.0307541,'METU Guest House, Kalkanlı'],
#
# [-35.4158638,149.0897893,'Monash ACT 2904, Australia'],
#
# [-38.3105571,146.4292232,'Monash University Gippsland Student Lounge, 7N Mary Grant Bruce Dr, Churchill VIC 3842, Australia'],
#
# [55.755826,37.6173,'Moscow, Russia'],
#
# [55.7066609,37.5169664,'Lomonosov Moscow State University, MSU Institute of Mechanics, Michurinskiy pr., 1, Moskva, Russia, 119192'],
#
# [35.712815,135.9711705,'Nyu, Mihama, Mikata District, Fukui Prefecture 919-1201, Japan'],
#
# [31.204638,121.5853839,'Nanyang Technological University Shanghai Office, Pudong, Shanghai, China, 201203'],
#
# [25.0254571,121.5273658,'National Taiwan Normal University Main Campus I, Da’an District, Taipei City, Taiwan 106'],
#
# [28.0530332,-82.4553299,'N Central Ave, Tampa, FL, USA'],
#
# [15.9447035,120.5815111,'Lyceum NorthWestern University, Urdaneta City, Pangasinan, Philippines'],
#
# [36.8838958,-76.3040214,'Old Dominion University, 5115 Hampton Blvd, Norfolk, VA 23508, USA'],
#
# [19.4478319,-70.6832457,'Tanque PUCMM, Santiago De Los Caballeros 51000, Dominican Republic'],
#
# [40.7933949,-77.8600012,'State College, PA, USA'],
#
# [44.4267674,26.1025384,'Bucharest, Romania'],
#
# [12.0263438,79.8492812,'Pondicherry University, Kalapet, Puducherry 605014, India'],
#
# [45.513099,-122.6885447,'Portland State University Community Garden, SW 12th Ave, Portland, OR 97201, USA'],
#
# [26.3462258,43.7633239,'College of Engineering, 419, Buraydah 52571, Saudi Arabia'],
#
# [41.1228928,-74.0865966,'College Rd, Monsey, NY 10952, USA'],
#
# [10.7295115,79.0196067,'Sastra University Road, Tirumalaisamudram, Tamil Nadu 613401, India'],
#
# [27.7518284,-82.6267345,'St Petersburg, FL, USA'],
#
# [37.7634766,-122.4390923,'States St, San Francisco, CA 94114, USA'],
#
# [31.17900569999999,121.4219573,'Shanghai Sixth People's Hospital Affiliated to Shanghai Jiao Tong University In-patient Department, Xuhui, Shanghai, China, 200231'],
#
# [28.6379654,-106.094602,'Simon Bolívar, Chihuahua, Chih., Mexico'],
#
# [54.7903112,32.0503663,'Smolensk, Smolensk Oblast, Russia'],
#
# [39.6726798,-105.0250535,'S Federal Blvd, Denver, CO, USA'],
#
# [37.42410599999999,-122.1660756,'Stanford, CA, USA'],
#
# [43.4553461,-76.5104973,'Oswego, NY, USA'],
#
# [42.0594537,-71.0819465,'Stonehill College Rd, Easton, MA, USA'],
#
# [59.39384699999999,24.6650872,'Tallinn University of Technology Stadium, 12616 Tallinn, Estonia'],
#
# [30.0564126,31.2102065,'Tanta, Al Agouzah, Giza Governorate, Egypt'],
#
# [46.7712101,23.6236353,'Cluj-Napoca, Romania'],
#
# [32.1036377,34.8046418,'Tel Aviv - University, Tel Aviv-Yafo'],
#
# [56.9529022,24.1138355,'University of Latvia Library, Kalpaka bulvāris 4, Centra rajons, Rīga, LV-1050, Latvia'],
#
# [-33.9592646,18.4607236,'University Ave S, Rondebosch, Cape Town, 7700, South Africa'],
#
# [42.4036847,-71.120482,'South Hall Tufts University, 30 Lower Campus Rd, Somerville, MA 02144, USA'],
#
# [40.5382913,-78.3528584,'Ucla Ln, Altoona, PA 16602, USA'],
#
# [40.110833,-88.22694399999999,'UIUC Engineering Hall, Urbana, IL 61801, USA'],
#
# [-34.9221963,138.5922272,'Yungondi Building, North Terrace, Adelaide SA 5000, Australia'],
#
# [40.7127837,-74.0059413,'New York, NY, USA'],
#
# [43.0447617,-89.4245627,'University of Wisconsin-Madison Arboretum, 1207 Seminole Hwy, Madison, WI 53711, USA'],
#
# [40.4469796,-3.7278167,'Av. Complutense, Madrid, Madrid, Spain'],
#
# [19.3188895,-99.1843676,'National Autonomous University of Mexico, Mexico City, Federal District, Mexico'],
#
# [-4.009976,-79.2085378,'Colombia, Loja, Ecuador'],
#
# [-34.4414891,-58.75956629999999,'Universidad de Buenos Aires, Manuel Alberti, Buenos Aires, Argentina'],
#
# [3.4321247,-76.54617089999999,'Parqueadero Universidad Del Valle, Cali, Cali, Valle del Cauca, Colombia'],
#
# [14.6360021,-90.50953969999999,'Bufete Popular Universidad de San Carlos, Guatemala City, Guatemala'],
#
# [4.860259500000001,-74.03330319999999,'Universidad De La Sabana, Chía, Chía, Cundinamarca, Colombia'],
#
# [-6.751508599999999,-35.6437193,'Universidade Federal da Paraíba - CAVN - R. Santos Dumont, Bananeiras - PB, 58220-000, Brazil'],
#
# [-30.0699518,-51.118329,'Ac. Universidade Federal do Rio Grande do Sul, Porto Alegre - RS, Brazil'],
#
# [38.7139308,-9.197198799999999,'Av. Universidade Técnica, Lisboa, Portugal'],
#
# [41.557583,-8.397568,'Universidade do Minho, 4710 Braga, Portugal'],
#
# [39.48131559999999,-0.3505,'Universitat Politècnica, 46022 Valencia, Valencia, Spain'],
#
# [53.3053439,-6.220654,'Ucd Post Office, University College Dublin, Stillorgan Rd, Belfield, Dublin 4, Ireland'],
#
# [41.0757602,-81.5113878,'University of Akron, Akron, OH, USA'],
#
# [14.6311122,121.0925464,'Amsterdam, Marikina, Metro Manila, Philippines'],
#
# [33.6813785,-117.8207916,'Athens, Irvine, CA 92614, USA'],
#
# [32.485186,-99.7334839,'Birmingham, Abilene, TX 79601, USA'],
#
# [52.20166709999999,0.1177882,'University Of Cambridge, Cambridge, Cambridge, Cambridgeshire CB2, UK'],
#
# [28.0282578,-82.39242689999999,'Chicago Ave, Temple Terrace, FL 33617, USA'],
#
# [40.0082221,-105.2591119,'Colorado Ave & University Heights, Boulder, CO 80302, USA'],
#
# [28.6450197,-106.1127292,'Dallas, Campestre III Etapa, 31213 Chihuahua, Chih., Mexico'],
#
# [33.7105331,-117.7759092,'Delaware, Irvine, CA 92620, USA'],
#
# [44.9715569,-93.231866,'Essex St SE, Minneapolis, MN 55455, USA'],
#
# [28.0735403,-82.43735889999999,'University, FL, USA'],
#
# [54.08654629999999,13.3923414,'Greifswald, Germany'],
#
# [33.4229288,-111.8883942,'Hawaii, Tempe, AZ 85281, USA'],
#
# [8.5080482,4.5849938,'Kwara State University, Ilorin, Nigeria'],
#
# [38.8991444,-94.72548929999999,'University Of Kansas, Overland Park, KS 66213, USA'],
#
# [51.5266171,-0.1260773,'University Of London, 1-11 Cartwright Gardens, Kings Cross, London WC1H 9EB, UK'],
#
# [14.6349377,121.0560147,'Malaya, Diliman, Lungsod Quezon, Kalakhang Maynila, Philippines'],
#
# [42.2783714,-83.7371794,'University of Michigan, Ann Arbor, MI, USA'],
#
# [6.7959931,79.8970038,'Bandaranayake Mawatha, Moratuwa, Sri Lanka'],
#
# [31.80783,-106.468841,'Nebraska, El Paso, TX 79930, USA'],
#
# [41.2692748,-72.75524779999999,'University of New Haven, Branford Trolley Trail, Branford, CT 06405, USA'],
#
# [40.751539,-73.9812309,'University-Notre Dame Development, 10 E 40th St #1901, New York, NY 10016, USA'],
#
# [28.652306,-106.1181642,'Ottawa, Fidel Velázquez, 31210 Chihuahua, Chih., Mexico'],
#
# [33.6778327,-117.8151285,'Padua, Irvine, CA 92614, USA'],
#
# [33.4238104,-111.8869146,'Pennsylvania, Tempe, AZ 85281, USA'],
#
# [-25.7328565,28.2007589,'University of Pretoria, Dr Savage Rd, Pretoria, 0084, South Africa'],
#
# [28.6853472,-106.1015266,'São Paulo, Chihuahua, Chih., Mexico'],
#
# [38.19991050000001,-85.7659121,'Southern Pkwy, Louisville, KY, USA'],
#
# [58.37332809999999,26.7265098,'University of Tartu Physics Building, 50103 Tartu, Estonia'],
#
# [30.2306914,-97.75552049999999,'University, Austin, TX 78704, USA'],
#
# [43.659598,-79.3947916,'Toronto, Toronto, ON M5S, Canada'],
#
# [38.9562038,-95.24411119999999,'Twente Hall, Lawrence, KS 66044, USA'],
#
# [33.6140008,-117.8440006,'Vienna, Newport Beach, CA 92660, USA'],
#
# [31.767879,-106.440736,'Washington, El Paso, TX 79905, USA'],
#
# [43.4731293,-80.541687,'University of Waterloo, Waterloo, ON N2L, Canada'],
#
# [14.5995226,121.0539938,'Wisconsin, Mandaluyong, Metro Manila, Philippines'],
#
# [-26.1800289,28.0437484,'University of the Witwatersrand - Bohlaleng Block, Leseding Block, McGregor Block, Marang Centre, 1 Jan Smuts Ave, Johannesburg, 2000, South Africa'],
#
# [54.6871555,25.2796514,'Vilnius, Lithuania'],
#
# [36.8743583,-76.17454409999999,'Virginia Tech Trail, Virginia Beach, VA 23455, USA'],
#
# [14.606319,121.0977669,'Warsaw, Pasig, Metro Manila, Philippines'],
#
# [38.2407197,-82.43794009999999,'State Ave, Wayne, WV 25570, USA'],
#
# [31.9026385,34.8085102,'Weizmann Institute of Science, Herzl St 234, Rehovot, 76100, Israel'],
#
# [33.5047266,-112.0657477,'Xavier College, Phoenix, AZ 85012, USA'],
#
# [31.4932177,73.10517779999999,'Allama Iqbal Open University, Faisalabad, Pakistan'],
#
# [-18.512178,-44.5550308,'State of Minas Gerais, Brazil'],
#
# [40.4469796,-3.7278167,'Av. Complutense, Madrid, Madrid, Spain'],
#
# [33.6778327,-117.8151285,'Padua, Irvine, CA 92614, USA'],
#
# Records written : 149

# %%
import sqlite3
import ssl
import urllib.error
from urllib.parse import urlparse
from urllib.parse import urljoin
from urllib.request import urlopen
from bs4 import BeautifulSoup

# Ignore SSL certificate errors
ctx = ssl.create_default_context()
ctx.check_hostname = False
ctx.verify_mode = ssl.CERT_NONE


conn = sqlite3.connect('test.sqlite')
cur = conn.cursor()

cur.executescript('''
    Create table if not exists Pages(
    id integer primary key,
    url text unique,
    html text,
    error integer,
    old_rank real,
    new_rank real
    );

    Create table if not exists Links(
    from_id integer,
    to_id integer,
    unique(from_id,to_id)
    );

    Create table if not exists Webs(
    url text unique
    );

    ''')

cur.execute('Select id,url From Pages WHERE html is NULL and error is NULL order by random() limit 1')
row = cur.fetchone()

if row is not None:
    print('Restarting the spidering.Remove test.db to perform from beginning')
else:
    starturl = input('Enter the url:')
    if len(starturl) < 1 : starturl = 'https://www.python.org/'
    if starturl.endswith('/') : starturl = starturl[:-1]
    web = starturl

    if starturl.endswith('.htm') or starturl.endswith('.html'):
        pos = starturl.rfind('/')
        web = starturl[:pos]

    if len(web) > 1:
        cur.execute('Insert or Ignore into Webs(url) values(?)',(web,))
        cur.execute('Insert or Ignore into Pages(url,html,new_rank) values(?,NULL,1.0)',(starturl,))
        conn.commit()
    
cur.execute('Select url from Webs')
webs = list()
for row in cur:
    webs.append(str(row[0]))

print(webs)



many = 0
while True:
    if (many < 1) :
        sval = input('How many pages?')
        if len(sval) < 1: break
        many = int(sval)

    many = many -1

    cur.execute('Select id,url from Pages where html is NULL and error is NULL order by random() limit 1')

    try:
        row = cur.fetchone()
        from_id = row[0]
        url = row[1]

    except:
        print('No url remain to retrieved')
        many = 0
        break

    print(from_id,url,end = '')

    cur.execute('Delete from Links  where from_id = ?',(from_id,))

    try:
        documents = urlopen(url,context = ctx)

        html = documents.read()

        if documents.getcode() != 200:
            print('error on page:',documents.getcode())
            cur.execute('Update Pages set error = ? where url = ?',(documents.getcode(),url))

        if 'text/html' != documents.info().get_content_type():
            print('Not a html or text file')
            cur.execute('Delete from pages where url = ?',(url,))
            conn.commit()
            continue

        print('('+str(len(html))+')',end = '')

        soup = BeautifulSoup(html,"html.parser")

    except KeyboardInterrupt:
        print('Interrupted by user')
        break

    except:
        print('Unable to retrieve pages or url ')
        cur.execute('Update Pages set error = -1 where url = ?',(url,))
        conn.commit()
        continue

        cur.execute('INSERT OR IGNORE INTO Pages (url, html, new_rank) VALUES ( ?, NULL, 1.0 )', ( url, ) )
        cur.execute('UPDATE Pages SET html=? WHERE url=?', (memoryview(html), url ) )
        conn.commit()

        tags = soup('a')
        count = 0
        for tag in tags:
            href = tag.get('href',None)

            if href is None: continue
            up = urlparse(href)

            if len(up.scheme) < 1:
                href = urljoin(url,href)

            pound = href.find('#')
            if pound is not None:
                href = href[:pound]

            if href.endswith('.png') or href.endswith('.jpg') or href.endswith('.gif') : continue

            if href.endswith('/'):
                href = href[:-1]

            if len(href) < 1: continue

            found = False
            for web in webs:
                 if ( href.startswith(web) ) :
                    found = True
                    break
            if not found : continue

            cur.execute('Insert or Ignore into Pages(url,html,new_rank) values(?,NULL,1.0)',(href,))
            count = count + 1
            conn.commit()

            cur.execute('Select id from Pages where url = ? limit 1',(href,))

            try:
                to_id = cur.fetchone()[0]
            except:
                print('unable to retrieve id')
                continue

            
            cur.execute('Insert or Ignore into Links(from_id,to_id) values(?,?)',(from_id,to_id))

            

        print(count)

cur.close()
# Out:
# Enter the url:
# ['https://www.python.org']
# How many pages?5
# 1 https://www.python.org(49849)1 https://www.python.org(49849)1 https://www.python.org(49849)1 https://www.python.org(49849)1 https://www.python.org(49849)How many pages?
